# %%
# %load_ext autoreload
# %autoreload 2

# %%
from collections import defaultdict
import math
import scipy.optimize
import numpy
import string
from sklearn import linear_model
import random
import gzip
import numpy as np
from collections import Counter
import os
from utils import auc, jaccard_similarity

# %%
def readGz(path):
    for l in gzip.open(path, 'rt', encoding = 'utf8'):
        yield eval(l)

def readCSV(path):
    f = gzip.open(path, 'rt')
    f.readline()
    for l in f:
        u,b,r = l.strip().split(',')
        r = int(r)
        yield u,b,r

# %%
dataset_folder_path = os.path.join(os.getcwd(),"dataset")

user_recommend = {}
for  d in readGz(os.path.join(dataset_folder_path,"australian_user_reviews.json.gz")):
    user_recommend[d['user_id']] = [review["item_id"] for review in d['reviews'] if review["recommend"]==True]

# %%
# collect all the genres, tags, specs info for each game

steam_games_genres = {}

missing_genres_count = 0
missing_tags_count = 0
missing_specs_count = 0
missing_id_count = 0
rep_items = 0

for d in readGz(os.path.join(dataset_folder_path,"steam_games.json.gz")):

    if 'id' not in d.keys():
        print(f"This game has no id info!")
        print(d)
        missing_id_count += 1
        continue

    if d['id'] in steam_games_genres.keys():
        print(f"This game id ({d['id']}) already exists!")
        continue

    if 'genres' not in d.keys():
        print(f"This game id ({d['id']}) has no genre info!")
        genre_info = []
        missing_genres_count += 1

    else:
        genre_info = d['genres']

    if 'tags' not in d.keys():
        print(f"This game id ({d['id']}) has no tag info!")
        tag_info = []
        missing_tags_count += 1

    else:
        tag_info = d['tags']

    if 'specs' not in d.keys():
        print(f"This game id ({d['id']}) has no specs info!")
        specs_info = []
        missing_specs_count += 1

    else:
        specs_info = d['specs']

    steam_games_genres[d['id']] = {'genres': genre_info,
                                   'tags': tag_info, 'specs': specs_info}
# Out:
# This game id (773570) has no genre info!
# This game id (724910) has no genre info!
# This game id (772590) has no genre info!
# This game id (640250) has no genre info!
# This game id (711440) has no genre info!
# This game id (777910) has no genre info!
# This game id (777910) has no specs info!
# This game id (594200) has no genre info!
# This game id (680970) has no genre info!
# This game id (541930) has no genre info!
# This game id (769350) has no genre info!
# This game id (374970) has no genre info!
# This game has no id info!
# {'url': 'http://store.steampowered.com/', 'price': 19.99, 'discount_price': 14.99, 'early_access': False}
# This game id (12580) has no genre info!
# This game id (12570) has no genre info!
# This game id (22340) has no genre info!
# This game id (900883) has no genre info!
# This game id (31990) has no tag info!
# This game id (38440) has no genre info!
# This game id (35050) has no tag info!
# This game id (39392) has no tag info!
# This game id (39391) has no tag info!
# This game id (42200) has no genre info!
# This game id (25806) has no genre info!
# This game id (25806) has no tag info!
# This game id (37360) has no tag info!
# This game id (34278) has no genre info!
# This game id (27930) has no genre info!
# This game id (27930) has no tag info!
# This game id (71111) has no genre info!
# This game id (71110) has no genre info!
# This game id (34318) has no genre info!
# This game id (71168) has no genre info!
# This game id (71162) has no genre info!
# This game id (56436) has no genre info!
# This game id (56436) has no tag info!
# This game id (48220) has no specs info!
# This game id (202520) has no genre info!
# This game id (202520) has no tag info!
# This game id (202523) has no genre info!
# This game id (202523) has no tag info!
# This game id (25811) has no genre info!
# This game id (25811) has no tag info!
# This game id (65302) has no genre info!
# This game id (65302) has no tag info!
# This game id (206760) has no specs info!
# This game id (71167) has no genre info!
# This game id (40391) has no genre info!
# This game id (40391) has no tag info!
# This game id (209373) has no genre info!
# This game id (209373) has no tag info!
# This game id (211204) has no genre info!
# This game id (211203) has no genre info!
# This game id (211207) has no genre info!
# This game id (211205) has no genre info!
# This game id (211208) has no genre info!
# This game id (211209) has no genre info!
# This game id (229750) has no genre info!
# This game id (570) has no genre info!
# This game id (223750) has no genre info!
# This game id (236390) has no genre info!
# This game id (257610) has no specs info!
# This game id (262650) has no specs info!
# This game id (215922) has no genre info!
# This game id (215922) has no tag info!
# This game id (215921) has no genre info!
# This game id (215921) has no tag info!
# This game id (215914) has no genre info!
# This game id (215914) has no tag info!
# This game id (215913) has no genre info!
# This game id (215913) has no tag info!
# This game id (255760) has no genre info!
# This game id (255760) has no tag info!
# This game id (292350) has no specs info!
# This game id (269550) has no specs info!
# This game id (294350) has no tag info!
# This game id (288730) has no specs info!
# This game id (298010) has no tag info!
# This game id (282240) has no genre info!
# This game id (282240) has no tag info!
# This game id (281900) has no specs info!
# This game id (301730) has no specs info!
# This game id (205093) has no genre info!
# This game id (205093) has no tag info!
# This game id (275171) has no genre info!
# This game id (275171) has no tag info!
# This game id (302130) has no specs info!
# This game id (360290) has no genre info!
# This game id (360290) has no specs info!
# This game id (296070) has no genre info!
# This game id (314500) has no specs info!
# This game id (319260) has no genre info!
# This game id (301320) has no genre info!
# This game id (316630) has no specs info!
# This game id (316620) has no specs info!
# This game id (251890) has no genre info!
# This game id (317800) has no genre info!
# This game id (317800) has no specs info!
# This game id (326760) has no genre info!
# This game id (325670) has no genre info!
# This game id (325670) has no tag info!
# This game id (282510) has no genre info!
# This game id (325180) has no specs info!
# This game id (322410) has no specs info!
# This game id (241680) has no specs info!
# This game id (244210) has no genre info!
# This game id (329770) has no genre info!
# This game id (343120) has no genre info!
# This game id (343740) has no genre info!
# This game id (345310) has no specs info!
# This game id (345300) has no specs info!
# This game id (348010) has no tag info!
# This game id (341190) has no genre info!
# This game id (348860) has no genre info!
# This game id (340410) has no genre info!
# This game id (354110) has no genre info!
# This game id (354110) has no tag info!
# This game id (345370) has no specs info!
# This game id (359080) has no genre info!
# This game id (354570) has no genre info!
# This game id (354570) has no tag info!
# This game id (356940) has no specs info!
# This game id (342430) has no genre info!
# This game id (342430) has no specs info!
# This game id (362280) has no genre info!
# This game id (362280) has no specs info!
# This game id (325330) has no specs info!
# This game id (362900) has no genre info!
# This game id (363620) has no genre info!
# This game id (364380) has no genre info!
# This game id (365670) has no specs info!
# This game id (362870) has no specs info!
# This game id (367150) has no genre info!
# This game id (367150) has no tag info!
# This game id (331460) has no genre info!
# This game id (361220) has no genre info!
# This game id (361220) has no specs info!
# This game id (296710) has no genre info!
# This game id (372390) has no genre info!
# This game id (365140) has no genre info!
# This game id (329860) has no genre info!
# This game id (373020) has no genre info!
# This game id (373020) has no specs info!
# This game id (373330) has no genre info!
# This game id (384420) has no genre info!
# This game id (384420) has no specs info!
# This game id (371300) has no genre info!
# This game id (382620) has no genre info!
# This game id (382620) has no specs info!
# This game id (382690) has no genre info!
# This game id (382690) has no specs info!
# This game id (382700) has no genre info!
# This game id (382700) has no specs info!
# This game id (382660) has no genre info!
# This game id (382660) has no specs info!
# This game id (382790) has no genre info!
# This game id (382790) has no specs info!
# This game id (382760) has no genre info!
# This game id (382760) has no specs info!
# This game id (387460) has no genre info!
# This game id (387460) has no specs info!
# This game id (382740) has no genre info!
# This game id (382740) has no specs info!
# This game id (382750) has no genre info!
# This game id (382750) has no specs info!
# This game id (374120) has no genre info!
# This game id (387550) has no genre info!
# This game id (387550) has no specs info!
# This game id (387480) has no genre info!
# This game id (387480) has no specs info!
# This game id (389240) has no genre info!
# This game id (389240) has no tag info!
# This game id (387590) has no genre info!
# This game id (387590) has no specs info!
# This game id (387630) has no genre info!
# This game id (387630) has no specs info!
# This game id (387620) has no genre info!
# This game id (387620) has no specs info!
# This game id (383540) has no genre info!
# This game id (387640) has no genre info!
# This game id (387640) has no specs info!
# This game id (394900) has no genre info!
# This game id (394900) has no specs info!
# This game id (388980) has no specs info!
# This game id (395210) has no genre info!
# This game id (395210) has no tag info!
# This game id (396140) has no genre info!
# This game id (396130) has no genre info!
# This game id (396120) has no genre info!
# This game id (393360) has no genre info!
# This game id (393360) has no specs info!
# This game id (252870) has no genre info!
# This game id (382650) has no genre info!
# This game id (382650) has no specs info!
# This game id (337280) has no genre info!
# This game id (342260) has no genre info!
# This game id (406820) has no genre info!
# This game id (406820) has no tag info!
# This game id (400040) has no specs info!
# This game id (378750) has no genre info!
# This game id (363020) has no specs info!
# This game id (393340) has no specs info!
# This game id (382670) has no genre info!
# This game id (382670) has no specs info!
# This game id (391910) has no genre info!
# This game id (386550) has no specs info!
# This game id (411550) has no specs info!
# This game id (401990) has no genre info!
# This game id (401990) has no specs info!
# This game id (401310) has no genre info!
# This game id (401310) has no specs info!
# This game id (404110) has no genre info!
# This game id (404110) has no specs info!
# This game id (404300) has no genre info!
# This game id (404300) has no specs info!
# This game id (402730) has no genre info!
# This game id (402730) has no specs info!
# This game id (405700) has no specs info!
# This game id (405690) has no specs info!
# This game id (394890) has no genre info!
# This game id (394890) has no specs info!
# This game id (413850) has no genre info!
# This game id (413850) has no specs info!
# This game id (411690) has no genre info!
# This game id (413600) has no genre info!
# This game id (413600) has no specs info!
# This game id (412770) has no genre info!
# This game id (413900) has no genre info!
# This game id (413900) has no specs info!
# This game id (413890) has no genre info!
# This game id (413890) has no specs info!
# This game id (406210) has no genre info!
# This game id (398480) has no genre info!
# This game id (353380) has no genre info!
# This game id (353380) has no specs info!
# This game id (413910) has no genre info!
# This game id (413910) has no specs info!
# This game id (413920) has no genre info!
# This game id (413920) has no specs info!
# This game id (411180) has no genre info!
# This game id (411180) has no specs info!
# This game id (418290) has no specs info!
# This game id (384990) has no genre info!
# This game id (419550) has no genre info!
# This game id (419550) has no specs info!
# This game id (419610) has no genre info!
# This game id (419610) has no specs info!
# This game id (419620) has no genre info!
# This game id (419620) has no specs info!
# This game id (419640) has no genre info!
# This game id (419640) has no specs info!
# This game id (416590) has no genre info!
# This game id (422540) has no genre info!
# This game id (391050) has no specs info!
# This game id (432970) has no genre info!
# This game id (432970) has no tag info!
# This game id (431490) has no genre info!
# This game id (431490) has no tag info!
# This game id (207340) has no specs info!
# This game id (414840) has no genre info!
# This game id (414840) has no specs info!
# This game id (433430) has no genre info!
# This game id (433430) has no tag info!
# This game id (419220) has no genre info!
# This game id (419220) has no specs info!
# This game id (411350) has no specs info!
# This game id (393330) has no specs info!
# This game id (438110) has no specs info!
# This game id (414860) has no genre info!
# This game id (414860) has no specs info!
# This game id (393320) has no specs info!
# This game id (425560) has no specs info!
# This game id (414510) has no genre info!
# This game id (439260) has no genre info!
# This game id (428340) has no specs info!
# This game id (400810) has no genre info!
# This game id (400810) has no tag info!
# This game id (433270) has no genre info!
# This game id (433270) has no specs info!
# This game id (441540) has no genre info!
# This game id (441540) has no specs info!
# This game id (444550) has no genre info!
# This game id (382990) has no genre info!
# This game id (382990) has no tag info!
# This game id (382990) has no specs info!
# This game id (431730) has no specs info!
# This game id (323910) has no specs info!
# This game id (377590) has no specs info!
# This game id (435175) has no genre info!
# This game id (435175) has no tag info!
# This game id (435170) has no genre info!
# This game id (435170) has no tag info!
# This game id (435173) has no genre info!
# This game id (435173) has no tag info!
# This game id (435177) has no genre info!
# This game id (435172) has no genre info!
# This game id (435172) has no tag info!
# This game id (435176) has no genre info!
# This game id (435176) has no tag info!
# This game id (435174) has no genre info!
# This game id (435174) has no tag info!
# This game id (435171) has no genre info!
# This game id (435171) has no tag info!
# This game id (442310) has no genre info!
# This game id (442310) has no specs info!
# This game id (437400) has no genre info!
# This game id (450220) has no genre info!
# This game id (419240) has no genre info!
# This game id (419240) has no specs info!
# This game id (446960) has no genre info!
# This game id (446960) has no specs info!
# This game id (449130) has no genre info!
# This game id (406830) has no specs info!
# This game id (455440) has no genre info!
# This game id (446830) has no specs info!
# This game id (330770) has no genre info!
# This game id (300060) has no genre info!
# This game id (433500) has no genre info!
# This game id (382110) has no genre info!
# This game id (457880) has no genre info!
# This game id (392190) has no genre info!
# This game id (451650) has no genre info!
# This game id (420840) has no genre info!
# This game id (434430) has no genre info!
# This game id (380670) has no genre info!
# This game id (448880) has no genre info!
# This game id (447270) has no genre info!
# This game id (457960) has no genre info!
# This game id (428370) has no genre info!
# This game id (409390) has no genre info!
# This game id (446770) has no genre info!
# This game id (427890) has no genre info!
# This game id (459260) has no genre info!
# This game id (452710) has no genre info!
# This game id (433700) has no genre info!
# This game id (343730) has no genre info!
# This game id (457870) has no genre info!
# This game id (412740) has no genre info!
# This game id (414120) has no genre info!
# This game id (451520) has no genre info!
# This game id (322770) has no genre info!
# This game id (410570) has no genre info!
# This game id (457690) has no genre info!
# This game id (456420) has no genre info!
# This game id (461020) has no genre info!
# This game id (461020) has no tag info!
# This game id (460740) has no genre info!
# This game id (460740) has no specs info!
# This game id (462550) has no genre info!
# This game id (462550) has no tag info!
# This game id (457660) has no genre info!
# This game id (446620) has no genre info!
# This game id (461180) has no genre info!
# This game id (459940) has no genre info!
# This game id (453440) has no genre info!
# This game id (427390) has no genre info!
# This game id (462460) has no genre info!
# This game id (427350) has no genre info!
# This game id (427300) has no genre info!
# This game id (427360) has no genre info!
# This game id (427370) has no genre info!
# This game id (427320) has no genre info!
# This game id (421370) has no genre info!
# This game id (427310) has no genre info!
# This game id (453450) has no genre info!
# This game id (416560) has no genre info!
# This game id (416520) has no genre info!
# This game id (417590) has no genre info!
# This game id (417610) has no genre info!
# This game id (426500) has no genre info!
# This game id (426530) has no genre info!
# This game id (453920) has no genre info!
# This game id (426540) has no genre info!
# This game id (426420) has no genre info!
# This game id (426520) has no genre info!
# This game id (426510) has no genre info!
# This game id (417640) has no genre info!
# This game id (417630) has no genre info!
# This game id (441170) has no genre info!
# This game id (441160) has no genre info!
# This game id (421460) has no genre info!
# This game id (421470) has no genre info!
# This game id (421490) has no genre info!
# This game id (421480) has no genre info!
# This game id (421450) has no genre info!
# This game id (417580) has no genre info!
# This game id (426470) has no genre info!
# This game id (426480) has no genre info!
# This game id (417560) has no genre info!
# This game id (426440) has no genre info!
# This game id (417670) has no genre info!
# This game id (441150) has no genre info!
# This game id (437240) has no genre info!
# This game id (441100) has no genre info!
# This game id (441090) has no genre info!
# This game id (441180) has no genre info!
# This game id (441200) has no genre info!
# This game id (441080) has no genre info!
# This game id (441210) has no genre info!
# This game id (426350) has no genre info!
# This game id (437260) has no genre info!
# This game id (426450) has no genre info!
# This game id (441140) has no genre info!
# This game id (441190) has no genre info!
# This game id (441120) has no genre info!
# This game id (421240) has no genre info!
# This game id (463310) has no genre info!
# This game id (463310) has no tag info!
# This game id (457320) has no genre info!
# This game id (462530) has no genre info!
# This game id (395880) has no genre info!
# This game id (463750) has no genre info!
# This game id (463750) has no specs info!
# This game id (465450) has no genre info!
# This game id (435740) has no specs info!
# This game id (222573) has no genre info!
# This game id (222573) has no tag info!
# This game id (401820) has no genre info!
# This game id (462000) has no genre info!
# This game id (458990) has no genre info!
# This game id (344180) has no genre info!
# This game id (463290) has no genre info!
# This game id (465310) has no genre info!
# This game id (452950) has no specs info!
# This game id (467190) has no genre info!
# This game id (467180) has no genre info!
# This game id (467110) has no genre info!
# This game id (467100) has no genre info!
# This game id (467160) has no genre info!
# This game id (467200) has no genre info!
# This game id (467140) has no genre info!
# This game id (290060) has no genre info!
# This game id (467130) has no genre info!
# This game id (452110) has no genre info!
# This game id (464190) has no genre info!
# This game id (464190) has no specs info!
# This game id (469560) has no genre info!
# This game id (450200) has no genre info!
# This game id (450260) has no genre info!
# This game id (414810) has no genre info!
# This game id (450270) has no genre info!
# This game id (450280) has no genre info!
# This game id (450300) has no genre info!
# This game id (450310) has no genre info!
# This game id (446690) has no genre info!
# This game id (450230) has no genre info!
# This game id (421320) has no genre info!
# This game id (452140) has no genre info!
# This game id (452160) has no genre info!
# This game id (452150) has no genre info!
# This game id (452270) has no genre info!
# This game id (452170) has no genre info!
# This game id (452260) has no genre info!
# This game id (452300) has no genre info!
# This game id (452350) has no genre info!
# This game id (452330) has no genre info!
# This game id (452370) has no genre info!
# This game id (452380) has no genre info!
# This game id (452360) has no genre info!
# This game id (464940) has no genre info!
# This game id (427400) has no genre info!
# This game id (462470) has no genre info!
# This game id (356180) has no genre info!
# This game id (440150) has no genre info!
# This game id (440150) has no specs info!
# This game id (422640) has no genre info!
# This game id (477130) has no genre info!
# This game id (485270) has no genre info!
# This game id (482390) has no genre info!
# This game id (347170) has no genre info!
# This game id (485110) has no genre info!
# This game id (467230) has no genre info!
# This game id (467230) has no specs info!
# This game id (464410) has no genre info!
# This game id (464420) has no genre info!
# This game id (464430) has no genre info!
# This game id (313630) has no genre info!
# This game id (432030) has no specs info!
# This game id (473100) has no genre info!
# This game id (473100) has no tag info!
# This game id (467870) has no genre info!
# This game id (467870) has no tag info!
# This game id (456570) has no genre info!
# This game id (485880) has no genre info!
# This game id (433800) has no specs info!
# This game id (417620) has no genre info!
# This game id (357920) has no genre info!
# This game id (490320) has no genre info!
# This game id (490320) has no tag info!
# This game id (465780) has no genre info!
# This game id (494150) has no genre info!
# This game id (488370) has no genre info!
# This game id (488380) has no genre info!
# This game id (488400) has no genre info!
# This game id (488390) has no genre info!
# This game id (406220) has no genre info!
# This game id (458200) has no genre info!
# This game id (494310) has no genre info!
# This game id (495320) has no genre info!
# This game id (457340) has no genre info!
# This game id (378070) has no genre info!
# This game id (492470) has no genre info!
# This game id (492470) has no specs info!
# This game id (492510) has no genre info!
# This game id (492510) has no specs info!
# This game id (490090) has no genre info!
# This game id (490090) has no specs info!
# This game id (498510) has no genre info!
# This game id (493380) has no genre info!
# This game id (487990) has no genre info!
# This game id (468680) has no genre info!
# This game id (500920) has no genre info!
# This game id (491710) has no genre info!
# This game id (275030) has no specs info!
# This game id (458110) has no genre info!
# This game id (468700) has no genre info!
# This game id (381940) has no genre info!
# This game id (495540) has no genre info!
# This game id (494810) has no genre info!
# This game id (493620) has no genre info!
# This game id (501420) has no genre info!
# This game id (373650) has no genre info!
# This game id (500500) has no genre info!
# This game id (495550) has no genre info!
# This game id (485150) has no specs info!
# This game id (500570) has no specs info!
# This game id (500470) has no genre info!
# This game id (500380) has no genre info!
# This game id (503110) has no genre info!
# This game id (503110) has no tag info!
# This game id (501380) has no genre info!
# This game id (497300) has no genre info!
# This game id (427340) has no genre info!
# This game id (452810) has no genre info!
# This game id (499610) has no genre info!
# This game id (494780) has no genre info!
# This game id (500800) has no genre info!
# This game id (495300) has no genre info!
# This game id (453840) has no genre info!
# This game id (496710) has no genre info!
# This game id (496800) has no genre info!
# This game id (496800) has no specs info!
# This game id (496720) has no genre info!
# This game id (496010) has no genre info!
# This game id (504630) has no genre info!
# This game id (487740) has no genre info!
# This game id (504100) has no genre info!
# This game id (494680) has no genre info!
# This game id (494680) has no specs info!
# This game id (503470) has no genre info!
# This game id (499940) has no genre info!
# This game id (485230) has no genre info!
# This game id (506570) has no genre info!
# This game id (509340) has no genre info!
# This game id (509360) has no genre info!
# This game id (497460) has no genre info!
# This game id (377340) has no genre info!
# This game id (377350) has no genre info!
# This game id (498210) has no genre info!
# This game id (498230) has no genre info!
# This game id (498250) has no genre info!
# This game id (510740) has no genre info!
# This game id (501220) has no genre info!
# This game id (507570) has no genre info!
# This game id (507570) has no specs info!
# This game id (498260) has no genre info!
# This game id (504710) has no specs info!
# This game id (499160) has no genre info!
# This game id (504720) has no specs info!
# This game id (411620) has no genre info!
# This game id (499130) has no genre info!
# This game id (495390) has no genre info!
# This game id (495830) has no genre info!
# This game id (511940) has no genre info!
# This game id (511940) has no specs info!
# This game id (510700) has no genre info!
# This game id (510410) has no genre info!
# This game id (426400) has no genre info!
# This game id (504570) has no genre info!
# This game id (504570) has no specs info!
# This game id (505490) has no genre info!
# This game id (506230) has no genre info!
# This game id (512970) has no genre info!
# This game id (510990) has no genre info!
# This game id (513670) has no genre info!
# This game id (512630) has no genre info!
# This game id (511420) has no genre info!
# This game id (513790) has no genre info!
# This game id (451010) has no genre info!
# This game id (508890) has no genre info!
# This game id (514190) has no genre info!
# This game id (514190) has no specs info!
# This game id (511410) has no genre info!
# This game id (511410) has no specs info!
# This game id (511400) has no genre info!
# This game id (511400) has no specs info!
# This game id (493500) has no genre info!
# This game id (516850) has no genre info!
# This game id (516830) has no genre info!
# This game id (428080) has no genre info!
# This game id (473970) has no genre info!
# This game id (516590) has no genre info!
# This game id (514350) has no genre info!
# This game id (504550) has no genre info!
# This game id (476700) has no genre info!
# This game id (505380) has no genre info!
# This game id (489740) has no genre info!
# This game id (516550) has no genre info!
# This game id (471160) has no genre info!
# This game id (519220) has no genre info!
# This game id (519220) has no specs info!
# This game id (519420) has no genre info!
# This game id (519420) has no specs info!
# This game id (513420) has no genre info!
# This game id (516940) has no genre info!
# This game id (222500) has no genre info!
# This game id (510960) has no genre info!
# This game id (482210) has no genre info!
# This game id (504580) has no genre info!
# This game id (507980) has no genre info!
# This game id (507980) has no specs info!
# This game id (508000) has no genre info!
# This game id (508000) has no specs info!
# This game id (503150) has no genre info!
# This game id (516020) has no genre info!
# This game id (490250) has no genre info!
# This game id (272920) has no genre info!
# This game id (523570) has no genre info!
# This game id (511570) has no genre info!
# This game id (513200) has no genre info!
# This game id (523050) has no genre info!
# This game id (525650) has no genre info!
# This game id (460990) has no genre info!
# This game id (517770) has no genre info!
# This game id (519940) has no genre info!
# This game id (511720) has no specs info!
# This game id (506030) has no specs info!
# This game id (460580) has no genre info!
# This game id (505580) has no genre info!
# This game id (510910) has no genre info!
# This game id (517460) has no genre info!
# This game id (500350) has no genre info!
# This game id (490840) has no genre info!
# This game id (524060) has no genre info!
# This game id (504610) has no genre info!
# This game id (496160) has no genre info!
# This game id (517860) has no genre info!
# This game id (492710) has no genre info!
# This game id (519530) has no genre info!
# This game id (526960) has no genre info!
# This game id (527440) has no specs info!
# This game id (497310) has no specs info!
# This game id (517030) has no genre info!
# This game id (518440) has no genre info!
# This game id (518440) has no specs info!
# This game id (518460) has no genre info!
# This game id (518460) has no specs info!
# This game id (523360) has no genre info!
# This game id (523360) has no specs info!
# This game id (518500) has no genre info!
# This game id (518500) has no specs info!
# This game id (527360) has no genre info!
# This game id (525500) has no genre info!
# This game id (528790) has no genre info!
# This game id (505560) has no genre info!
# This game id (534140) has no genre info!
# This game id (517990) has no genre info!
# This game id (524610) has no genre info!
# This game id (492870) has no genre info!
# This game id (426610) has no genre info!
# This game id (521270) has no genre info!
# This game id (521480) has no genre info!
# This game id (521480) has no specs info!
# This game id (503160) has no genre info!
# This game id (517220) has no genre info!
# This game id (466290) has no genre info!
# This game id (535380) has no genre info!
# This game id (535960) has no genre info!
# This game id (535960) has no specs info!
# This game id (518110) has no genre info!
# This game id (535530) has no genre info!
# This game id (527160) has no genre info!
# This game id (526550) has no genre info!
# This game id (528200) has no specs info!
# This game id (529820) has no genre info!
# This game id (528590) has no genre info!
# This game id (528590) has no specs info!
# This game id (518200) has no genre info!
# This game id (518200) has no specs info!
# This game id (529280) has no genre info!
# This game id (536800) has no genre info!
# This game id (538780) has no genre info!
# This game id (519360) has no genre info!
# This game id (519360) has no specs info!
# This game id (534000) has no genre info!
# This game id (519320) has no genre info!
# This game id (519320) has no specs info!
# This game id (487730) has no genre info!
# This game id (520040) has no genre info!
# This game id (537870) has no genre info!
# This game id (537590) has no genre info!
# This game id (538410) has no genre info!
# This game id (509380) has no genre info!
# This game id (505700) has no genre info!
# This game id (538330) has no genre info!
# This game id (518240) has no genre info!
# This game id (506330) has no genre info!
# This game id (531560) has no genre info!
# This game id (506310) has no genre info!
# This game id (504560) has no genre info!
# This game id (503630) has no genre info!
# This game id (436400) has no genre info!
# This game id (532740) has no genre info!
# This game id (542170) has no genre info!
# This game id (511700) has no genre info!
# This game id (543640) has no genre info!
# This game id (409020) has no genre info!
# This game id (542750) has no genre info!
# This game id (523720) has no genre info!
# This game id (540500) has no genre info!
# This game id (468110) has no genre info!
# This game id (526590) has no genre info!
# This game id (531570) has no genre info!
# This game id (542960) has no genre info!
# This game id (485240) has no genre info!
# This game id (413250) has no genre info!
# This game id (413250) has no specs info!
# This game id (545630) has no genre info!
# This game id (547650) has no genre info!
# This game id (547200) has no genre info!
# This game id (513320) has no genre info!
# This game id (547850) has no genre info!
# This game id (519400) has no genre info!
# This game id (519400) has no specs info!
# This game id (519300) has no genre info!
# This game id (519300) has no specs info!
# This game id (534440) has no genre info!
# This game id (429180) has no genre info!
# This game id (522710) has no genre info!
# This game id (543660) has no genre info!
# This game id (548360) has no genre info!
# This game id (466900) has no genre info!
# This game id (514630) has no genre info!
# This game id (513760) has no genre info!
# This game id (546240) has no genre info!
# This game id (522730) has no genre info!
# This game id (544420) has no genre info!
# This game id (493490) has no genre info!
# This game id (427240) has no genre info!
# This game id (489860) has no genre info!
# This game id (489860) has no tag info!
# This game id (523180) has no genre info!
# This game id (548080) has no genre info!
# This game id (547740) has no genre info!
# This game id (536210) has no genre info!
# This game id (552220) has no genre info!
# This game id (495030) has no genre info!
# This game id (554700) has no genre info!
# This game id (553410) has no genre info!
# This game id (536370) has no genre info!
# This game id (552770) has no genre info!
# This game id (549530) has no genre info!
# This game id (549530) has no specs info!
# This game id (550270) has no genre info!
# This game id (539050) has no genre info!
# This game id (550280) has no genre info!
# This game id (551690) has no genre info!
# This game id (478000) has no genre info!
# This game id (550290) has no genre info!
# This game id (550290) has no specs info!
# This game id (504420) has no genre info!
# This game id (504470) has no genre info!
# This game id (370210) has no genre info!
# This game id (538980) has no genre info!
# This game id (546650) has no genre info!
# This game id (553590) has no genre info!
# This game id (548860) has no genre info!
# This game id (456920) has no genre info!
# This game id (549000) has no genre info!
# This game id (540430) has no genre info!
# This game id (540440) has no genre info!
# This game id (548490) has no genre info!
# This game id (538970) has no genre info!
# This game id (550060) has no specs info!
# This game id (552660) has no genre info!
# This game id (559010) has no genre info!
# This game id (558060) has no genre info!
# This game id (557850) has no genre info!
# This game id (501630) has no specs info!
# This game id (549070) has no genre info!
# This game id (547590) has no genre info!
# This game id (549071) has no genre info!
# This game id (460730) has no genre info!
# This game id (515700) has no genre info!
# This game id (554680) has no genre info!
# This game id (520210) has no genre info!
# This game id (552230) has no genre info!
# This game id (254590) has no genre info!
# This game id (451540) has no genre info!
# This game id (462520) has no genre info!
# This game id (565560) has no genre info!
# This game id (565570) has no genre info!
# This game id (565580) has no genre info!
# This game id (471660) has no genre info!
# This game id (565590) has no genre info!
# This game id (562510) has no specs info!
# This game id (529590) has no genre info!
# This game id (530350) has no genre info!
# This game id (520350) has no genre info!
# This game id (558650) has no genre info!
# This game id (554140) has no genre info!
# This game id (566150) has no genre info!
# This game id (559300) has no genre info!
# This game id (550520) has no genre info!
# This game id (527540) has no genre info!
# This game id (416090) has no genre info!
# This game id (486780) has no genre info!
# This game id (561360) has no genre info!
# This game id (568030) has no genre info!
# This game id (506930) has no genre info!
# This game id (523550) has no genre info!
# This game id (558850) has no genre info!
# This game id (561230) has no genre info!
# This game id (551720) has no genre info!
# This game id (566170) has no genre info!
# This game id (556140) has no genre info!
# This game id (541600) has no genre info!
# This game id (541520) has no genre info!
# This game id (541610) has no genre info!
# This game id (541690) has no genre info!
# This game id (513160) has no genre info!
# This game id (554820) has no specs info!
# This game id (489380) has no genre info!
# This game id (565190) has no genre info!
# This game id (512010) has no genre info!
# This game id (466520) has no genre info!
# This game id (546110) has no genre info!
# This game id (476430) has no genre info!
# This game id (408250) has no genre info!
# This game id (571990) has no genre info!
# This game id (535190) has no genre info!
# This game id (570060) has no genre info!
# This game id (561490) has no genre info!
# This game id (560970) has no genre info!
# This game id (559140) has no genre info!
# This game id (566870) has no genre info!
# This game id (531980) has no genre info!
# This game id (552340) has no genre info!
# This game id (543920) has no genre info!
# This game id (568800) has no genre info!
# This game id (420020) has no genre info!
# This game id (573610) has no genre info!
# This game id (488040) has no genre info!
# This game id (575560) has no genre info!
# This game id (574190) has no genre info!
# This game id (548010) has no genre info!
# This game id (573330) has no genre info!
# This game id (557670) has no genre info!
# This game id (560930) has no genre info!
# This game id (570470) has no genre info!
# This game id (548560) has no genre info!
# This game id (577260) has no genre info!
# This game id (575280) has no genre info!
# This game id (541650) has no genre info!
# This game id (566730) has no genre info!
# This game id (570860) has no genre info!
# This game id (576100) has no genre info!
# This game id (573550) has no genre info!
# This game id (566780) has no genre info!
# This game id (577290) has no genre info!
# This game id (577370) has no genre info!
# This game id (577270) has no genre info!
# This game id (579050) has no genre info!
# This game id (557960) has no genre info!
# This game id (575170) has no genre info!
# This game id (576880) has no genre info!
# This game id (540490) has no genre info!
# This game id (573280) has no genre info!
# This game id (566900) has no genre info!
# This game id (566880) has no genre info!
# This game id (565530) has no genre info!
# This game id (538230) has no genre info!
# This game id (571930) has no genre info!
# This game id (582200) has no genre info!
# This game id (560400) has no genre info!
# This game id (560400) has no tag info!
# This game id (555810) has no specs info!
# This game id (576230) has no genre info!
# This game id (568330) has no genre info!
# This game id (578300) has no genre info!
# This game id (531550) has no genre info!
# This game id (578050) has no genre info!
# This game id (501650) has no specs info!
# This game id (501660) has no specs info!
# This game id (526180) has no genre info!
# This game id (566270) has no genre info!
# This game id (346460) has no genre info!
# This game id (578610) has no genre info!
# This game id (565520) has no genre info!
# This game id (575110) has no genre info!
# This game id (583570) has no genre info!
# This game id (492520) has no specs info!
# This game id (541480) has no genre info!
# This game id (579080) has no genre info!
# This game id (438100) has no genre info!
# This game id (446060) has no specs info!
# This game id (451450) has no genre info!
# This game id (451450) has no tag info!
# This game id (579640) has no specs info!
# This game id (582500) has no genre info!
# This game id (588290) has no genre info!
# This game id (574920) has no genre info!
# This game id (520510) has no genre info!
# This game id (582210) has no genre info!
# This game id (584320) has no genre info!
# This game id (570510) has no genre info!
# This game id (578130) has no genre info!
# This game id (590500) has no genre info!
# This game id (590500) has no tag info!
# This game id (582290) has no genre info!
# This game id (580630) has no genre info!
# This game id (522020) has no genre info!
# This game id (586360) has no genre info!
# This game id (583200) has no genre info!
# This game id (355460) has no genre info!
# This game id (589180) has no genre info!
# This game id (585340) has no genre info!
# This game id (568240) has no genre info!
# This game id (575270) has no specs info!
# This game id (460470) has no genre info!
# This game id (574520) has no genre info!
# This game id (578510) has no genre info!
# This game id (578550) has no genre info!
# This game id (578570) has no genre info!
# This game id (577720) has no genre info!
# This game id (579040) has no genre info!
# This game id (568600) has no genre info!
# This game id (526130) has no genre info!
# This game id (497440) has no genre info!
# This game id (522220) has no genre info!
# This game id (590740) has no genre info!
# This game id (591150) has no genre info!
# This game id (592870) has no genre info!
# This game id (592930) has no genre info!
# This game id (593520) has no genre info!
# This game id (595220) has no genre info!
# This game id (595450) has no genre info!
# This game id (592900) has no genre info!
# This game id (595540) has no genre info!
# This game id (556010) has no genre info!
# This game id (556520) has no genre info!
# This game id (598100) has no genre info!
# This game id (577010) has no genre info!
# This game id (595210) has no genre info!
# This game id (596750) has no genre info!
# This game id (595680) has no genre info!
# This game id (596790) has no genre info!
# This game id (593190) has no genre info!
# This game id (596040) has no genre info!
# This game id (596010) has no genre info!
# This game id (596450) has no genre info!
# This game id (597800) has no genre info!
# This game id (580680) has no genre info!
# This game id (599970) has no genre info!
# This game id (595620) has no genre info!
# This game id (584040) has no genre info!
# This game id (582990) has no genre info!
# This game id (535170) has no genre info!
# This game id (580530) has no genre info!
# This game id (592920) has no genre info!
# This game id (592720) has no genre info!
# This game id (596640) has no genre info!
# This game id (571040) has no specs info!
# This game id (580060) has no genre info!
# This game id (442230) has no specs info!
# This game id (586990) has no genre info!
# This game id (598150) has no genre info!
# This game id (461320) has no genre info!
# This game id (601760) has no genre info!
# This game id (601620) has no genre info!
# This game id (570150) has no genre info!
# This game id (391640) has no genre info!
# This game id (580310) has no specs info!
# This game id (590640) has no specs info!
# This game id (595510) has no specs info!
# This game id (544000) has no genre info!
# This game id (534920) has no genre info!
# This game id (594150) has no genre info!
# This game id (579620) has no genre info!
# This game id (592330) has no genre info!
# This game id (594360) has no genre info!
# This game id (577690) has no genre info!
# This game id (582490) has no genre info!
# This game id (576720) has no genre info!
# This game id (578190) has no genre info!
# This game id (594490) has no genre info!
# This game id (596140) has no specs info!
# This game id (592360) has no genre info!
# This game id (536050) has no genre info!
# This game id (604890) has no genre info!
# This game id (604890) has no tag info!
# This game id (598690) has no genre info!
# This game id (598160) has no genre info!
# This game id (582710) has no genre info!
# This game id (582640) has no genre info!
# This game id (599630) has no genre info!
# This game id (598660) has no genre info!
# This game id (592410) has no genre info!
# This game id (605860) has no genre info!
# This game id (496740) has no genre info!
# This game id (599430) has no genre info!
# This game id (593240) has no genre info!
# This game id (586830) has no genre info!
# This game id (590530) has no genre info!
# This game id (606270) has no genre info!
# This game id (602660) has no genre info!
# This game id (607560) has no genre info!
# This game id (602920) has no specs info!
# This game id (608980) has no genre info!
# This game id (587860) has no genre info!
# This game id (602130) has no genre info!
# This game id (553050) has no genre info!
# This game id (600150) has no genre info!
# This game id (608190) has no genre info!
# This game id (577640) has no genre info!
# This game id (587060) has no genre info!
# This game id (606180) has no genre info!
# This game id (595470) has no genre info!
# This game id (594800) has no genre info!
# This game id (592350) has no specs info!
# This game id (567700) has no genre info!
# This game id (548820) has no genre info!
# This game id (548820) has no tag info!
# This game id (606820) has no genre info!
# This game id (494960) has no genre info!
# This game id (610470) has no genre info!
# This game id (610790) has no genre info!
# This game id (613380) has no genre info!
# This game id (612730) has no genre info!
# This game id (614390) has no genre info!
# This game id (614500) has no genre info!
# This game id (614510) has no genre info!
# This game id (585170) has no genre info!
# This game id (593460) has no genre info!
# This game id (572810) has no genre info!
# This game id (572810) has no specs info!
# This game id (615330) has no genre info!
# This game id (588410) has no genre info!
# This game id (593260) has no genre info!
# This game id (572820) has no genre info!
# This game id (572820) has no specs info!
# This game id (572830) has no genre info!
# This game id (572830) has no specs info!
# This game id (600830) has no genre info!
# This game id (600830) has no specs info!
# This game id (600820) has no genre info!
# This game id (600820) has no specs info!
# This game id (611050) has no genre info!
# This game id (615460) has no genre info!
# This game id (606920) has no genre info!
# This game id (508250) has no genre info!
# This game id (591610) has no genre info!
# This game id (447330) has no genre info!
# This game id (615120) has no genre info!
# This game id (607090) has no genre info!
# This game id (616410) has no genre info!
# This game id (597360) has no genre info!
# This game id (594860) has no genre info!
# This game id (594120) has no genre info!
# This game id (498370) has no genre info!
# This game id (503930) has no genre info!
# This game id (612220) has no genre info!
# This game id (607690) has no genre info!
# This game id (613850) has no genre info!
# This game id (597670) has no genre info!
# This game id (546670) has no genre info!
# This game id (582700) has no genre info!
# This game id (574010) has no genre info!
# This game id (618920) has no genre info!
# This game id (618590) has no genre info!
# This game id (620140) has no genre info!
# This game id (527110) has no genre info!
# This game id (618610) has no genre info!
# This game id (598860) has no specs info!
# This game id (607980) has no genre info!
# This game id (605730) has no genre info!
# This game id (549550) has no genre info!
# This game id (549550) has no specs info!
# This game id (549590) has no genre info!
# This game id (549590) has no specs info!
# This game id (549570) has no genre info!
# This game id (549570) has no specs info!
# This game id (621430) has no genre info!
# This game id (621430) has no specs info!
# This game id (622110) has no genre info!
# This game id (594870) has no genre info!
# This game id (621780) has no genre info!
# This game id (615650) has no genre info!
# This game id (592320) has no genre info!
# This game id (621140) has no genre info!
# This game id (624660) has no genre info!
# This game id (619600) has no genre info!
# This game id (616050) has no genre info!
# This game id (613960) has no genre info!
# This game id (582400) has no genre info!
# This game id (582400) has no tag info!
# This game id (582400) has no specs info!
# This game id (612840) has no genre info!
# This game id (546350) has no genre info!
# This game id (574890) has no genre info!
# This game id (590560) has no genre info!
# This game id (627680) has no genre info!
# This game id (582110) has no genre info!
# This game id (579110) has no genre info!
# This game id (608470) has no genre info!
# This game id (594890) has no genre info!
# This game id (613330) has no genre info!
# This game id (626500) has no genre info!
# This game id (509510) has no genre info!
# This game id (528260) has no genre info!
# This game id (624900) has no genre info!
# This game id (628960) has no genre info!
# This game id (624720) has no genre info!
# This game id (624700) has no genre info!
# This game id (624670) has no genre info!
# This game id (624730) has no genre info!
# This game id (624790) has no genre info!
# This game id (624810) has no genre info!
# This game id (625490) has no genre info!
# This game id (486670) has no specs info!
# This game id (608480) has no genre info!
# This game id (600350) has no genre info!
# This game id (523130) has no specs info!
# This game id (601890) has no specs info!
# This game id (633490) has no genre info!
# This game id (607760) has no genre info!
# This game id (628530) has no genre info!
# This game id (625180) has no genre info!
# This game id (612250) has no genre info!
# This game id (631130) has no specs info!
# This game id (408340) has no genre info!
# This game id (436230) has no genre info!
# This game id (509250) has no genre info!
# This game id (420130) has no specs info!
# This game id (637330) has no genre info!
# This game id (593250) has no genre info!
# This game id (569640) has no genre info!
# This game id (633940) has no genre info!
# This game id (623100) has no genre info!
# This game id (485680) has no genre info!
# This game id (611720) has no genre info!
# This game id (624610) has no genre info!
# This game id (620790) has no genre info!
# This game id (639870) has no genre info!
# This game id (639870) has no specs info!
# This game id (635110) has no genre info!
# This game id (635110) has no specs info!
# This game id (635130) has no genre info!
# This game id (635130) has no specs info!
# This game id (609010) has no genre info!
# This game id (538110) has no genre info!
# This game id (630350) has no genre info!
# This game id (639690) has no genre info!
# This game id (639690) has no specs info!
# This game id (623800) has no genre info!
# This game id (621420) has no genre info!
# This game id (433190) has no genre info!
# This game id (634250) has no genre info!
# This game id (638830) has no genre info!
# This game id (621390) has no genre info!
# This game id (616570) has no genre info!
# This game id (642930) has no genre info!
# ...
# This game id (411340) has no specs info!
# This game id (414850) has no genre info!
# This game id (414850) has no specs info!
# This game id (419250) has no genre info!
# This game id (419250) has no specs info!
# This game id (414830) has no genre info!
# This game id (414830) has no specs info!
# This game id (413970) has no genre info!
# This game id (413970) has no specs info!
# This game id (428810) has no genre info!
# This game id (422550) has no genre info!
# This game id (417540) has no specs info!
# This game id (413960) has no genre info!
# This game id (413960) has no specs info!
# This game id (425680) has no genre info!
# This game id (424100) has no genre info!
# This game id (422530) has no genre info!
# This game id (422630) has no genre info!
# This game id (310560) has no genre info!
# This game id (414130) has no genre info!
# This game id (413950) has no genre info!
# This game id (413950) has no specs info!
# This game id (423010) has no genre info!
# This game id (413940) has no genre info!
# This game id (413940) has no specs info!
# This game id (413930) has no genre info!
# This game id (413930) has no specs info!
# This game id (418600) has no genre info!
# This game id (418600) has no tag info!
# This game id (353420) has no genre info!
# This game id (353420) has no specs info!
# This game id (353390) has no genre info!
# This game id (353390) has no specs info!
# This game id (418090) has no genre info!
# This game id (418090) has no tag info!
# This game id (353370) has no genre info!
# This game id (353370) has no specs info!
# This game id (415760) has no genre info!
# This game id (386290) has no genre info!
# This game id (387690) has no genre info!
# This game id (387690) has no specs info!
# This game id (387680) has no genre info!
# This game id (387680) has no specs info!
# This game id (399010) has no genre info!
# This game id (414750) has no genre info!
# This game id (413720) has no genre info!
# This game id (413720) has no tag info!
# This game id (403270) has no genre info!
# This game id (413610) has no genre info!
# This game id (413610) has no specs info!
# This game id (413220) has no genre info!
# This game id (413220) has no specs info!
# This game id (403040) has no specs info!
# This game id (413230) has no genre info!
# This game id (413230) has no specs info!
# This game id (410660) has no genre info!
# This game id (405470) has no specs info!
# This game id (403810) has no genre info!
# This game id (403810) has no specs info!
# This game id (406260) has no genre info!
# This game id (406260) has no specs info!
# This game id (394250) has no genre info!
# This game id (406040) has no specs info!
# This game id (406840) has no specs info!
# This game id (323680) has no genre info!
# This game id (406060) has no specs info!
# This game id (406050) has no specs info!
# This game id (327880) has no genre info!
# This game id (341800) has no genre info!
# This game id (406030) has no specs info!
# This game id (402590) has no genre info!
# This game id (374690) has no specs info!
# This game id (394370) has no genre info!
# This game id (394370) has no tag info!
# This game id (398180) has no genre info!
# This game id (403990) has no genre info!
# This game id (403990) has no tag info!
# This game id (355860) has no genre info!
# This game id (394920) has no genre info!
# This game id (394920) has no specs info!
# This game id (394930) has no genre info!
# This game id (394930) has no specs info!
# This game id (394940) has no genre info!
# This game id (394940) has no specs info!
# This game id (311930) has no genre info!
# This game id (396030) has no genre info!
# This game id (253050) has no specs info!
# This game id (230290) has no genre info!
# This game id (394650) has no genre info!
# This game id (394650) has no tag info!
# This game id (393970) has no genre info!
# This game id (393970) has no specs info!
# This game id (387660) has no genre info!
# This game id (387660) has no specs info!
# This game id (387670) has no genre info!
# This game id (387670) has no specs info!
# This game id (389090) has no genre info!
# This game id (389090) has no specs info!
# This game id (387560) has no genre info!
# This game id (387560) has no specs info!
# This game id (387610) has no genre info!
# This game id (387610) has no specs info!
# This game id (387600) has no genre info!
# This game id (387600) has no specs info!
# This game id (387570) has no genre info!
# This game id (387570) has no specs info!
# This game id (387580) has no genre info!
# This game id (387580) has no specs info!
# This game id (334410) has no genre info!
# This game id (387810) has no specs info!
# This game id (388350) has no tag info!
# This game id (387520) has no genre info!
# This game id (387520) has no specs info!
# This game id (387530) has no genre info!
# This game id (387530) has no specs info!
# This game id (376990) has no specs info!
# This game id (387540) has no genre info!
# This game id (387540) has no specs info!
# This game id (387510) has no genre info!
# This game id (387510) has no specs info!
# This game id (382770) has no genre info!
# This game id (382770) has no specs info!
# This game id (387470) has no genre info!
# This game id (387470) has no specs info!
# This game id (387490) has no genre info!
# This game id (387490) has no specs info!
# This game id (387790) has no specs info!
# This game id (387780) has no specs info!
# This game id (387770) has no specs info!
# This game id (387800) has no specs info!
# This game id (373000) has no specs info!
# This game id (389990) has no genre info!
# This game id (389990) has no tag info!
# This game id (388280) has no specs info!
# This game id (383730) has no specs info!
# This game id (382720) has no genre info!
# This game id (382720) has no specs info!
# This game id (382780) has no genre info!
# This game id (382780) has no specs info!
# This game id (382710) has no genre info!
# This game id (382710) has no specs info!
# This game id (379650) has no genre info!
# This game id (379650) has no tag info!
# This game id (366810) has no genre info!
# This game id (367950) has no genre info!
# This game id (382680) has no genre info!
# This game id (382680) has no specs info!
# This game id (320540) has no genre info!
# This game id (382640) has no genre info!
# This game id (382640) has no specs info!
# This game id (382630) has no genre info!
# This game id (382630) has no specs info!
# This game id (371240) has no genre info!
# This game id (371240) has no specs info!
# This game id (367930) has no genre info!
# This game id (377040) has no specs info!
# This game id (377050) has no specs info!
# This game id (352360) has no genre info!
# This game id (375190) has no genre info!
# This game id (380890) has no genre info!
# This game id (380890) has no specs info!
# This game id (368670) has no specs info!
# This game id (372060) has no specs info!
# This game id (286160) has no genre info!
# This game id (368061) has no genre info!
# This game id (368061) has no tag info!
# This game id (374400) has no specs info!
# This game id (368060) has no genre info!
# This game id (368060) has no tag info!
# This game id (278190) has no specs info!
# This game id (355100) has no genre info!
# This game id (340860) has no genre info!
# This game id (370450) has no genre info!
# This game id (370450) has no tag info!
# This game id (371930) has no genre info!
# This game id (371930) has no tag info!
# This game id (366550) has no specs info!
# This game id (374570) has no genre info!
# This game id (374570) has no specs info!
# This game id (371230) has no genre info!
# This game id (371230) has no specs info!
# This game id (371270) has no genre info!
# This game id (371270) has no specs info!
# This game id (349280) has no specs info!
# This game id (357410) has no genre info!
# This game id (357410) has no specs info!
# This game id (368400) has no tag info!
# This game id (359522) has no genre info!
# This game id (359522) has no tag info!
# This game id (363550) has no specs info!
# This game id (363460) has no genre info!
# This game id (366530) has no specs info!
# This game id (357380) has no genre info!
# This game id (365170) has no genre info!
# This game id (357460) has no genre info!
# This game id (347890) has no genre info!
# This game id (347890) has no tag info!
# This game id (364240) has no specs info!
# This game id (363690) has no genre info!
# This game id (363690) has no tag info!
# This game id (361700) has no genre info!
# This game id (361700) has no specs info!
# This game id (359320) has no genre info!
# This game id (359410) has no genre info!
# This game id (357470) has no genre info!
# This game id (234630) has no genre info!
# This game id (354500) has no genre info!
# This game id (354500) has no specs info!
# This game id (351570) has no genre info!
# This game id (351570) has no specs info!
# This game id (341960) has no specs info!
# This game id (349210) has no genre info!
# This game id (349210) has no specs info!
# This game id (330070) has no specs info!
# This game id (315397) has no genre info!
# This game id (315397) has no tag info!
# This game id (315394) has no genre info!
# This game id (315394) has no tag info!
# This game id (347350) has no genre info!
# This game id (266410) has no genre info!
# This game id (339890) has no genre info!
# This game id (339890) has no tag info!
# This game id (338440) has no genre info!
# This game id (338440) has no tag info!
# This game id (338440) has no specs info!
# This game id (264710) has no genre info!
# This game id (321540) has no specs info!
# This game id (329190) has no genre info!
# This game id (327490) has no specs info!
# This game id (333500) has no genre info!
# This game id (333500) has no tag info!
# This game id (330511) has no tag info!
# This game id (332490) has no genre info!
# This game id (265146) has no genre info!
# This game id (265146) has no tag info!
# This game id (307960) has no genre info!
# This game id (314730) has no specs info!
# This game id (289025) has no genre info!
# This game id (289025) has no tag info!
# This game id (314720) has no specs info!
# This game id (325910) has no specs info!
# This game id (272300) has no specs info!
# This game id (313260) has no genre info!
# This game id (313260) has no tag info!
# This game id (301950) has no genre info!
# This game id (323620) has no specs info!
# This game id (301170) has no genre info!
# This game id (301170) has no tag info!
# This game id (315240) has no specs info!
# This game id (279280) has no specs info!
# This game id (279920) has no genre info!
# This game id (298720) has no genre info!
# This game id (298720) has no tag info!
# This game id (306510) has no genre info!
# This game id (306510) has no tag info!
# This game id (288290) has no genre info!
# This game id (304570) has no tag info!
# This game id (228180) has no specs info!
# This game id (297900) has no genre info!
# This game id (297900) has no tag info!
# This game id (245550) has no genre info!
# This game id (243890) has no specs info!
# This game id (264420) has no specs info!
# This game id (251810) has no genre info!
# This game id (259211) has no genre info!
# This game id (259211) has no tag info!
# This game id (241660) has no specs info!
# This game id (253030) has no genre info!
# This game id (215917) has no genre info!
# This game id (215917) has no tag info!
# This game id (215916) has no genre info!
# This game id (215916) has no tag info!
# This game id (215911) has no genre info!
# This game id (215911) has no tag info!
# This game id (215918) has no genre info!
# This game id (215918) has no tag info!
# This game id (215915) has no genre info!
# This game id (215915) has no tag info!
# This game id (250360) has no specs info!
# This game id (257650) has no specs info!
# This game id (257400) has no specs info!
# This game id (236890) has no specs info!
# This game id (243020) has no genre info!
# This game id (233680) has no specs info!
# This game id (238280) has no genre info!
# This game id (218620) has no genre info!
# This game id (227260) has no specs info!
# This game id (224380) has no specs info!
# This game id (218064) has no genre info!
# This game id (218064) has no tag info!
# This game id (227240) has no specs info!
# This game id (100400) has no specs info!
# This game id (220960) has no specs info!
# This game id (221001) has no genre info!
# This game id (24077) has no tag info!
# This game id (204731) has no genre info!
# This game id (204731) has no tag info!
# This game has no id info!
# {'publisher': 'Warner Bros. Interactive Entertainment, Feral Interactive (Mac)', 'genres': ['Action', 'Adventure'], 'app_name': 'Batman: Arkham City - Game of the Year Edition', 'sentiment': 'Overwhelmingly Positive', 'title': 'Batman: Arkham City - Game of the Year Edition', 'url': 'http://store.steampowered.com/app/200260', 'release_date': '2012-09-07', 'tags': ['Action', 'Open World', 'Batman', 'Adventure', 'Stealth', 'Third Person', 'Superhero', 'Singleplayer', "Beat 'em up", 'Comic Book', 'Detective', 'Fighting', 'Atmospheric', 'Story Rich', 'Action-Adventure', 'Cinematic', 'Controller', '3D Vision', 'Metroidvania', 'Sandbox'], 'metascore': 91, 'price': 19.99, 'early_access': False, 'specs': ['Single-player', 'Steam Achievements', 'Steam Trading Cards', 'Partial Controller Support', 'Steam Cloud'], 'developer': 'Rocksteady Studios,Feral Interactive (Mac)'}
# This game id (203733) has no genre info!
# This game id (203733) has no tag info!
# This game id (42695) has no genre info!
# This game id (42695) has no tag info!
# This game id (211202) has no genre info!
# This game id (211201) has no genre info!
# This game id (211200) has no genre info!
# This game id (50513) has no genre info!
# This game id (50513) has no tag info!
# This game id (208600) has no genre info!
# This game id (209362) has no genre info!
# This game id (209362) has no tag info!
# This game id (202290) has no genre info!
# This game id (200940) has no genre info!
# This game id (202530) has no genre info!
# This game id (202522) has no genre info!
# This game id (202522) has no tag info!
# This game id (34342) has no genre info!
# This game id (34342) has no tag info!
# This game id (65230) has no tag info!
# This game id (22630) has no genre info!
# This game id (22630) has no tag info!
# This game id (49409) has no specs info!
# This game id (104600) has no genre info!
# This game id (34348) has no genre info!
# This game id (34348) has no tag info!
# This game id (71250) has no genre info!
# This game id (35419) has no genre info!
# This game id (35419) has no tag info!
# This game id (65200) has no specs info!
# This game id (55020) has no genre info!
# This game id (34312) has no genre info!
# This game id (34283) has no genre info!
# This game id (34311) has no genre info!
# This game id (37290) has no tag info!
# This game id (37280) has no tag info!
# This game id (36270) has no genre info!
# This game id (36270) has no tag info!
# This game id (36150) has no specs info!
# This game id (34910) has no tag info!
# This game id (13630) has no specs info!
# This game id (11920) has no tag info!
# This game id (901660) has no genre info!
# This game id (406890) has no genre info!
# This game id (731120) has no genre info!
# This game id (767330) has no genre info!
# This game id (761880) has no genre info!
# This game id (751730) has no genre info!
# This game id (768110) has no genre info!
# This game id (759980) has no genre info!
# This game id (753960) has no genre info!
# This game id (775660) has no genre info!
# This game id (775660) has no specs info!
# This game id (750440) has no genre info!
# This game id (391480) has no genre info!
# This game id (736340) has no genre info!
# This game id (595630) has no genre info!
# This game id (752200) has no genre info!
# This game id (772420) has no genre info!
# This game id (579130) has no genre info!
# This game id (704470) has no genre info!
# This game id (745900) has no genre info!
# This game id (764110) has no genre info!
# This game id (705860) has no genre info!
# This game id (755540) has no genre info!
# This game id (755310) has no specs info!
# This game id (775640) has no genre info!
# This game id (775640) has no specs info!
# This game id (777930) has no genre info!
# This game id (777930) has no specs info!
# This game id (775370) has no genre info!
# This game id (777950) has no genre info!
# This game id (777950) has no specs info!
# This game id (681550) has no genre info!

# %%
# collect the genre, tags, specs info of each game in each bundle
bundle_games_genres = {}

for d in readGz(os.path.join(dataset_folder_path,"bundle_data.json.gz")):

    if "bundle_id" not in d.keys() or "items" not in d.keys():
        print(f"This bundle data is missing id or items info!")
        print(d)
        continue

    games_ids = [g["item_id"] for g in d["items"]]

    bundle_games_genres[d["bundle_id"]] = {'genres': [], 'tags': [], 'specs': []}
    for item in games_ids:
        if item in steam_games_genres.keys():
            bundle_games_genres[d["bundle_id"]]['genres'].extend(steam_games_genres[item]['genres'])
            bundle_games_genres[d["bundle_id"]]['tags'].extend(steam_games_genres[item]['tags'])
            bundle_games_genres[d["bundle_id"]]['specs'].extend(steam_games_genres[item]['specs'])

    bundle_games_genres[d["bundle_id"]]['genres'] = list(set(bundle_games_genres[d["bundle_id"]]['genres']))
    bundle_games_genres[d["bundle_id"]]['tags'] = list(set(bundle_games_genres[d["bundle_id"]]['tags']))
    bundle_games_genres[d["bundle_id"]]['specs'] = list(set(bundle_games_genres[d["bundle_id"]]['specs']))

# %%
bundle_games_genres
# Out:
# {'450': {'genres': ['Indie', 'Adventure', 'Casual', 'Action'],
#   'tags': ['Nudity',
#    'Dating Sim',
#    'Romance',
#    'Anime',
#    'Casual',
#    'Action',
#    "Shoot 'Em Up",
#    'Indie',
#    'Sexual Content',
#    'Adventure',
#    'Episodic',
#    'Singleplayer',
#    'Mature',
#    'Visual Novel'],
#   'specs': ['Downloadable Content',
#    'Steam Cloud',
#    'Steam Trading Cards',
#    'Single-player',
#    'Steam Achievements']},
#  '1473': {'genres': [], 'tags': [], 'specs': []},
#  '1474': {'genres': [], 'tags': [], 'specs': []},
#  '1437': {'genres': ['Sports',
#    'Casual',
#    'Indie',
#    'Free to Play',
#    'Strategy',
#    'Simulation'],
#   'tags': ['Sports',
#    'Casual',
#    'Indie',
#    'Free to Play',
#    'Strategy',
#    'Simulation'],
#   'specs': ['Downloadable Content',
#    'Steam Leaderboards',
#    'Steam Cloud',
#    'Steam Trading Cards',
#    'Full controller support',
#    'In-App Purchases',
#    'Single-player',
#    'Stats',
#    'Steam Achievements']},
#  '1466': {'genres': [], 'tags': [], 'specs': []},
#  '1478': {'genres': ['Simulation', 'Casual'],
#   'tags': ['Casual', 'Hidden Object', 'Management', 'Puzzle', 'Simulation'],
#   'specs': ['Single-player']},
#  '1482': {'genres': ['Casual', 'Action', 'Indie', 'Adventure', 'Strategy'],
#   'tags': ['Time Attack',
#    'Casual',
#    'Singleplayer',
#    'Action',
#    'Isometric',
#    'Funny',
#    'Puzzle-Platformer',
#    'Colorful',
#    'Open World',
#    'Metroidvania',
#    'Difficult',
#    'Family Friendly',
#    'Abstract',
#    'Level Editor',
#    'Great Soundtrack',
#    'Retro',
#    'Indie',
#    '2D',
#    'Adventure',
#    'Platformer',
#    'Strategy',
#    'Controller',
#    'Puzzle',
#    'Cute'],
#   'specs': ['Steam Leaderboards',
#    'Partial Controller Support',
#    'Includes level editor',
#    'Steam Cloud',
#    'Steam Trading Cards',
#    'Full controller support',
#    'Steam Workshop',
#    'Single-player',
#    'Steam Achievements']},
#  '1396': {'genres': [],
#   'tags': ['Fighting',
#    'Action',
#    'Movie',
#    'Action-Adventure',
#    'War',
#    'Adventure',
#    'Martial Arts',
#    'Thriller'],
#   'specs': ['Captions available']},
#  '1400': {'genres': [], 'tags': [], 'specs': []},
#  '1471': {'genres': ['Simulation'],
#   'tags': ['Simulation', 'Driving'],
#   'specs': ['Single-player']},
#  '1472': {'genres': [], 'tags': [], 'specs': []},
#  '1477': {'genres': ['Indie', 'Simulation', 'RPG', 'Strategy'],
#   'tags': ['Rogue-like',
#    'Tactical RPG',
#    'Turn-Based',
#    'Indie',
#    'Turn-Based Combat',
#    '2D',
#    'Turn-Based Strategy',
#    'Pixel Graphics',
#    'RPG',
#    'Strategy',
#    'Base Building',
#    'Simulation',
#    'Singleplayer',
#    'Strategy RPG',
#    'Space'],
#   'specs': ['Downloadable Content',
#    'Steam Cloud',
#    'Steam Trading Cards',
#    'Steam Workshop',
#    'Single-player',
#    'Steam Achievements']},
#  '1284': {'genres': ['Indie', 'Casual'],
#   'tags': ['Indie', 'Casual'],
#   'specs': ['Partial Controller Support',
#    'Steam Trading Cards',
#    'Single-player',
#    'Downloadable Content']},
#  '1468': {'genres': ['Racing',
#    'Sports',
#    'Action',
#    'Adventure',
#    'RPG',
#    'Strategy',
#    'Simulation'],
#   'tags': ['Third-Person Shooter',
#    'Touch-Friendly',
#    'Villain Protagonist',
#    'Casual',
#    '4 Player Local',
#    'Management',
#    'Free to Play',
#    'Magic',
#    'First-Person',
#    'Story Rich',
#    'Stealth',
#    'Singleplayer',
#    'Racing',
#    'Dark Humor',
#    'Local Co-Op',
#    'Military',
#    'Local Multiplayer',
#    'Action',
#    'Action RPG',
#    'Action-Adventure',
#    'Mythology',
#    'TrackIR',
#    'Atmospheric',
#    'RPG',
#    'Hack and Slash',
#    'Simulation',
#    'Co-op',
#    '3D Vision',
#    'FPS',
#    'Dark Fantasy',
#    'Top-Down',
#    'Funny',
#    'Sports',
#    'Offroad',
#    'Tactical',
#    'Shooter',
#    'Open World',
#    'Steampunk',
#    'Driving',
#    'Difficult',
#    'VR',
#    'Fantasy',
#    'Comedy',
#    'Family Friendly',
#    'Multiplayer',
#    'Realistic',
#    'Great Soundtrack',
#    'Arcade',
#    'Fast-Paced',
#    'War',
#    'Adventure',
#    'Third Person',
#    'RTS',
#    'Split Screen',
#    'Strategy',
#    'Controller',
#    'Puzzle',
#    'Walking Simulator'],
#   'specs': ['Shared/Split Screen',
#    'Downloadable Content',
#    'Multi-player',
#    'Steam Leaderboards',
#    'Partial Controller Support',
#    'Gamepad',
#    'Single-player',
#    'Steam Cloud',
#    'Steam Trading Cards',
#    'Full controller support',
#    'Oculus Rift',
#    'Valve Anti-Cheat enabled',
#    'Steam Workshop',
#    'Cross-Platform Multiplayer',
#    'Co-op',
#    'Seated',
#    'Keyboard / Mouse',
#    'Steam Achievements']},
#  '1225': {'genres': ['Indie', 'Free to Play', 'Action'],
#   'tags': ['Free to Play',
#    'Competitive',
#    'First-Person',
#    'Singleplayer',
#    'Gun Customization',
#    'Zombies',
#    'Military',
#    'Action',
#    'Co-op',
#    'FPS',
#    'Character Customization',
#    'Shooter',
#    'Open World',
#    'Multiplayer',
#    'Survival',
#    'War',
#    'Indie',
#    'Adventure',
#    'Strategy',
#    'Controller'],
#   'specs': ['Downloadable Content',
#    'Multi-player',
#    'Valve Anti-Cheat enabled',
#    'Online Multi-Player',
#    'In-App Purchases',
#    'Stats',
#    'Steam Achievements']},
#  '1455': {'genres': ['Indie', 'Action'],
#   'tags': ['Twin Stick Shooter',
#    'Casual',
#    'Singleplayer',
#    'Bullet Hell',
#    'Cyberpunk',
#    'Action',
#    'Isometric',
#    'Top-Down',
#    'Sci-fi',
#    'Difficult',
#    'Procedural Generation',
#    'Great Soundtrack',
#    'Arcade',
#    'Anime',
#    'Fast-Paced',
#    'Retro',
#    'Indie',
#    'Pixel Graphics',
#    'Female Protagonist'],
#   'specs': ['Downloadable Content',
#    'Steam Trading Cards',
#    'Full controller support',
#    'Single-player',
#    'Steam Achievements']},
#  '1419': {'genres': [], 'tags': [], 'specs': []},
#  '1421': {'genres': [], 'tags': [], 'specs': []},
#  '1433': {'genres': [], 'tags': [], 'specs': []},
#  '1420': {'genres': [], 'tags': [], 'specs': []},
#  '1011': {'genres': ['Indie', 'Adventure', 'Action', 'Simulation'],
#   'tags': ['FPS',
#    'Dinosaurs',
#    'Zombies',
#    'Memes',
#    'Shooter',
#    'Open World',
#    'Action',
#    'Hunting',
#    'Gore',
#    'Indie',
#    'Horror',
#    'Adventure',
#    'Simulation',
#    'First-Person',
#    'Multiplayer',
#    'Survival'],
#   'specs': ['Downloadable Content',
#    'Multi-player',
#    'Steam Leaderboards',
#    'Single-player',
#    'Steam Trading Cards',
#    'Full controller support',
#    'Co-op',
#    'Stats',
#    'Steam Achievements']},
#  '419': {'genres': ['Indie', 'Adventure', 'Action', 'Simulation'],
#   'tags': ['FPS',
#    'Dinosaurs',
#    'Zombies',
#    'Memes',
#    'Shooter',
#    'Open World',
#    'Action',
#    'Hunting',
#    'Gore',
#    'Indie',
#    'Horror',
#    'Adventure',
#    'Simulation',
#    'First-Person',
#    'Multiplayer',
#    'Survival'],
#   'specs': ['Downloadable Content',
#    'Multi-player',
#    'Steam Leaderboards',
#    'Single-player',
#    'Steam Trading Cards',
#    'Full controller support',
#    'Co-op',
#    'Steam Achievements']},
#  '1460': {'genres': ['Indie', 'Action', 'Strategy'],
#   'tags': ['Action',
#    'Sci-fi',
#    'Indie',
#    'RTS',
#    'Strategy',
#    'Multiplayer',
#    'Singleplayer'],
#   'specs': ['Downloadable Content',
#    'Includes level editor',
#    'Steam Cloud',
#    'Steam Trading Cards',
#    'Steam Workshop',
#    'Single-player',
#    'Steam Achievements']},
#  '317': {'genres': ['Indie', 'Adventure', 'Casual'],
#   'tags': ['Rogue-like', 'Casual', 'Indie', 'Adventure', 'Platformer'],
#   'specs': ['Shared/Split Screen',
#    'Downloadable Content',
#    'Steam Leaderboards',
#    'Partial Controller Support',
#    'Steam Trading Cards',
#    'Single-player']},
#  '1379': {'genres': ['Adventure'],
#   'tags': ['Crime',
#    'Memes',
#    'Villain Protagonist',
#    'Casual',
#    'Short',
#    'Dystopian',
#    'Sexual Content',
#    'Conspiracy',
#    'Typing',
#    'Sci-fi',
#    'Comedy',
#    'Post-apocalyptic',
#    'Survival Horror',
#    'Anime',
#    'Gore',
#    'Indie',
#    'Horror',
#    'Adventure',
#    'Female Protagonist',
#    'Quick-Time Events',
#    'Walking Simulator'],
#   'specs': ['Steam Trading Cards',
#    'Single-player',
#    'Captions available',
#    'Downloadable Content']},
#  '1385': {'genres': ['Indie', 'Simulation', 'Casual', 'Strategy'],
#   'tags': ['Resource Management',
#    'Casual',
#    'Politics',
#    'Management',
#    'Competitive',
#    'Real-Time with Pause',
#    'Singleplayer',
#    'Board Game',
#    'Action',
#    'Stylized',
#    'Card Game',
#    'Atmospheric',
#    'Relaxing',
#    'Simulation',
#    'Historical',
#    'Funny',
#    'Sandbox',
#    'Steampunk',
#    'City Builder',
#    'Fantasy',
#    'Family Friendly',
#    'Soundtrack',
#    'Multiplayer',
#    'Comedy',
#    'Turn-Based Strategy',
#    'Economy',
#    'Great Soundtrack',
#    'Trains',
#    'Building',
#    'Turn-Based',
#    'Indie',
#    '2D',
#    'Strategy',
#    'Puzzle',
#    'Replay Value'],
#   'specs': ['Online Co-op',
#    'Multi-player',
#    'Steam Workshop',
#    'Steam Cloud',
#    'Co-op',
#    'Steam Trading Cards',
#    'Online Multi-Player',
#    'Cross-Platform Multiplayer',
#    'Single-player',
#    'Steam Achievements']},
#  '1137': {'genres': ['Racing',
#    'Sports',
#    'Casual',
#    'Action',
#    'Adventure',
#    'Simulation'],
#   'tags': ['Racing',
#    'Sports',
#    'On-Rails Shooter',
#    'Arcade',
#    'Online Co-Op',
#    'Casual',
#    'Action',
#    'VR',
#    'Retro',
#    'Indie',
#    'Basketball',
#    'Adventure',
#    'Multiplayer',
#    'Simulation',
#    'Co-op',
#    '1980s'],
#   'specs': ['Online Co-op',
#    'Downloadable Content',
#    'Multi-player',
#    'Gamepad',
#    'Tracked Motion Controllers',
#    'Single-player',
#    'Oculus Rift',
#    'Full controller support',
#    'HTC Vive',
#    'Online Multi-Player',
#    'Room-Scale',
#    'Co-op',
#    'Seated',
#    'Keyboard / Mouse',
#    'Standing',
#    'Steam Achievements']},
#  '279': {'genres': ['Casual', 'Action', 'Indie', 'Adventure', 'Strategy'],
#   'tags': ['Casual',
#    'First-Person',
#    'Singleplayer',
#    'Zombies',
#    'Action',
#    'Co-op',
#    'FPS',
#    'Tower Defense',
#    'Shooter',
#    'Difficult',
#    'Multiplayer',
#    'Great Soundtrack',
#    'Voxel',
#    'Horror',
#    'Indie',
#    'Adventure',
#    'Pixel Graphics',
#    'Strategy',
#    'Werewolves'],
#   'specs': ['Downloadable Content',
#    'Multi-player',
#    'Single-player',
#    'Steam Trading Cards',
#    'Cross-Platform Multiplayer',
#    'Co-op',
#    'Steam Achievements']},
#  '1440': {'genres': ['Racing',
#    'Casual',
#    'Action',
#    'Indie',
#    'Adventure',
#    'Strategy'],
#   'tags': ['Casual',
#    'Hidden Object',
#    'Classic',
#    'Singleplayer',
#    'Minimalist',
#    'Racing',
#    'Action',
#    'Stylized',
#    'Action-Adventure',
#    'Atmospheric',
#    'Funny',
#    'Puzzle-Platformer',
#    'Character Customization',
#    'Fantasy',
#    'Multiplayer',
#    'Runner',
#    'Great Soundtrack',
#    'Arcade',
#    'Anime',
#    'Retro',
#    'Indie',
#    '2D',
#    'Adventure',
#    'Platformer',
#    'Strategy',
#    'Puzzle',
#    'Choose Your Own Adventure'],
#   'specs': ['Steam Leaderboards',
#    'Multi-player',
#    'Steam Cloud',
#    'Co-op',
#    'Steam Turn Notifications',
#    'Steam Trading Cards',
#    'Full controller support',
#    'Online Multi-Player',
#    'Cross-Platform Multiplayer',
#    'Single-player',
#    'Steam Achievements']},
#  '1441': {'genres': ['Casual',
#    'Action',
#    'Indie',
#    'Adventure',
#    'Strategy',
#    'Simulation'],
#   'tags': ['Casual',
#    'Hidden Object',
#    'Classic',
#    'Singleplayer',
#    'Minimalist',
#    'Space',
#    "Shoot 'Em Up",
#    'Action',
#    'Stylized',
#    'Action-Adventure',
#    'Atmospheric',
#    'Exploration',
#    'Simulation',
#    'Funny',
#    'Puzzle-Platformer',
#    'Sci-fi',
#    'Fantasy',
#    'Post-apocalyptic',
#    'Runner',
#    'Futuristic',
#    'Survival',
#    'Great Soundtrack',
#    'Experimental',
#    'Arcade',
#    'Anime',
#    'Retro',
#    'Indie',
#    '2D',
#    'Adventure',
#    'War',
#    'Platformer',
#    'Strategy',
#    'Puzzle',
#    'Choose Your Own Adventure'],
#   'specs': ['Steam Leaderboards',
#    'Partial Controller Support',
#    'Steam Cloud',
#    'Steam Trading Cards',
#    'Full controller support',
#    'Local Co-op',
#    'Single-player',
#    'Steam Achievements']},
#  '658': {'genres': [], 'tags': [], 'specs': []},
#  '355': {'genres': ['Racing', 'Simulation', 'Sports'],
#   'tags': ['Racing',
#    'Sports',
#    'Offroad',
#    'Open World',
#    'Action',
#    'Third Person',
#    'Simulation',
#    'Multiplayer',
#    'Singleplayer',
#    'Moddable'],
#   'specs': ['Downloadable Content',
#    'Multi-player',
#    'Steam Leaderboards',
#    'Partial Controller Support',
#    'Includes level editor',
#    'Steam Cloud',
#    'Single-player',
#    'Steam Achievements']},
#  '1401': {'genres': ['Adventure', 'Action'],
#   'tags': ['Memes',
#    'Demons',
#    'First-Person',
#    'Singleplayer',
#    'Action',
#    'Hack and Slash',
#    'Co-op',
#    'Parkour',
#    'FPS',
#    'Funny',
#    'Loot',
#    'Shooter',
#    'Open World',
#    'Sci-fi',
#    'Comedy',
#    'Multiplayer',
#    'Swordplay',
#    'Gore',
#    'Adventure',
#    'Ninja'],
#   'specs': ['Online Co-op',
#    'Downloadable Content',
#    'Single-player',
#    'Steam Cloud',
#    'Steam Trading Cards',
#    'Full controller support',
#    'Steam Workshop',
#    'Co-op',
#    'Steam Achievements']},
#  '1418': {'genres': ['Casual', 'Action', 'Strategy'],
#   'tags': ['Touch-Friendly',
#    'Point & Click',
#    'Casual',
#    'Hidden Object',
#    'Classic',
#    'Singleplayer',
#    'Aliens',
#    'Zombies',
#    'Underwater',
#    'Match 3',
#    'Action',
#    'Relaxing',
#    'Simulation',
#    'Funny',
#    'Tactical',
#    'Tower Defense',
#    'Typing',
#    'Colorful',
#    'Physics',
#    'Education',
#    'Comedy',
#    'Multiplayer',
#    'Family Friendly',
#    'Post-apocalyptic',
#    'Survival',
#    'Great Soundtrack',
#    'Arcade',
#    'Anime',
#    '2D',
#    'Indie',
#    'Adventure',
#    'Clicker',
#    'Strategy',
#    'Puzzle',
#    'Cute'],
#   'specs': ['Single-player', 'Stats', 'Steam Achievements']},
#  '1282': {'genres': ['Indie', 'Casual', 'Action'],
#   'tags': ['Fighting',
#    'Casual',
#    'Action',
#    'Anime',
#    'Dark',
#    'Indie',
#    'Sexual Content'],
#   'specs': ['Shared/Split Screen',
#    'Downloadable Content',
#    'Partial Controller Support',
#    'Local Multi-Player',
#    'Steam Trading Cards',
#    'Captions available',
#    'Steam Workshop',
#    'Single-player']},
#  '1399': {'genres': ['Adventure', 'Action'],
#   'tags': ['Memes',
#    'Singleplayer',
#    'Classic',
#    'Zombies',
#    'Nudity',
#    'Action',
#    'Atmospheric',
#    'RPG',
#    'Co-op',
#    'Multiple Endings',
#    'Funny',
#    'Sandbox',
#    'Online Co-Op',
#    'Character Customization',
#    'Open World',
#    'Difficult',
#    'Comedy',
#    'Multiplayer',
#    'Survival',
#    'Great Soundtrack',
#    'Survival Horror',
#    'Crafting',
#    'Gore',
#    'Horror',
#    'Adventure',
#    'Third Person',
#    '3D Vision'],
#   'specs': ['Multi-player',
#    'Steam Leaderboards',
#    'Partial Controller Support',
#    'Single-player',
#    'Steam Cloud',
#    'Steam Trading Cards',
#    'Full controller support',
#    'Co-op',
#    'Steam Achievements']},
#  '1392': {'genres': ['Indie', 'Action', 'RPG'],
#   'tags': ['Funny',
#    'Great Soundtrack',
#    'Party-Based RPG',
#    'Experimental',
#    'Local Multiplayer',
#    'Rhythm',
#    'Action',
#    'Fast-Paced',
#    'Indie',
#    'Music',
#    'Fantasy',
#    '2D',
#    'Co-op',
#    'RPG',
#    'Comedy',
#    'Singleplayer'],
#   'specs': ['Shared/Split Screen',
#    'Downloadable Content',
#    'Steam Leaderboards',
#    'Partial Controller Support',
#    'Includes level editor',
#    'Local Multi-Player',
#    'Steam Cloud',
#    'Steam Trading Cards',
#    'Full controller support',
#    'Local Co-op',
#    'Single-player',
#    'Steam Achievements']},
#  '1404': {'genres': ['Indie', 'Casual', 'Action', 'Strategy'],
#   'tags': ['Fighting',
#    'Casual',
#    'Action',
#    'Card Game',
#    'Indie',
#    'Strategy',
#    'Comedy',
#    'Multiplayer'],
#   'specs': ['Downloadable Content',
#    'Multi-player',
#    'Steam Trading Cards',
#    'Online Multi-Player',
#    'In-App Purchases',
#    'Single-player',
#    'Steam Achievements']},
#  '1406': {'genres': ['Indie', 'Casual', 'Action', 'Strategy'],
#   'tags': ['Indie', 'Casual', 'Action', 'Strategy'],
#   'specs': ['Steam Achievements',
#    'Single-player',
#    'Multi-player',
#    'Downloadable Content']},
#  '1407': {'genres': [], 'tags': [], 'specs': []},
#  '1403': {'genres': [],
#   'tags': ['Great Soundtrack',
#    'Local Co-Op',
#    'Psychedelic',
#    'Difficult',
#    'Hardware',
#    'Atmospheric',
#    'Steam Machine',
#    'Puzzle',
#    'Simulation',
#    'Mod'],
#   'specs': []},
#  '1293': {'genres': ['Action'],
#   'tags': ['Arcade', 'Bullet Hell', "Shoot 'Em Up", 'Action'],
#   'specs': ['Shared/Split Screen',
#    'Downloadable Content',
#    'Steam Leaderboards',
#    'Local Multi-Player',
#    'Steam Cloud',
#    'Steam Trading Cards',
#    'Full controller support',
#    'Local Co-op',
#    'Single-player',
#    'Steam Achievements']},
#  '1248': {'genres': ['Action'],
#   'tags': ['Arcade', "Shoot 'Em Up", 'Action'],
#   'specs': ['Downloadable Content',
#    'Steam Leaderboards',
#    'Local Multi-Player',
#    'Steam Cloud',
#    'Full controller support',
#    'Local Co-op',
#    'Single-player',
#    'Steam Achievements']},
#  '1409': {'genres': [], 'tags': [], 'specs': []},
#  '1410': {'genres': [], 'tags': [], 'specs': []},
#  '1382': {'genres': ['Indie', 'Action'],
#   'tags': ['Great Soundtrack',
#    "Shoot 'Em Up",
#    'Action',
#    'Difficult',
#    'Indie',
#    '2D',
#    'Pixel Graphics',
#    'Platformer'],
#   'specs': ['Downloadable Content',
#    'Steam Cloud',
#    'Steam Trading Cards',
#    'Full controller support',
#    'Single-player',
#    'Steam Achievements']},
#  '1386': {'genres': ['Indie', 'Action'],
#   'tags': ['Great Soundtrack',
#    'Action',
#    'Sci-fi',
#    'Indie',
#    'Side Scroller',
#    'Platformer',
#    'Family Friendly',
#    'Space'],
#   'specs': ['Downloadable Content',
#    'Steam Trading Cards',
#    'Full controller support',
#    'Single-player',
#    'Steam Achievements']},
#  '1356': {'genres': ['Racing', 'Action', 'RPG', 'Strategy'],
#   'tags': ['Classic',
#    'Racing',
#    'Tactical',
#    'Arcade',
#    'Open World',
#    'Action',
#    'Driving',
#    'Turn-Based',
#    'Indie',
#    'Adventure',
#    'Atmospheric',
#    'RPG',
#    'Strategy',
#    'Cult Classic',
#    'Post-apocalyptic',
#    'Multiplayer',
#    'Singleplayer',
#    'Survival'],
#   'specs': ['Steam Trading Cards',
#    'Single-player',
#    'Full controller support',
#    'Multi-player']},
#  '1332': {'genres': ['Indie', 'Adventure', 'Casual'],
#   'tags': ['Point & Click',
#    'Casual',
#    'Indie',
#    'Horror',
#    'Adventure',
#    'Hidden Object',
#    'Singleplayer'],
#   'specs': ['Steam Trading Cards', 'Single-player', 'Steam Achievements']},
#  '667': {'genres': ['Indie', 'Adventure', 'Casual'],
#   'tags': ['Nudity',
#    'Memes',
#    'Point & Click',
#    'Dating Sim',
#    'Casual',
#    'Anime',
#    'Indie',
#    'Adventure',
#    'Female Protagonist',
#    'Visual Novel'],
#   'specs': ['Steam Trading Cards', 'Single-player', 'Downloadable Content']},
#  '1390': {'genres': ['Indie', 'Adventure', 'Casual', 'Action'],
#   'tags': ['Casual',
#    'Story Rich',
#    'Classic',
#    'Bullet Hell',
#    'Psychological Horror',
#    'Nudity',
#    'Mystery',
#    "Shoot 'Em Up",
#    'Action',
#    'Dark',
#    'Atmospheric',
#    'Lore-Rich',
#    'Surreal',
#    'Psychological',
#    'Philisophical',
#    'Detective',
#    'Great Soundtrack',
#    'Anime',
#    'Gore',
#    'Horror',
#    'Indie',
#    'Adventure',
#    'Female Protagonist',
#    'Visual Novel'],
#   'specs': ['Steam Leaderboards',
#    'Partial Controller Support',
#    'Steam Cloud',
#    'Steam Trading Cards',
#    'Full controller support',
#    'Single-player',
#    'Steam Achievements']},
#  '1349': {'genres': ['Indie', 'Action', 'RPG'],
#   'tags': ['Twin Stick Shooter',
#    'Bullet Hell',
#    'Cyberpunk',
#    'Local Co-Op',
#    'Rogue-like',
#    'Rogue-lite',
#    'Action',
#    'RPG',
#    'Co-op',
#    'Top-Down',
#    'Difficult',
#    'Sci-fi',
#    'Futuristic',
#    'Co-op Campaign',
#    'Great Soundtrack',
#    'Perma Death',
#    'Robots',
#    'Indie',
#    '2D',
#    'Pixel Graphics'],
#   'specs': ['Shared/Split Screen',
#    'Downloadable Content',
#    'Steam Leaderboards',
#    'Steam Cloud',
#    'Commentary available',
#    'Steam Trading Cards',
#    'Full controller support',
#    'Local Co-op',
#    'Single-player',
#    'Steam Achievements']},
#  '1373': {'genres': ['Indie', 'Adventure'],
#   'tags': ['Great Soundtrack',
#    'Puzzle-Platformer',
#    'Colorful',
#    'Metroidvania',
#    'Indie',
#    '2D',
#    'Adventure',
#    'Platformer',
#    'Narration',
#    'Puzzle'],
#   'specs': ['Downloadable Content',
#    'Steam Cloud',
#    'Full controller support',
#    'Single-player',
#    'Steam Achievements']},
#  '1295': {'genres': ['Indie', 'Casual', 'Strategy'],
#   'tags': ['Casual', 'VR', 'Indie', 'Strategy', 'Puzzle'],
#   'specs': ['Downloadable Content',
#    'Gamepad',
#    'Partial Controller Support',
#    'Tracked Motion Controllers',
#    'Steam Cloud',
#    'Steam Trading Cards',
#    'HTC Vive',
#    'Room-Scale',
#    'Single-player',
#    'Keyboard / Mouse',
#    'Steam Achievements']},
#  '1387': {'genres': ['Indie', 'Casual'],
#   'tags': ['Indie', 'Bullet Hell', 'Casual'],
#   'specs': ['Steam Leaderboards',
#    'Partial Controller Support',
#    'Steam Trading Cards',
#    'Single-player',
#    'Steam Achievements']},
#  '1222': {'genres': ['Action',
#    'Indie',
#    'Adventure',
#    'Simulation',
#    'Massively Multiplayer'],
#   'tags': ['Zombies',
#    'FPS',
#    'Building',
#    'Shooter',
#    'Action',
#    'Indie',
#    'Horror',
#    'Adventure',
#    'Multiplayer',
#    'Simulation',
#    'Massively Multiplayer'],
#   'specs': ['Online Co-op',
#    'Multi-player',
#    'Partial Controller Support',
#    'Includes level editor',
#    'Single-player',
#    'MMO',
#    'Steam Trading Cards',
#    'Online Multi-Player',
#    'In-App Purchases',
#    'Co-op']},
#  '803': {'genres': ['Sports', 'Action', 'Indie', 'Adventure', 'Strategy'],
#   'tags': ['Casual',
#    'First-Person',
#    'Music',
#    'Story Rich',
#    'Singleplayer',
#    'Classic',
#    'Short',
#    'Space',
#    "Shoot 'Em Up",
#    'Action',
#    'Hand-drawn',
#    'Dragons',
#    'Atmospheric',
#    'Exploration',
#    'FPS',
#    'Funny',
#    'Sports',
#    'Sandbox',
#    'Puzzle-Platformer',
#    'Physics',
#    'Open World',
#    'Shooter',
#    'Metroidvania',
#    'Difficult',
#    'Sci-fi',
#    'Fantasy',
#    'Family Friendly',
#    'Comedy',
#    'Survival',
#    'Level Editor',
#    'Great Soundtrack',
#    'Arcade',
#    'Anime',
#    'Turn-Based',
#    'Retro',
#    'Indie',
#    '2D',
#    'Adventure',
#    'Gore',
#    'Pixel Graphics',
#    'Third Person',
#    'Platformer',
#    'Strategy',
#    'Female Protagonist',
#    'Puzzle',
#    'Horror'],
#   'specs': ['Partial Controller Support',
#    'Includes level editor',
#    'Steam Cloud',
#    'Commentary available',
#    'Co-op',
#    'Steam Trading Cards',
#    'Full controller support',
#    'Steam Workshop',
#    'Single-player',
#    'Stats',
#    'Steam Achievements']},
#  '498': {'genres': ['Indie', 'Adventure', 'Casual', 'Action'],
#   'tags': ['Top-Down',
#    'Puzzle-Platformer',
#    'Casual',
#    'Action',
#    "Shoot 'Em Up",
#    'Retro',
#    'Indie',
#    'Adventure',
#    'Pixel Graphics',
#    'Platformer'],
#   'specs': ['Partial Controller Support',
#    'Steam Trading Cards',
#    'Single-player']},
#  '396': {'genres': ['Indie', 'Adventure', 'Action'],
#   'tags': ['Casual',
#    'Singleplayer',
#    'Space',
#    'Short',
#    "Shoot 'Em Up",
#    'Action',
#    'Hand-drawn',
#    'Dragons',
#    'Funny',
#    'Puzzle-Platformer',
#    'Shooter',
#    'Metroidvania',
#    'Sci-fi',
#    'Difficult',
#    'Fantasy',
#    'Comedy',
#    'Family Friendly',
#    'Great Soundtrack',
#    'Arcade',
#    'Anime',
#    'Retro',
#    'Indie',
#    '2D',
#    'Adventure',
#    'Pixel Graphics',
#    'Platformer',
#    'Puzzle'],
#   'specs': ['Steam Cloud',
#    'Steam Trading Cards',
#    'Full controller support',
#    'Single-player',
#    'Stats',
#    'Steam Achievements']},
#  '1372': {'genres': ['Indie', 'Action'],
#   'tags': ['Time Attack',
#    'Great Soundtrack',
#    'Puzzle-Platformer',
#    'Action',
#    'Difficult',
#    'Indie',
#    '2D',
#    'Platformer'],
#   'specs': ['Downloadable Content',
#    'Steam Leaderboards',
#    'Steam Cloud',
#    'Steam Trading Cards',
#    'Single-player',
#    'Steam Achievements']},
#  '972': {'genres': ['Indie', 'Action', 'Strategy'],
#   'tags': ['Funny',
#    'Action',
#    'Fast-Paced',
#    'Indie',
#    'RTS',
#    'Pixel Graphics',
#    'Strategy',
#    'Comedy'],
#   'specs': ['Downloadable Content',
#    'Multi-player',
#    'Steam Leaderboards',
#    'Local Multi-Player',
#    'Steam Cloud',
#    'Steam Trading Cards',
#    'Full controller support',
#    'Online Multi-Player',
#    'Cross-Platform Multiplayer',
#    'Single-player',
#    'Steam Achievements']},
#  '1378': {'genres': ['Indie', 'Casual', 'Action', 'Strategy'],
#   'tags': ['Indie', 'Casual', 'Action', 'Strategy'],
#   'specs': ['Steam Trading Cards', 'Single-player', 'Steam Achievements']},
#  '1367': {'genres': [], 'tags': [], 'specs': []},
#  '1369': {'genres': [], 'tags': [], 'specs': []},
#  '1371': {'genres': [], 'tags': [], 'specs': []},
#  '1376': {'genres': [],
#   'tags': [],
#   'specs': ['Single-player', 'Downloadable Content']},
#  '1337': {'genres': [], 'tags': [], 'specs': []},
#  '1343': {'genres': [], 'tags': [], 'specs': []},
#  '1368': {'genres': [], 'tags': [], 'specs': []},
#  '1370': {'genres': [], 'tags': [], 'specs': []},
#  '1264': {'genres': [], 'tags': [], 'specs': []},
#  '1324': {'genres': [], 'tags': [], 'specs': []},
#  '1268': {'genres': ['Racing', 'Simulation'],
#   'tags': ['Racing', 'Simulation', 'Driving', 'Open World'],
#   'specs': ['Single-player']},
#  '1328': {'genres': ['Indie', 'Adventure'],
#   'tags': ['Interactive Fiction',
#    'Detective',
#    'Mystery',
#    'Anime',
#    'Indie',
#    'Horror',
#    'Adventure',
#    'Female Protagonist',
#    'Story Rich',
#    'Visual Novel'],
#   'specs': ['Steam Trading Cards',
#    'Single-player',
#    'Downloadable Content',
#    'Steam Achievements']},
#  '825': {'genres': ['Early Access',
#    'Casual',
#    'Action',
#    'Indie',
#    'Adventure',
#    'RPG',
#    'Strategy'],
#   'tags': ['Early Access',
#    'Puzzle-Platformer',
#    'Casual',
#    'Action',
#    'Sci-fi',
#    'Robots',
#    'Indie',
#    'Difficult',
#    'Adventure',
#    'RPG',
#    'Strategy',
#    'Platformer'],
#   'specs': ['Steam Leaderboards',
#    'Partial Controller Support',
#    'Includes level editor',
#    'Steam Trading Cards',
#    'Full controller support',
#    'Single-player',
#    'Steam Achievements']},
#  '473': {'genres': ['Indie', 'Casual', 'Action'],
#   'tags': ['Casual',
#    'Action',
#    'Difficult',
#    'Indie',
#    '2D',
#    'Side Scroller',
#    'Pixel Graphics',
#    'Platformer',
#    'Singleplayer',
#    'Runner'],
#   'specs': ['Steam Trading Cards', 'Single-player']},
#  '1297': {'genres': ['Indie', 'Adventure', 'Casual'],
#   'tags': ['Physics', 'Casual', 'Indie', 'Adventure', 'Puzzle'],
#   'specs': ['Steam Trading Cards',
#    'Single-player',
#    'Downloadable Content',
#    'Steam Achievements']},
#  '604': {'genres': ['Adventure', 'Action', 'RPG'],
#   'tags': ['Magic',
#    'Story Rich',
#    'Singleplayer',
#    'Classic',
#    'Gothic',
#    'Nudity',
#    'Action',
#    'Atmospheric',
#    'Exploration',
#    'RPG',
#    'Dark Fantasy',
#    'Medieval',
#    'Sandbox',
#    'Character Customization',
#    'Open World',
#    'Difficult',
#    'Fantasy',
#    'Great Soundtrack',
#    'Adventure',
#    'Third Person',
#    'Pirates',
#    'Action RPG'],
#   'specs': ['Downloadable Content',
#    'Partial Controller Support',
#    'Steam Cloud',
#    'Steam Trading Cards',
#    'Captions available',
#    'Single-player',
#    'Stats',
#    'Steam Achievements']},
#  '1333': {'genres': [], 'tags': [], 'specs': []},
#  '1336': {'genres': ['RPG', 'Strategy'],
#   'tags': ['Memes',
#    'Casual',
#    'Story Rich',
#    'Singleplayer',
#    'Nudity',
#    'Action',
#    'RPG',
#    'JRPG',
#    'Funny',
#    'Sci-fi',
#    'Comedy',
#    'Great Soundtrack',
#    'Anime',
#    'Turn-Based',
#    'Turn-Based Combat',
#    'Adventure',
#    'Female Protagonist',
#    'Strategy',
#    'Cute',
#    'Visual Novel'],
#   'specs': ['Downloadable Content',
#    'Steam Cloud',
#    'Steam Trading Cards',
#    'Full controller support',
#    'Single-player',
#    'Steam Achievements']},
#  '1340': {'genres': ['RPG', 'Strategy'],
#   'tags': ['Memes',
#    'Casual',
#    'Story Rich',
#    'Singleplayer',
#    'Nudity',
#    'Action',
#    'RPG',
#    'JRPG',
#    'Funny',
#    'Sci-fi',
#    'Comedy',
#    'Great Soundtrack',
#    'Anime',
#    'Turn-Based',
#    'Turn-Based Combat',
#    'Adventure',
#    'Female Protagonist',
#    'Strategy',
#    'Cute',
#    'Visual Novel'],
#   'specs': ['Downloadable Content',
#    'Steam Cloud',
#    'Steam Trading Cards',
#    'Full controller support',
#    'Single-player',
#    'Steam Achievements']},
#  '1153': {'genres': ['Indie', 'Adventure'],
#   'tags': ['Great Soundtrack',
#    'Local Multiplayer',
#    'Local Co-Op',
#    'Difficult',
#    'Indie',
#    'Co-op',
#    'Adventure',
#    'Atmospheric',
#    'Side Scroller',
#    '2D',
#    'Platformer',
#    'Stealth',
#    'Puzzle',
#    'Singleplayer'],
#   'specs': ['Shared/Split Screen',
#    'Downloadable Content',
#    'Steam Trading Cards',
#    'Full controller support',
#    'Single-player',
#    'Steam Achievements']},
#  '1355': {'genres': ['Racing', 'Simulation', 'Sports'],
#   'tags': ['Racing', 'Sports', 'Multiplayer', 'Simulation', 'Realistic'],
#   'specs': ['Downloadable Content',
#    'Multi-player',
#    'Partial Controller Support',
#    'Single-player',
#    'Steam Achievements']},
#  '1161': {'genres': ['Indie', 'Action'],
#   'tags': ['Bullet Hell',
#    'Arcade',
#    "Shoot 'Em Up",
#    'Casual',
#    'Action',
#    'Indie',
#    'Platformer',
#    'Puzzle'],
#   'specs': ['Steam Cloud',
#    'Steam Trading Cards',
#    'Full controller support',
#    'Single-player',
#    'Steam Achievements']},
#  '567': {'genres': ['Early Access',
#    'Racing',
#    'Casual',
#    'Action',
#    'Indie',
#    'Adventure',
#    'RPG'],
#   'tags': ['Memes',
#    'Point & Click',
#    'RPGMaker',
#    'Casual',
#    'Story Rich',
#    'Singleplayer',
#    'Space',
#    'Zombies',
#    'Racing',
#    'Psychological Horror',
#    'Nudity',
#    "Shoot 'Em Up",
#    'Action',
#    'RPG',
#    'JRPG',
#    'Early Access',
#    'Survival',
#    'Survival Horror',
#    'Arcade',
#    'Indie',
#    'Horror',
#    'Adventure',
#    '2D',
#    'Pixel Graphics',
#    'Female Protagonist'],
#   'specs': ['Partial Controller Support',
#    'Steam Trading Cards',
#    'Full controller support',
#    'Single-player',
#    'Steam Achievements']},
#  '1361': {'genres': ['Indie', 'Simulation', 'Casual', 'Strategy'],
#   'tags': ['Psychological Horror',
#    'Nudity',
#    'Dating Sim',
#    'Military',
#    'Resource Management',
#    'Anime',
#    'Casual',
#    'Sci-fi',
#    'Turn-Based',
#    'Indie',
#    'Turn-Based Combat',
#    'Strategy',
#    'Simulation',
#    'Cute',
#    'Visual Novel',
#    'Aliens'],
#   'specs': ['Steam Trading Cards',
#    'Single-player',
#    'Downloadable Content',
#    'Steam Achievements']},
#  '903': {'genres': ['Indie', 'Adventure', 'Action'],
#   'tags': ['Great Soundtrack',
#    'Open World',
#    'Action',
#    '3D Platformer',
#    'Sci-fi',
#    'Indie',
#    'Horror',
#    'Adventure',
#    'Atmospheric',
#    'Exploration',
#    'First-Person',
#    'Story Rich',
#    'Singleplayer',
#    'Parkour',
#    'Walking Simulator'],
#   'specs': ['Downloadable Content',
#    'Steam Cloud',
#    'Steam Trading Cards',
#    'Full controller support',
#    'Single-player',
#    'Steam Achievements']},
#  '1271': {'genres': ['Adventure'],
#   'tags': ['Adventure', 'Anime', 'Cute', 'Visual Novel'],
#   'specs': ['Partial Controller Support',
#    'Steam Trading Cards',
#    'Single-player',
#    'Downloadable Content']},
#  '1330': {'genres': ['Indie', 'Adventure', 'Action'],
#   'tags': ['Resource Management',
#    'Story Rich',
#    'Singleplayer',
#    'Short',
#    'Zombies',
#    'Action',
#    'Atmospheric',
#    'Shooter',
#    'Sci-fi',
#    'Post-apocalyptic',
#    'Survival',
#    'Great Soundtrack',
#    'Trains',
#    'Indie',
#    '2D',
#    'Adventure',
#    'Horror',
#    'Pixel Graphics',
#    'Side Scroller',
#    'Platformer'],
#   'specs': ['Downloadable Content',
#    'Steam Cloud',
#    'Steam Trading Cards',
#    'Full controller support',
#    'Captions available',
#    'Single-player',
#    'Steam Achievements']},
#  '1350': {'genres': ['Action', 'RPG'],
#   'tags': ['First-Person',
#    'Stealth',
#    'Story Rich',
#    'Singleplayer',
#    'Cyberpunk',
#    'Dystopian',
#    'Action',
#    'Atmospheric',
#    'RPG',
#    'Transhumanism',
#    'FPS',
#    'Conspiracy',
#    'Illuminati',
#    'Shooter',
#    'Open World',
#    'Sci-fi',
#    'Futuristic',
#    'Great Soundtrack',
#    'Adventure',
#    'Third Person'],
#   'specs': ['Downloadable Content',
#    'Steam Cloud',
#    'Steam Trading Cards',
#    'Full controller support',
#    'Single-player',
#    'Steam Achievements']},
#  '1351': {'genres': ['Action', 'RPG'],
#   'tags': ['MMORPG',
#    'Hardware',
#    'First-Person',
#    'Stealth',
#    'Story Rich',
#    'Singleplayer',
#    'Cyberpunk',
#    'Local Multiplayer',
#    'Dystopian',
#    'Action',
#    'Atmospheric',
#    'RPG',
#    'Transhumanism',
#    'FPS',
#    'Conspiracy',
#    'Illuminati',
#    'Shooter',
#    'Open World',
#    'VR',
#    'Sci-fi',
#    'Futuristic',
#    'Great Soundtrack',
#    '2D',
#    'Adventure',
#    'Third Person',
#    'Steam Machine',
#    'Controller',
#    'e-sports',
#    '3D Vision'],
#   'specs': ['Steam Cloud',
#    'Steam Trading Cards',
#    'Full controller support',
#    'Single-player',
#    'Steam Achievements']},
#  '1352': {'genres': ['Action', 'RPG'],
#   'tags': ['MMORPG',
#    'Hardware',
#    'First-Person',
#    'Stealth',
#    'Story Rich',
#    'Singleplayer',
#    'Cyberpunk',
#    'Local Multiplayer',
#    'Dystopian',
#    'Action',
#    'Atmospheric',
#    'RPG',
#    'Transhumanism',
#    'FPS',
#    'Conspiracy',
#    'Illuminati',
#    'Shooter',
#    'Open World',
#    'VR',
#    'Sci-fi',
#    'Futuristic',
#    'Great Soundtrack',
#    '2D',
#    'Adventure',
#    'Third Person',
#    'Steam Machine',
#    'Controller',
#    'e-sports',
#    '3D Vision'],
#   'specs': ['Downloadable Content',
#    'Steam Cloud',
#    'Steam Trading Cards',
#    'Full controller support',
#    'Single-player',
#    'Steam Achievements']},
#  '1209': {'genres': ['Indie', 'Racing', 'Adventure', 'Action'],
#   'tags': ['Racing',
#    'Dark Humor',
#    'Rhythm',
#    'Action',
#    'Difficult',
#    'Indie',
#    'Adventure',
#    'Music',
#    'Puzzle'],
#   'specs': ['Steam Leaderboards',
#    'Includes level editor',
#    'Steam Cloud',
#    'Full controller support',
#    'Steam Workshop',
#    'Single-player',
#    'Steam Achievements']},
#  '982': {'genres': ['Indie', 'Action'],
#   'tags': ['Psychological Horror',
#    'Survival Horror',
#    'Action',
#    'Indie',
#    'Horror',
#    'Simulation'],
#   'specs': ['Single-player']},
#  '827': {'genres': ['Indie', 'RPG'],
#   'tags': ['RPGMaker',
#    'Casual',
#    'Story Rich',
#    'Singleplayer',
#    'Classic',
#    'Rogue-like',
#    'Rogue-lite',
#    'RPG',
#    'JRPG',
#    'Silent Protagonist',
#    'Top-Down',
#    'Fantasy',
#    'Surreal',
#    'Procedural Generation',
#    'Survival',
#    'Great Soundtrack',
#    'Anime',
#    'Perma Death',
#    'Turn-Based',
#    'Retro',
#    'Indie',
#    '2D',
#    'Adventure',
#    'Side Scroller',
#    'Pixel Graphics',
#    'Fast-Paced',
#    'Ninja',
#    'Replay Value'],
#   'specs': ['Downloadable Content',
#    'Partial Controller Support',
#    'Steam Cloud',
#    'Steam Trading Cards',
#    'Single-player',
#    'Steam Achievements']},
#  '694': {'genres': ['Indie', 'Adventure'],
#   'tags': ['Story Rich',
#    'Psychological Horror',
#    'Great Soundtrack',
#    'Visual Novel',
#    'Walking Simulator',
#    'Indie',
#    'Horror',
#    'Adventure',
#    'Atmospheric',
#    'First-Person',
#    'Controller',
#    'Puzzle',
#    'Singleplayer',
#    'Narration'],
#   'specs': ['Steam Trading Cards',
#    'Full controller support',
#    'Captions available',
#    'Single-player',
#    'Steam Achievements']},
#  '531': {'genres': ['Indie', 'Simulation', 'Strategy'],
#   'tags': ['World War II',
#    'Wargame',
#    'Hex Grid',
#    'Turn-Based',
#    'Indie',
#    'Strategy',
#    'Simulation',
#    'Turn-Based Strategy',
#    'Historical'],
#   'specs': ['Shared/Split Screen',
#    'Multi-player',
#    'Single-player',
#    'Steam Cloud',
#    'Steam Trading Cards',
#    'Steam Workshop',
#    'Co-op',
#    'Steam Achievements']},
#  '538': {'genres': ['Indie', 'Casual', 'Strategy'],
#   'tags': ['Rogue-like', 'Casual', 'Indie', 'Relaxing', 'Strategy'],
#   'specs': ['Partial Controller Support',
#    'Steam Trading Cards',
#    'Single-player',
#    'Steam Achievements']},
#  '347': {'genres': ['Action', 'Indie', 'Adventure', 'RPG', 'Strategy'],
#   'tags': ['FPS',
#    'Cyberpunk',
#    'Great Soundtrack',
#    'Dystopian',
#    'RPGMaker',
#    'Action',
#    'Shooter',
#    'Sci-fi',
#    'Indie',
#    '2D',
#    'Adventure',
#    'First-Person',
#    'RPG',
#    'Strategy',
#    'Choices Matter',
#    'Multiple Endings'],
#   'specs': ['Partial Controller Support',
#    'Steam Trading Cards',
#    'Single-player',
#    'Steam Achievements']},
#  '1005': {'genres': ['Early Access',
#    'Casual',
#    'Indie',
#    'Adventure',
#    'Strategy',
#    'Simulation'],
#   'tags': ['Early Access',
#    'Casual',
#    'Indie',
#    'Adventure',
#    'Atmospheric',
#    'Strategy',
#    'Story Rich',
#    'Simulation'],
#   'specs': ['Downloadable Content',
#    'Steam Cloud',
#    'Steam Trading Cards',
#    'Single-player',
#    'Steam Achievements']},
#  '1100': {'genres': ['Indie', 'Action', 'Strategy'],
#   'tags': ['Competitive',
#    'First-Person',
#    'PvP',
#    'Singleplayer',
#    'Military',
#    'Action',
#    'Atmospheric',
#    'Simulation',
#    'Co-op',
#    'FPS',
#    'Team-Based',
#    'Tactical',
#    'Online Co-Op',
#    'Shooter',
#    'Multiplayer',
#    'Realistic',
#    'War',
#    'Indie',
#    'Adventure',
#    'Strategy'],
#   'specs': ['Multi-player',
#    'Includes level editor',
#    'Steam Trading Cards',
#    'Full controller support',
#    'Valve Anti-Cheat enabled',
#    'Steam Workshop',
#    'Cross-Platform Multiplayer',
#    'Co-op',
#    'Steam Achievements']},
#  '1114': {'genres': ['Indie', 'Action', 'Strategy'],
#   'tags': ['Great Soundtrack',
#    'Rogue-like',
#    'Rogue-lite',
#    'Action',
#    'Mythology',
#    'Indie',
#    'Pixel Graphics',
#    'Strategy',
#    'Singleplayer'],
#   'specs': ['Shared/Split Screen',
#    'Downloadable Content',
#    'Partial Controller Support',
#    'Local Multi-Player',
#    'Steam Cloud',
#    'Steam Trading Cards',
#    'Full controller support',
#    'Single-player',
#    'Steam Achievements']},
#  '494': {'genres': ['Indie', 'Simulation', 'Casual'],
#   'tags': ['Economy',
#    'Funny',
#    'Game Development',
#    'Sandbox',
#    'Point & Click',
#    'Building',
#    'Resource Management',
#    'Casual',
#    'City Builder',
#    'Indie',
#    '2D',
#    'Management',
#    'Relaxing',
#    'Strategy',
#    'Comedy',
#    'Simulation',
#    'Singleplayer'],
#   'specs': ['Steam Leaderboards',
#    'Includes level editor',
#    'Steam Cloud',
#    'Steam Trading Cards',
#    'Steam Workshop',
#    'Single-player',
#    'Stats',
#    'Steam Achievements']},
#  '357': {'genres': ['Indie', 'Action'],
#   'tags': ['Casual',
#    'Story Rich',
#    'Stealth',
#    'Singleplayer',
#    'Short',
#    'Minimalist',
#    'Cyberpunk',
#    'Action',
#    'Atmospheric',
#    'Relaxing',
#    'Narration',
#    'Top-Down',
#    'Funny',
#    'Puzzle-Platformer',
#    'Colorful',
#    'Sci-fi',
#    'Comedy',
#    'Family Friendly',
#    'Futuristic',
#    'Level Editor',
#    'Great Soundtrack',
#    'Indie',
#    '2D',
#    'Adventure',
#    'Platformer',
#    'Strategy',
#    'Puzzle'],
#   'specs': ['Steam Leaderboards',
#    'Includes level editor',
#    'Steam Cloud',
#    'Steam Trading Cards',
#    'Full controller support',
#    'Single-player',
#    'Steam Achievements']},
#  '363': {'genres': ['Indie'],
#   'tags': ['Singleplayer',
#    'Zombies',
#    'Rogue-like',
#    'Rogue-lite',
#    'Action-Adventure',
#    'Dark',
#    'Exploration',
#    'Top-Down',
#    'Open World',
#    'Sci-fi',
#    'Procedural Generation',
#    'Survival',
#    'Survival Horror',
#    'Crafting',
#    'Perma Death',
#    'Indie',
#    '2D',
#    'Horror',
#    'Pixel Graphics',
#    'Replay Value'],
#   'specs': ['Downloadable Content',
#    'Steam Leaderboards',
#    'Steam Cloud',
#    'Steam Trading Cards',
#    'Full controller support',
#    'Single-player',
#    'Steam Achievements']},
#  '284': {'genres': ['Indie', 'Adventure'],
#   'tags': ['Point & Click',
#    'First-Person',
#    'Story Rich',
#    'Singleplayer',
#    'Short',
#    'Psychological Horror',
#    'Mystery',
#    'Atmospheric',
#    'Exploration',
#    'Open World',
#    'VR',
#    'Supernatural',
#    'Detective',
#    'Great Soundtrack',
#    'Gore',
#    'Horror',
#    'Indie',
#    'Adventure',
#    'Puzzle',
#    'Walking Simulator',
#    'Lovecraftian'],
#   'specs': ['Downloadable Content',
#    'Gamepad',
#    'Steam Cloud',
#    'Steam Trading Cards',
#    'Full controller support',
#    'HTC Vive',
#    'Oculus Rift',
#    'Single-player',
#    'Seated',
#    'Standing',
#    'Steam Achievements']},
#  '1017': {'genres': ['Indie', 'Casual', 'Action'],
#   'tags': ['Casual',
#    'Tanks',
#    'First-Person',
#    'PvP',
#    'Singleplayer',
#    'Military',
#    'Action',
#    'Atmospheric',
#    'Relaxing',
#    'Team-Based',
#    'Funny',
#    'Tactical',
#    'Online Co-Op',
#    'Shooter',
#    'Physics',
#    'Family Friendly',
#    'Multiplayer',
#    'Futuristic',
#    'Procedural Generation',
#    'Fast-Paced',
#    'Indie',
#    'War',
#    'Controller',
#    'Puzzle'],
#   'specs': ['Steam Leaderboards',
#    'Steam Cloud',
#    'Steam Trading Cards',
#    'Full controller support',
#    'Online Multi-Player',
#    'Single-player',
#    'Steam Achievements']},
#  '1002': {'genres': ['Adventure'],
#   'tags': ['Great Soundtrack',
#    'Short',
#    'Sci-fi',
#    'Adventure',
#    'Atmospheric',
#    'First-Person',
#    'Female Protagonist',
#    'Puzzle',
#    'Singleplayer',
#    'Story Rich',
#    'Space'],
#   'specs': ['Downloadable Content',
#    'Steam Cloud',
#    'Steam Trading Cards',
#    'Full controller support',
#    'Single-player',
#    'Steam Achievements']},
#  '754': {'genres': ['Adventure', 'Casual'],
#   'tags': ['Detective',
#    'Great Soundtrack',
#    'Point & Click',
#    'Mystery',
#    'Casual',
#    'Hidden Object',
#    'Horror',
#    'Adventure',
#    '2D',
#    'Atmospheric',
#    'Fantasy',
#    'Female Protagonist',
#    'Indie',
#    'Family Friendly',
#    'Puzzle',
#    'Pirates',
#    'Singleplayer',
#    'Story Rich'],
#   'specs': ['Steam Trading Cards',
#    'Single-player',
#    'Steam Cloud',
#    'Steam Achievements']},
#  '536': {'genres': ['Simulation', 'Strategy'],
#   'tags': ['Classic',
#    'Medieval',
#    'Sandbox',
#    'Resource Management',
#    'Open World',
#    'City Builder',
#    'Co-op',
#    'Atmospheric',
#    'RTS',
#    'Strategy',
#    'Base Building',
#    'Multiplayer',
#    'Simulation',
#    'Singleplayer',
#    'Historical'],
#   'specs': ['Multi-player',
#    'Includes level editor',
#    'Steam Trading Cards',
#    'Cross-Platform Multiplayer',
#    'Single-player']},
#  '359': {'genres': ['Indie'],
#   'tags': ['Survival Horror',
#    'Rogue-like',
#    'Rogue-lite',
#    'Action',
#    'VR',
#    'Difficult',
#    'Perma Death',
#    'Horror',
#    'Indie',
#    'Atmospheric',
#    'First-Person',
#    'Stealth',
#    'Singleplayer',
#    'Procedural Generation',
#    'Survival'],
#   'specs': ['Downloadable Content',
#    'Gamepad',
#    'Oculus Rift',
#    'Full controller support',
#    'Single-player',
#    'Seated',
#    'Keyboard / Mouse',
#    'Standing',
#    'Steam Achievements']},
#  '416': {'genres': ['Indie', 'Action'],
#   'tags': ['Medieval',
#    'Local Multiplayer',
#    'Arcade',
#    'Local Co-Op',
#    'Shooter',
#    'Tower Defense',
#    'Action',
#    'Arena Shooter',
#    'Retro',
#    'Indie',
#    'Horror',
#    'Difficult',
#    '4 Player Local',
#    'Pixel Graphics',
#    '2D',
#    'Platformer',
#    'Co-op',
#    'Singleplayer'],
#   'specs': ['Shared/Split Screen',
#    'Partial Controller Support',
#    'Steam Trading Cards',
#    'Full controller support',
#    'Single-player',
#    'Steam Achievements']},
#  '251': {'genres': ['Early Access', 'Racing', 'Sports', 'Indie', 'Simulation'],
#   'tags': ['Early Access', 'Racing', 'Sports', 'Indie', 'Simulation'],
#   'specs': ['Steam Leaderboards',
#    'Partial Controller Support',
#    'Steam Turn Notifications',
#    'Single-player',
#    'Stats']},
#  '923': {'genres': ['Casual',
#    'Indie',
#    'Adventure',
#    'RPG',
#    'Strategy',
#    'Massively Multiplayer'],
#   'tags': ['Conspiracy',
#    'Psychological Horror',
#    'Illuminati',
#    'Casual',
#    'Indie',
#    'Horror',
#    'Adventure',
#    'RPG',
#    'Strategy',
#    'Puzzle',
#    'Massively Multiplayer'],
#   'specs': ['Downloadable Content',
#    'Multi-player',
#    'Single-player',
#    'MMO',
#    'Cross-Platform Multiplayer',
#    'Co-op',
#    'Steam Achievements']},
#  '953': {'genres': ['Early Access',
#    'Action',
#    'Indie',
#    'Adventure',
#    'RPG',
#    'Strategy'],
#   'tags': ['Early Access',
#    'Rogue-like',
#    'Open World',
#    'Action',
#    'Indie',
#    'Adventure',
#    'Pixel Graphics',
#    'RPG',
#    'Strategy',
#    'Comedy',
#    'Space'],
#   'specs': ['Steam Trading Cards',
#    'Single-player',
#    'Downloadable Content',
#    'Steam Achievements']},
#  '869': {'genres': ['Indie', 'Adventure', 'Action'],
#   'tags': ['FPS',
#    'Zombies',
#    'Psychological Horror',
#    'Nudity',
#    'Dark Comedy',
#    'Shooter',
#    'Action',
#    'Indie',
#    'Horror',
#    'Adventure',
#    'Comedy'],
#   'specs': ['Partial Controller Support',
#    'Steam Trading Cards',
#    'Single-player',
#    'Steam Achievements']},
#  '622': {'genres': ['Indie', 'RPG', 'Strategy'],
#   'tags': ['Story Rich',
#    'Singleplayer',
#    'Strategy RPG',
#    'Zombies',
#    'Turn-Based Tactics',
#    'Rogue-like',
#    'Tactical RPG',
#    'RPG',
#    'Dark Fantasy',
#    'Tactical',
#    'Difficult',
#    'Fantasy',
#    'CRPG',
#    'Turn-Based Strategy',
#    'Great Soundtrack',
#    'Perma Death',
#    'Turn-Based',
#    'Indie',
#    'Turn-Based Combat',
#    'Strategy',
#    'Replay Value'],
#   'specs': ['Shared/Split Screen',
#    'Multi-player',
#    'Local Multi-Player',
#    'Steam Cloud',
#    'Steam Trading Cards',
#    'Steam Workshop',
#    'Cross-Platform Multiplayer',
#    'Single-player',
#    'Steam Achievements']},
#  '507': {'genres': ['Indie', 'Simulation', 'RPG', 'Strategy'],
#   'tags': ['Zombies',
#    'Sandbox',
#    'Turn-Based',
#    'Difficult',
#    'Indie',
#    'Sci-fi',
#    'Horror',
#    'RPG',
#    'Strategy',
#    'Post-apocalyptic',
#    'Simulation',
#    'Singleplayer',
#    'Survival'],
#   'specs': ['Steam Trading Cards',
#    'Single-player',
#    'Stats',
#    'Steam Achievements']},
#  '298': {'genres': ['Indie', 'Simulation', 'Sports', 'Strategy'],
#   'tags': ['Sports', 'Indie', 'Management', 'Strategy', 'Simulation'],
#   'specs': ['Multi-player',
#    'Steam Trading Cards',
#    'Steam Workshop',
#    'Cross-Platform Multiplayer',
#    'Single-player',
#    'Steam Achievements']},
#  '304': {'genres': ['Indie', 'Adventure', 'Casual'],
#   'tags': ['Casual',
#    'Sci-fi',
#    'Indie',
#    'Adventure',
#    'Strategy',
#    'Visual Novel'],
#   'specs': ['Steam Trading Cards',
#    'Single-player',
#    'Downloadable Content',
#    'Steam Achievements']},
#  '166': {'genres': ['Adventure', 'Action'],
#   'tags': ['Crime',
#    'Third-Person Shooter',
#    'First-Person',
#    'Singleplayer',
#    'Racing',
#    'Action',
#    'Atmospheric',
#    'RPG',
#    'Co-op',
#    'Mature',
#    'Funny',
#    'Sandbox',
#    'Shooter',
#    'Open World',
#    'Comedy',
#    'Multiplayer',
#    'Moddable',
#    'Great Soundtrack',
#    'Adventure',
#    'Third Person'],
#   'specs': ['Single-player',
#    'Full controller support',
#    'Multi-player',
#    'Steam Achievements']},
#  '1191': {'genres': ['Indie', 'Adventure', 'Action'],
#   'tags': ["Beat 'em up",
#    'Great Soundtrack',
#    'Character Action Game',
#    'Voxel',
#    'Rogue-like',
#    'Action',
#    'Difficult',
#    'Robots',
#    'Indie',
#    'Adventure',
#    'Hack and Slash',
#    'Singleplayer'],
#   'specs': ['Downloadable Content',
#    'Steam Cloud',
#    'Steam Trading Cards',
#    'Full controller support',
#    'Single-player',
#    'Steam Achievements']},
#  '1246': {'genres': ['Action', 'RPG'],
#   'tags': ['Third-Person Shooter',
#    'Party-Based RPG',
#    'Story Rich',
#    'Real-Time with Pause',
#    'Singleplayer',
#    'Classic',
#    'Space',
#    'Romance',
#    'Action',
#    'Mythology',
#    'Dragons',
#    'Atmospheric',
#    'RPG',
#    'Martial Arts',
#    'Choices Matter',
#    'Mature',
#    'Multiple Endings',
#    'Dark Fantasy',
#    'Tactical',
#    'Character Customization',
#    'Shooter',
#    'Open World',
#    'Sci-fi',
#    'Fantasy',
#    'Cinematic',
#    'Moddable',
#    'Great Soundtrack',
#    'Adventure',
#    'Third Person',
#    'Female Protagonist',
#    'Strategy',
#    'Action RPG'],
#   'specs': ['Partial Controller Support', 'Single-player']},
#  '1115': {'genres': [], 'tags': [], 'specs': []},
#  '836': {'genres': ['RPG', 'Strategy'],
#   'tags': ['Memes',
#    'Story Rich',
#    'Singleplayer',
#    'Nudity',
#    'Action',
#    'Sexual Content',
#    'RPG',
#    'JRPG',
#    'Funny',
#    'Fantasy',
#    'Comedy',
#    'Great Soundtrack',
#    'Anime',
#    'Turn-Based',
#    'Turn-Based Combat',
#    'Third Person',
#    'Female Protagonist',
#    'Strategy',
#    'Cute',
#    'Visual Novel'],
#   'specs': ['Downloadable Content',
#    'Steam Cloud',
#    'Steam Trading Cards',
#    'Full controller support',
#    'Single-player',
#    'Steam Achievements']},
#  '568': {'genres': ['Indie', 'Adventure'],
#   'tags': ['Racing',
#    'Great Soundtrack',
#    'Open World',
#    'VR',
#    'Indie',
#    'Adventure',
#    'Atmospheric',
#    'Fantasy',
#    'Exploration',
#    'First-Person',
#    'Platformer',
#    'Competitive',
#    'RPG',
#    'Singleplayer',
#    'Parkour',
#    'Replay Value'],
#   'specs': ['Downloadable Content',
#    'Gamepad',
#    'Tracked Motion Controllers',
# ...
#    'Online Multi-Player',
#    'Cross-Platform Multiplayer',
#    'Single-player',
#    'Steam Achievements']},
#  '449': {'genres': ['RPG', 'Strategy'],
#   'tags': ['4X', 'RPG', 'Strategy'],
#   'specs': ['Downloadable Content',
#    'Multi-player',
#    'Partial Controller Support',
#    'Steam Workshop',
#    'Steam Cloud',
#    'Steam Trading Cards',
#    'Online Multi-Player',
#    'Cross-Platform Multiplayer',
#    'Single-player',
#    'Steam Achievements']},
#  '451': {'genres': ['Simulation', 'Strategy'],
#   'tags': ['Story Rich',
#    'Singleplayer',
#    'Classic',
#    'Space',
#    'Action',
#    'Atmospheric',
#    'Simulation',
#    'Tactical',
#    'Sci-fi',
#    'Multiplayer',
#    'Futuristic',
#    'Moddable',
#    'Survival',
#    '4X',
#    'Great Soundtrack',
#    'Adventure',
#    'RTS',
#    'Female Protagonist',
#    'Strategy',
#    'Remake'],
#   'specs': ['Multi-player',
#    'Steam Cloud',
#    'Steam Workshop',
#    'Single-player',
#    'Steam Achievements']},
#  '454': {'genres': ['Indie', 'Adventure', 'RPG', 'Strategy'],
#   'tags': ['Interactive Fiction',
#    'Nudity',
#    'Dating Sim',
#    'Strategy',
#    'Romance',
#    'Anime',
#    'Otome',
#    'Turn-Based',
#    'Sci-fi',
#    'Indie',
#    'Fantasy',
#    'Adventure',
#    'RPG',
#    'Female Protagonist',
#    'Story Rich',
#    'Singleplayer',
#    'Mature',
#    'Visual Novel'],
#   'specs': ['Downloadable Content',
#    'Partial Controller Support',
#    'Steam Cloud',
#    'Steam Trading Cards',
#    'Single-player',
#    'Steam Achievements']},
#  '457': {'genres': ['Casual',
#    'Indie',
#    'Adventure',
#    'RPG',
#    'Strategy',
#    'Simulation'],
#   'tags': ['Dating Sim',
#    'Casual',
#    'Story Rich',
#    'Singleplayer',
#    'Nudity',
#    'Cyberpunk',
#    'Romance',
#    'Otome',
#    'RPG',
#    'Simulation',
#    'Mature',
#    'Multiple Endings',
#    'Sci-fi',
#    'Fantasy',
#    'Interactive Fiction',
#    'Anime',
#    'Turn-Based',
#    'Indie',
#    'Adventure',
#    'Female Protagonist',
#    'Strategy',
#    'Visual Novel'],
#   'specs': ['Downloadable Content',
#    'Partial Controller Support',
#    'Steam Cloud',
#    'Steam Trading Cards',
#    'Single-player',
#    'Steam Achievements']},
#  '460': {'genres': ['Racing', 'Casual', 'Action', 'Indie', 'Adventure', 'RPG'],
#   'tags': ['Alternate History',
#    'Casual',
#    'First-Person',
#    'Magic',
#    'Cult Classic',
#    'Singleplayer',
#    'Artificial Intelligence',
#    'Minimalist',
#    'Gun Customization',
#    'Racing',
#    'Psychological Horror',
#    'Real-Time',
#    'Rogue-like',
#    'Rogue-lite',
#    'Action',
#    'Arena Shooter',
#    'Dungeon Crawler',
#    'Exploration',
#    'RPG',
#    'Co-op',
#    'Multiple Endings',
#    'Isometric',
#    'Team-Based',
#    'FPS',
#    'Top-Down',
#    'Funny',
#    'Silent Protagonist',
#    'Fighting',
#    'Loot',
#    'Character Customization',
#    'Shooter',
#    'Open World',
#    'Difficult',
#    'Multiplayer',
#    'Procedural Generation',
#    'Swordplay',
#    'Cartoony',
#    'Great Soundtrack',
#    'Arcade',
#    'Fast-Paced',
#    'Perma Death',
#    'Retro',
#    'Indie',
#    'Horror',
#    'Adventure',
#    'Third Person',
#    'Side Scroller',
#    'Controller',
#    'Action RPG',
#    '2.5D',
#    'Walking Simulator',
#    'Replay Value'],
#   'specs': ['Online Co-op',
#    'Multi-player',
#    'Steam Leaderboards',
#    'Steam Cloud',
#    'Co-op',
#    'Steam Trading Cards',
#    'Full controller support',
#    'Online Multi-Player',
#    'Cross-Platform Multiplayer',
#    'Single-player',
#    'Stats',
#    'Steam Achievements']},
#  '462': {'genres': ['Action', 'Indie', 'RPG', 'Strategy', 'Simulation'],
#   'tags': ['Story Rich',
#    'Singleplayer',
#    'Space',
#    'Aliens',
#    'Turn-Based Tactics',
#    'Rogue-like',
#    'Tactical RPG',
#    'Rogue-lite',
#    'Action',
#    'Dungeon Crawler',
#    'Atmospheric',
#    'RPG',
#    'Simulation',
#    'Tactical',
#    'Mechs',
#    'Character Customization',
#    'City Builder',
#    'Difficult',
#    'Sci-fi',
#    'Fantasy',
#    'Post-apocalyptic',
#    'Turn-Based Strategy',
#    '4X',
#    'Perma Death',
#    'Turn-Based',
#    'Retro',
#    'Indie',
#    'Turn-Based Combat',
#    'Strategy'],
#   'specs': ['Steam Trading Cards',
#    'Single-player',
#    'Steam Leaderboards',
#    'Steam Achievements']},
#  '467': {'genres': ['Casual',
#    'Indie',
#    'Free to Play',
#    'Adventure',
#    'Simulation'],
#   'tags': ['Casual', 'Indie', 'Free to Play', 'Adventure', 'Simulation'],
#   'specs': ['Downloadable Content',
#    'Steam Trading Cards',
#    'In-App Purchases',
#    'Single-player',
#    'Steam Achievements']},
#  '468': {'genres': [],
#   'tags': ['Anime', 'Movie'],
#   'specs': ['Captions available']},
#  '469': {'genres': ['Indie', 'Adventure', 'Casual', 'Action'],
#   'tags': ['Casual', 'Action', 'Indie', 'Adventure', 'Platformer', 'Puzzle'],
#   'specs': ['Downloadable Content',
#    'Steam Cloud',
#    'Steam Trading Cards',
#    'Single-player',
#    'Stats',
#    'Steam Achievements']},
#  '471': {'genres': ['Indie', 'Casual'],
#   'tags': ['Indie', 'Card Game', 'Casual'],
#   'specs': ['Steam Trading Cards', 'Single-player', 'Steam Achievements']},
#  '472': {'genres': ['Indie', 'Adventure', 'Casual', 'Action'],
#   'tags': ['Anime',
#    'Action',
#    'Casual',
#    'Indie',
#    '2D',
#    'Adventure',
#    'Pixel Graphics',
#    'Platformer',
#    'Female Protagonist'],
#   'specs': ['Downloadable Content',
#    'Steam Leaderboards',
#    'Partial Controller Support',
#    'Steam Cloud',
#    'Steam Trading Cards',
#    'Single-player',
#    'Steam Achievements']},
#  '476': {'genres': ['Action',
#    'Indie',
#    'Adventure',
#    'RPG',
#    'Massively Multiplayer'],
#   'tags': ['Twin Stick Shooter',
#    'Singleplayer',
#    'Massively Multiplayer',
#    'Bullet Hell',
#    'Local Co-Op',
#    'Rogue-like',
#    'Rogue-lite',
#    'Action',
#    'RPG',
#    'Hack and Slash',
#    'Co-op',
#    'Top-Down',
#    'Difficult',
#    'Multiplayer',
#    'Indie',
#    '2D',
#    'Adventure',
#    'Pixel Graphics',
#    'Controller',
#    'Action RPG'],
#   'specs': ['Shared/Split Screen',
#    'Online Co-op',
#    'Downloadable Content',
#    'Multi-player',
#    'Local Multi-Player',
#    'Single-player',
#    'Steam Cloud',
#    'Steam Trading Cards',
#    'Full controller support',
#    'Local Co-op',
#    'Online Multi-Player',
#    'Cross-Platform Multiplayer',
#    'Co-op',
#    'Steam Achievements']},
#  '484': {'genres': ['Casual', 'Action', 'Indie', 'RPG', 'Strategy'],
#   'tags': ['Wargame',
#    'Casual',
#    'Singleplayer',
#    'Classic',
#    'Action',
#    'Stylized',
#    'Atmospheric',
#    'RPG',
#    'Simulation',
#    'Funny',
#    'Tower Defense',
#    'Sci-fi',
#    'Fantasy',
#    'Survival',
#    'Arcade',
#    'Crafting',
#    'Retro',
#    'Indie',
#    'War',
#    '2D',
#    'RTS',
#    'Strategy',
#    'Action RPG'],
#   'specs': ['Steam Leaderboards',
#    'Includes level editor',
#    'Steam Trading Cards',
#    'Full controller support',
#    'Single-player',
#    'Stats',
#    'Steam Achievements']},
#  '485': {'genres': [], 'tags': [], 'specs': []},
#  '487': {'genres': ['Indie', 'Adventure', 'Action'],
#   'tags': ['Blood',
#    'Action',
#    'Difficult',
#    'Retro',
#    'Indie',
#    '2D',
#    'Adventure',
#    'Side Scroller',
#    'Pixel Graphics',
#    'Demons',
#    'Platformer',
#    'Ninja',
#    'Singleplayer'],
#   'specs': ['Downloadable Content',
#    'Steam Cloud',
#    'Steam Trading Cards',
#    'Full controller support',
#    'Single-player',
#    'Steam Achievements']},
#  '488': {'genres': ['Indie', 'RPG', 'Strategy'],
#   'tags': ['Utilities',
#    'Game Development',
#    'Party-Based RPG',
#    'Sandbox',
#    'Online Co-Op',
#    'Turn-Based',
#    'Indie',
#    'Horror',
#    'Fantasy',
#    'Adventure',
#    'RPG',
#    'Strategy',
#    'Story Rich',
#    'Multiplayer',
#    'Western',
#    'Software'],
#   'specs': ['Downloadable Content',
#    'Multi-player',
#    'Steam Workshop',
#    'Cross-Platform Multiplayer',
#    'Co-op']},
#  '491': {'genres': ['Design &amp; Illustration', 'Utilities', 'Photo Editing'],
#   'tags': ['Design & Illustration', 'Utilities', 'Photo Editing'],
#   'specs': ['Shared/Split Screen',
#    'Downloadable Content',
#    'Steam Trading Cards',
#    'Steam Workshop',
#    'Single-player']},
#  '492': {'genres': ['Design &amp; Illustration', 'Utilities', 'Photo Editing'],
#   'tags': ['Design & Illustration', 'Utilities', 'Photo Editing'],
#   'specs': ['Shared/Split Screen',
#    'Downloadable Content',
#    'Steam Trading Cards',
#    'Steam Workshop',
#    'Single-player']},
#  '495': {'genres': ['Indie', 'Strategy'],
#   'tags': ['Memes',
#    'Casual',
#    'Singleplayer',
#    'Board Game',
#    'Card Game',
#    'Funny',
#    'Difficult',
#    'Comedy',
#    'Family Friendly',
#    'Multiplayer',
#    'Great Soundtrack',
#    'Survival Horror',
#    'Anime',
#    'Turn-Based',
#    'Indie',
#    '2D',
#    'Female Protagonist',
#    'Strategy',
#    'Cute'],
#   'specs': ['Downloadable Content',
#    'Multi-player',
#    'Steam Leaderboards',
#    'Steam Cloud',
#    'Steam Trading Cards',
#    'Valve Anti-Cheat enabled',
#    'Single-player',
#    'Stats',
#    'Steam Achievements']},
#  '497': {'genres': ['Indie', 'Action'],
#   'tags': ['Indie', 'Bullet Hell', "Shoot 'Em Up", 'Action'],
#   'specs': ['Partial Controller Support',
#    'Single-player',
#    'Downloadable Content']},
#  '503': {'genres': ['Indie', 'Adventure', 'Action'],
#   'tags': ['Top-Down',
#    'Survival Horror',
#    'Arcade',
#    "Shoot 'Em Up",
#    'Action',
#    'Fast-Paced',
#    'Difficult',
#    'Retro',
#    'Indie',
#    '2D',
#    'Adventure',
#    'Horror',
#    'Pixel Graphics',
#    'Ninja'],
#   'specs': ['Steam Trading Cards', 'Single-player', 'Steam Achievements']},
#  '511': {'genres': ['Sports', 'Casual', 'Action', 'Indie', 'Adventure', 'RPG'],
#   'tags': ['Twin Stick Shooter',
#    'Casual',
#    'Cult Classic',
#    'Classic',
#    'Singleplayer',
#    'Aliens',
#    'Zombies',
#    'Cyberpunk',
#    'Local Multiplayer',
#    'Local Co-Op',
#    'Match 3',
#    'Rogue-like',
#    "Shoot 'Em Up",
#    'Action',
#    'Rogue-lite',
#    'Dystopian',
#    'Dungeon Crawler',
#    'Dark',
#    'Atmospheric',
#    'RPG',
#    'Co-op',
#    'Top-Down',
#    'Sports',
#    'Funny',
#    'Shooter',
#    'Physics',
#    'Top-Down Shooter',
#    'Sci-fi',
#    'Fantasy',
#    'Lovecraftian',
#    'Comedy',
#    'Post-apocalyptic',
#    'Survival',
#    'Moddable',
#    'Level Editor',
#    'Great Soundtrack',
#    'Arcade',
#    'Destruction',
#    'Gore',
#    'Indie',
#    '2D',
#    'Adventure',
#    'Puzzle',
#    'Replay Value'],
#   'specs': ['Shared/Split Screen',
#    'Steam Leaderboards',
#    'Includes level editor',
#    'Steam Cloud',
#    'Steam Trading Cards',
#    'Full controller support',
#    'Steam Workshop',
#    'Single-player',
#    'Stats',
#    'Steam Achievements']},
#  '514': {'genres': ['Casual', 'Action', 'Indie', 'Adventure', 'RPG'],
#   'tags': ['Zombies',
#    'World War II',
#    'Funny',
#    'Shooter',
#    'Casual',
#    'Action',
#    'Indie',
#    'Adventure',
#    'RPG'],
#   'specs': ['Shared/Split Screen',
#    'Partial Controller Support',
#    'Single-player',
#    'Steam Trading Cards',
#    'Co-op',
#    'Steam Achievements']},
#  '519': {'genres': ['Adventure', 'Action'],
#   'tags': ['Horror', 'Adventure', 'Action'],
#   'specs': ['Steam Trading Cards', 'Single-player', 'Downloadable Content']},
#  '528': {'genres': ['Casual', 'Action', 'Indie', 'Strategy', 'Simulation'],
#   'tags': ['Real Time Tactics',
#    'Point & Click',
#    'Resource Management',
#    'Casual',
#    'Management',
#    'Real-Time with Pause',
#    'Singleplayer',
#    'Zombies',
#    'Action',
#    'Relaxing',
#    'Simulation',
#    'Top-Down',
#    'Funny',
#    'Game Development',
#    'Sandbox',
#    'City Builder',
#    'Comedy',
#    'Post-apocalyptic',
#    'Multiplayer',
#    'Procedural Generation',
#    'Survival',
#    'Economy',
#    'Building',
#    'Crafting',
#    'Indie',
#    '2D',
#    'Strategy'],
#   'specs': ['Multi-player',
#    'Steam Leaderboards',
#    'Includes level editor',
#    'Steam Cloud',
#    'Steam Trading Cards',
#    'Steam Workshop',
#    'Cross-Platform Multiplayer',
#    'Single-player',
#    'Stats',
#    'Steam Achievements']},
#  '535': {'genres': ['Indie', 'Adventure', 'Casual'],
#   'tags': ['Casual',
#    'First-Person',
#    'Story Rich',
#    'Noir',
#    'Singleplayer',
#    'Mystery',
#    'Dragons',
#    'Atmospheric',
#    'Exploration',
#    'Relaxing',
#    'Narration',
#    'Mature',
#    'Multiple Endings',
#    'Great Soundtrack',
#    'Indie',
#    'Horror',
#    'Adventure',
#    'Female Protagonist',
#    'Walking Simulator'],
#   'specs': ['Partial Controller Support',
#    'Steam Cloud',
#    'Steam Trading Cards',
#    'Full controller support',
#    'Single-player',
#    'Steam Achievements']},
#  '540': {'genres': ['Adventure', 'Casual'],
#   'tags': ['Casual',
#    'Horror',
#    'Adventure',
#    'Atmospheric',
#    'Comedy',
#    'Story Rich',
#    'Visual Novel'],
#   'specs': ['Downloadable Content',
#    'Steam Cloud',
#    'Steam Trading Cards',
#    'Single-player',
#    'Steam Achievements']},
#  '547': {'genres': ['Indie', 'Adventure', 'Action'],
#   'tags': ['Funny',
#    'Great Soundtrack',
#    'Memes',
#    'Action',
#    'Difficult',
#    'Retro',
#    'Indie',
#    '2D',
#    'Adventure',
#    'Pixel Graphics',
#    'Platformer',
#    'Comedy',
#    'Singleplayer'],
#   'specs': ['Downloadable Content',
#    'Steam Trading Cards',
#    'Full controller support',
#    'Single-player',
#    'Steam Achievements']},
#  '565': {'genres': ['Casual',
#    'Action',
#    'Indie',
#    'Adventure',
#    'RPG',
#    'Strategy',
#    'Simulation'],
#   'tags': ['Twin Stick Shooter',
#    'Casual',
#    'Free to Play',
#    'Singleplayer',
#    'Space',
#    'Nudity',
#    'Local Multiplayer',
#    'Local Co-Op',
#    'Rogue-like',
#    'Rogue-lite',
#    'Action',
#    'Stylized',
#    'Mythology',
#    'Space Sim',
#    'Atmospheric',
#    'RPG',
#    'Simulation',
#    'Historical',
#    'Sandbox',
#    'Mechs',
#    'Shooter',
#    'Physics',
#    'Open World',
#    'Metroidvania',
#    'Sci-fi',
#    'Difficult',
#    'VR',
#    'Multiplayer',
#    'Great Soundtrack',
#    'Building',
#    'Destruction',
#    'Crafting',
#    'Indie',
#    '2D',
#    'Adventure',
#    'Side Scroller',
#    'Platformer',
#    'Strategy'],
#   'specs': ['Shared/Split Screen',
#    'Steam Leaderboards',
#    'Partial Controller Support',
#    'Local Multi-Player',
#    'Steam Cloud',
#    'Steam Trading Cards',
#    'Full controller support',
#    'Captions available',
#    'Local Co-op',
#    'Single-player',
#    'Stats',
#    'Steam Achievements']},
#  '571': {'genres': ['Casual'],
#   'tags': ['Resource Management', 'Casual', 'Family Friendly', 'Strategy'],
#   'specs': ['Single-player', 'Steam Cloud']},
#  '578': {'genres': [], 'tags': [], 'specs': []},
#  '579': {'genres': ['Adventure', 'Action'],
#   'tags': ['Adventure', 'Action'],
#   'specs': ['Steam Trading Cards', 'Single-player', 'Downloadable Content']},
#  '581': {'genres': ['Adventure', 'Action'],
#   'tags': ['Horror', 'Adventure', 'Action'],
#   'specs': ['Steam Trading Cards', 'Single-player', 'Downloadable Content']},
#  '582': {'genres': ['Indie', 'Adventure'],
#   'tags': ['Indie', 'Horror', 'Adventure', 'Historical', 'Walking Simulator'],
#   'specs': ['Partial Controller Support',
#    'Steam Trading Cards',
#    'Single-player',
#    'Downloadable Content']},
#  '584': {'genres': ['Indie', 'Adventure'],
#   'tags': ['Hacking',
#    'Programming',
#    'VR',
#    'Indie',
#    'Adventure',
#    'First-Person',
#    'Puzzle'],
#   'specs': ['Oculus Rift', 'Single-player', 'Downloadable Content']},
#  '586': {'genres': ['Indie', 'Adventure', 'Casual'],
#   'tags': ['Point & Click',
#    'Resource Management',
#    'Casual',
#    'Sci-fi',
#    'Hidden Object',
#    'Indie',
#    'Adventure',
#    'Family Friendly',
#    'Female Protagonist',
#    'Strategy',
#    'Comedy',
#    'Puzzle'],
#   'specs': ['Partial Controller Support',
#    'Steam Trading Cards',
#    'Single-player',
#    'Steam Cloud']},
#  '588': {'genres': ['Indie', 'Adventure', 'Casual', 'Action'],
#   'tags': ['Casual',
#    'Classic',
#    'Singleplayer',
#    'Space',
#    'Action',
#    'Stylized',
#    'Action-Adventure',
#    'Atmospheric',
#    'Simulation',
#    'Funny',
#    'Puzzle-Platformer',
#    'Fantasy',
#    'Soundtrack',
#    'Great Soundtrack',
#    'Arcade',
#    'Anime',
#    'Retro',
#    'Indie',
#    '2D',
#    'Adventure',
#    'Pixel Graphics',
#    'Platformer',
#    'Puzzle'],
#   'specs': ['Downloadable Content',
#    'Steam Leaderboards',
#    'Partial Controller Support',
#    'Steam Trading Cards',
#    'Single-player']},
#  '594': {'genres': ['Indie', 'Adventure', 'Action'],
#   'tags': ['Anime',
#    'Action',
#    'Retro',
#    'Indie',
#    'Adventure',
#    'Pixel Graphics',
#    'Platformer'],
#   'specs': ['Steam Cloud',
#    'Steam Trading Cards',
#    'Full controller support',
#    'Single-player',
#    'Steam Achievements']}}

# %%
# for each user, collect all the genres, tags, specs info from the games they recommended

user_recommend_genres = {}
for user in user_recommend.keys():
    user_recommend_genres[user] = {'genres': [], 'tags': [], 'specs': []}
    for item in user_recommend[user]:
        if item in steam_games_genres.keys():
            user_recommend_genres[user]['genres'].extend(steam_games_genres[item]['genres'])
            user_recommend_genres[user]['tags'].extend(steam_games_genres[item]['tags'])
            user_recommend_genres[user]['specs'].extend(steam_games_genres[item]['specs'])

# %%
user_recommend_genres
# Out:
# {'76561197970982479': {'genres': ['Action', 'Action', 'Indie'],
#   'tags': ['FPS',
#    'Zombies',
#    'Co-op',
#    'Survival',
#    'Action',
#    'Multiplayer',
#    'Horror',
#    'Online Co-Op',
#    'Shooter',
#    'Gore',
#    'Team-Based',
#    'First-Person',
#    'Moddable',
#    'Survival Horror',
#    'Great Soundtrack',
#    'Singleplayer',
#    'Class-Based',
#    'Difficult',
#    'Comedy',
#    'Adventure',
#    'Action',
#    'Indie',
#    'Surreal',
#    "Beat 'em up",
#    'FPS',
#    'Fighting',
#    'First-Person',
#    'Short',
#    'Singleplayer',
#    'Adventure',
#    'Fantasy',
#    'Atmospheric',
#    'Story Rich'],
#   'specs': ['Single-player',
#    'Multi-player',
#    'Co-op',
#    'Cross-Platform Multiplayer',
#    'Steam Achievements',
#    'Steam Trading Cards',
#    'Steam Workshop',
#    'Valve Anti-Cheat enabled',
#    'Stats',
#    'Includes level editor',
#    'Single-player',
#    'Steam Achievements',
#    'Steam Trading Cards',
#    'Steam Cloud']},
#  'js41637': {'genres': ['Indie', 'Simulation', 'Adventure', 'Indie'],
#   'tags': ['Simulation',
#    'Driving',
#    'Open World',
#    'Realistic',
#    'Relaxing',
#    'Singleplayer',
#    'Exploration',
#    'Moddable',
#    'First-Person',
#    'Economy',
#    'Indie',
#    'Adventure',
#    'Atmospheric',
#    'Management',
#    'TrackIR',
#    'Casual',
#    'Sandbox',
#    'Racing',
#    'Action',
#    'RPG',
#    'Indie',
#    'Political',
#    'Simulation',
#    'Point & Click',
#    'Singleplayer',
#    'Dystopian',
#    'Puzzle',
#    'Pixel Graphics',
#    'Retro',
#    'Multiple Endings',
#    'Atmospheric',
#    'Adventure',
#    'Story Rich',
#    'Strategy',
#    'Casual',
#    '2D',
#    'Great Soundtrack',
#    'Replay Value',
#    'Difficult',
#    'Surreal'],
#   'specs': ['Single-player',
#    'Steam Achievements',
#    'Steam Trading Cards',
#    'Steam Workshop',
#    'Partial Controller Support',
#    'Includes level editor',
#    'Single-player',
#    'Steam Achievements',
#    'Steam Trading Cards',
#    'Steam Cloud',
#    'Stats',
#    'Steam Leaderboards']},
#  'evcentric': {'genres': ['Action',
#    'Indie',
#    'RPG',
#    'Indie',
#    'Simulation',
#    'Action',
#    'Indie',
#    'RPG',
#    'Action',
#    'Indie',
#    'RPG',
#    'Action',
#    'Indie',
#    'RPG',
#    'Strategy',
#    'Indie',
#    'Simulation',
#    'Strategy'],
#   'tags': ['Rogue-like',
#    'Indie',
#    'Platformer',
#    'Action',
#    'Pixel Graphics',
#    'Great Soundtrack',
#    'Online Co-Op',
#    'Difficult',
#    'Perma Death',
#    'Co-op',
#    '2D',
#    'Local Co-Op',
#    'Rogue-lite',
#    'Multiplayer',
#    'RPG',
#    'Singleplayer',
#    'Replay Value',
#    'Survival',
#    'Sci-fi',
#    'Side Scroller',
#    'Programming',
#    'Puzzle',
#    'Indie',
#    'Simulation',
#    'Difficult',
#    'Hacking',
#    'Singleplayer',
#    'Education',
#    'Great Soundtrack',
#    'Female Protagonist',
#    'Indie',
#    'Cyberpunk',
#    'Sci-fi',
#    'Story Rich',
#    'Action RPG',
#    'RPG',
#    'Singleplayer',
#    'Isometric',
#    'Atmospheric',
#    'Action',
#    'Narration',
#    'Strategy',
#    'Adventure',
#    'Tactical',
#    'Turn-Based',
#    'Hack and Slash',
#    'Short',
#    '2D',
#    'RPG',
#    'Indie',
#    'Action',
#    'FPS',
#    'Open World',
#    'Sci-fi',
#    'Futuristic',
#    'Procedural Generation',
#    'Singleplayer',
#    'First-Person',
#    'Pixel Graphics',
#    'Shooter',
#    'Retro',
#    'Rogue-like',
#    'Space',
#    'Action',
#    'Indie',
#    'Sci-fi',
#    'Strategy',
#    'Top-Down',
#    'RPG',
#    'Zombies',
#    'Procedural Generation',
#    'Singleplayer',
#    'Open World',
#    '2D',
#    'Pirates',
#    'Exploration',
#    'Shooter',
#    'Sandbox',
#    'Adventure',
#    'RTS',
#    'Sandbox',
#    'Strategy',
#    'City Builder',
#    'Simulation',
#    'Indie',
#    'Survival',
#    'Building',
#    'Crafting',
#    'Singleplayer',
#    'Isometric',
#    'Fantasy',
#    'Resource Management',
#    'Pixel Graphics',
#    'RTS',
#    '2D',
#    'Management',
#    'Base Building',
#    'Replay Value',
#    'Rogue-like',
#    'Difficult'],
#   'specs': ['Single-player',
#    'Multi-player',
#    'Co-op',
#    'Shared/Split Screen',
#    'Steam Achievements',
#    'Steam Trading Cards',
#    'Partial Controller Support',
#    'Single-player',
#    'Steam Achievements',
#    'Steam Cloud',
#    'Steam Leaderboards',
#    'Includes level editor',
#    'Single-player',
#    'Steam Achievements',
#    'Full controller support',
#    'Steam Trading Cards',
#    'Steam Cloud',
#    'Single-player',
#    'Co-op',
#    'Steam Trading Cards',
#    'Single-player',
#    'Steam Achievements',
#    'Steam Trading Cards',
#    'Steam Cloud',
#    'Stats',
#    'Single-player',
#    'Steam Trading Cards',
#    'Steam Workshop']},
#  'doctr': {'genres': ['Adventure',
#    'RPG',
#    'Action',
#    'Action',
#    'Free to Play',
#    'Massively Multiplayer',
#    'RPG',
#    'Adventure',
#    'Action',
#    'Adventure'],
#   'tags': ['Adventure',
#    'Detective',
#    'Episodic',
#    'Story Rich',
#    'Point & Click',
#    'Noir',
#    'Mature',
#    'Comic Book',
#    'Singleplayer',
#    'Atmospheric',
#    'Mystery',
#    'Choose Your Own Adventure',
#    'Dark',
#    'Cinematic',
#    'Fantasy',
#    'Quick-Time Events',
#    'Great Soundtrack',
#    'Nudity',
#    'Cartoony',
#    'Action',
#    'RPG',
#    'Fantasy',
#    'Mature',
#    'Choices Matter',
#    'Story Rich',
#    'Third Person',
#    'Singleplayer',
#    'Dark Fantasy',
#    'Adventure',
#    'Nudity',
#    'Multiple Endings',
#    'Action',
#    'Atmospheric',
#    'Based On A Novel',
#    'Open World',
#    'Difficult',
#    'Dark',
#    'Medieval',
#    'Magic',
#    'Nonlinear',
#    'Action',
#    'Third-Person Shooter',
#    'Bullet Time',
#    'Multiplayer',
#    'Story Rich',
#    'Cinematic',
#    'Noir',
#    'Third Person',
#    'Shooter',
#    'Singleplayer',
#    'Great Soundtrack',
#    'Atmospheric',
#    'Violent',
#    'Adventure',
#    'Nudity',
#    'Linear',
#    'Dark',
#    '3D Vision',
#    'Open World',
#    'Co-op',
#    'Free to Play',
#    'Action',
#    'Open World',
#    'Massively Multiplayer',
#    'Third-Person Shooter',
#    'Multiplayer',
#    'RPG',
#    'Co-op',
#    'Shooter',
#    'Sci-fi',
#    'Survival',
#    'Post-apocalyptic',
#    'FPS',
#    'Online Co-Op',
#    'Adventure',
#    'Third Person',
#    'MMORPG',
#    'First-Person',
#    'Singleplayer',
#    'Casual',
#    'Zombies',
#    'Adventure',
#    'Story Rich',
#    'Point & Click',
#    'Episodic',
#    'Singleplayer',
#    'Horror',
#    'Choices Matter',
#    'Mature',
#    'Drama',
#    'Atmospheric',
#    'Comic Book',
#    'Choose Your Own Adventure',
#    'Survival',
#    'Post-apocalyptic',
#    'Quick-Time Events',
#    'Gore',
#    'Action',
#    'Third Person',
#    'Visual Novel',
#    'Action',
#    'Horror',
#    'Adventure',
#    'Third Person',
#    'Story Rich',
#    'Atmospheric',
#    'Singleplayer',
#    'Psychological Horror',
#    'Thriller',
#    'Great Soundtrack',
#    'Episodic',
#    'Mystery',
#    'Third-Person Shooter',
#    'Dark',
#    'Cinematic',
#    'Supernatural',
#    'Narration',
#    'Survival Horror',
#    'Shooter',
#    'Survival'],
#   'specs': ['Single-player',
#    'Steam Achievements',
#    'Full controller support',
#    'Single-player',
#    'Steam Achievements',
#    'Steam Trading Cards',
#    'Partial Controller Support',
#    'Steam Cloud',
#    'Steam Leaderboards',
#    'Single-player',
#    'Multi-player',
#    'Steam Achievements',
#    'Partial Controller Support',
#    'Multi-player',
#    'MMO',
#    'Co-op',
#    'Steam Trading Cards',
#    'Partial Controller Support',
#    'Single-player',
#    'Steam Achievements',
#    'Full controller support',
#    'Steam Trading Cards',
#    'Single-player',
#    'Steam Achievements',
#    'Full controller support',
#    'Steam Trading Cards',
#    'Steam Cloud']},
#  'maplemage': {'genres': ['Action',
#    'RPG',
#    'Action',
#    'Adventure',
#    'Casual',
#    'Indie',
#    'RPG',
#    'Action',
#    'Action',
#    'Free to Play',
#    'Indie',
#    'Strategy'],
#   'tags': ['RPG',
#    'Dark Fantasy',
#    'Difficult',
#    'Action',
#    'Exploration',
#    'Fantasy',
#    'Lore-Rich',
#    'Adventure',
#    'Atmospheric',
#    'Third Person',
#    'Action RPG',
#    'Replay Value',
#    'Open World',
#    'Dark',
#    'Multiplayer',
#    'Great Soundtrack',
#    'Story Rich',
#    'Singleplayer',
#    'Character Customization',
#    'Medieval',
#    'Sandbox',
#    'Adventure',
#    'Survival',
#    'Indie',
#    'Crafting',
#    'Space',
#    'Multiplayer',
#    'Building',
#    'Pixel Graphics',
#    '2D',
#    'RPG',
#    'Exploration',
#    'Action',
#    'Open World',
#    'Platformer',
#    'Sci-fi',
#    'Co-op',
#    'Singleplayer',
#    'Atmospheric',
#    'Great Soundtrack',
#    'FPS',
#    'Multiplayer',
#    'Shooter',
#    'Action',
#    'Team-Based',
#    'Competitive',
#    'Tactical',
#    'First-Person',
#    'e-sports',
#    'PvP',
#    'Online Co-Op',
#    'Military',
#    'Co-op',
#    'Strategy',
#    'War',
#    'Trading',
#    'Realistic',
#    'Difficult',
#    'Fast-Paced',
#    'Moddable',
#    'MOBA',
#    'Multiplayer',
#    'Platformer',
#    '2D',
#    'Action',
#    'Indie',
#    'Local Co-Op',
#    'Co-op',
#    'Great Soundtrack',
#    'Strategy',
#    'Controller',
#    'Sci-fi',
#    'Local Multiplayer',
#    'Free to Play',
#    'Online Co-Op',
#    'Space',
#    'Competitive',
#    'Cartoon',
#    'Side Scroller',
#    'Funny'],
#   'specs': ['Single-player',
#    'Multi-player',
#    'Steam Achievements',
#    'Partial Controller Support',
#    'Single-player',
#    'Multi-player',
#    'Online Multi-Player',
#    'Co-op',
#    'Online Co-op',
#    'Cross-Platform Multiplayer',
#    'Steam Achievements',
#    'Steam Trading Cards',
#    'Steam Workshop',
#    'Multi-player',
#    'Steam Achievements',
#    'Full controller support',
#    'Steam Trading Cards',
#    'Steam Workshop',
#    'In-App Purchases',
#    'Valve Anti-Cheat enabled',
#    'Stats',
#    'Single-player',
#    'Multi-player',
#    'Co-op',
#    'Shared/Split Screen',
#    'Steam Achievements',
#    'Full controller support',
#    'Steam Trading Cards',
#    'Steam Workshop',
#    'Steam Cloud',
#    'Valve Anti-Cheat enabled',
#    'Steam Leaderboards',
#    'Includes level editor']},
#  'Wackky': {'genres': ['Action',
#    'Adventure',
#    'Adventure',
#    'Action',
#    'Action',
#    'Indie',
#    'RPG',
#    'Strategy',
#    'Action'],
#   'tags': ['LEGO',
#    'Open World',
#    'Superhero',
#    'Adventure',
#    'Action',
#    'Local Co-Op',
#    'Comedy',
#    'Family Friendly',
#    'Funny',
#    'Comic Book',
#    'Singleplayer',
#    'Co-op',
#    'Third Person',
#    'Local Multiplayer',
#    'Split Screen',
#    'Casual',
#    'Multiplayer',
#    'Puzzle',
#    'Sandbox',
#    'Platformer',
#    'Zombies',
#    'Adventure',
#    'Story Rich',
#    'Point & Click',
#    'Episodic',
#    'Singleplayer',
#    'Horror',
#    'Choices Matter',
#    'Mature',
#    'Drama',
#    'Atmospheric',
#    'Comic Book',
#    'Choose Your Own Adventure',
#    'Survival',
#    'Post-apocalyptic',
#    'Quick-Time Events',
#    'Gore',
#    'Action',
#    'Third Person',
#    'Visual Novel',
#    'Zombies',
#    'Co-op',
#    'FPS',
#    'Multiplayer',
#    'Action',
#    'Online Co-Op',
#    'Shooter',
#    'Survival',
#    'First-Person',
#    'Horror',
#    'Team-Based',
#    'Moddable',
#    'Gore',
#    'Survival Horror',
#    'Post-apocalyptic',
#    'Singleplayer',
#    'Adventure',
#    'Local Co-Op',
#    'Tactical',
#    'Replay Value',
#    'Tower Defense',
#    'RPG',
#    'Strategy',
#    'Co-op',
#    'Action',
#    'Online Co-Op',
#    'Multiplayer',
#    'Fantasy',
#    'Indie',
#    'Third Person',
#    'Local Co-Op',
#    'Singleplayer',
#    'Local Multiplayer',
#    '4 Player Local',
#    'Split Screen',
#    'Action RPG',
#    'Hack and Slash',
#    'Loot',
#    'Third-Person Shooter',
#    'Survival',
#    'FPS',
#    'Action',
#    'Sci-fi',
#    'Singleplayer',
#    'Classic',
#    'Story Rich',
#    'Shooter',
#    'Adventure',
#    'First-Person',
#    'Dystopian',
#    'Atmospheric',
#    'Zombies',
#    'Aliens',
#    'Great Soundtrack',
#    'Silent Protagonist',
#    'Physics',
#    'Multiplayer',
#    'Horror',
#    'Moddable',
#    'Puzzle'],
#   'specs': ['Single-player',
#    'Shared/Split Screen',
#    'Steam Achievements',
#    'Full controller support',
#    'Steam Cloud',
#    'Single-player',
#    'Steam Achievements',
#    'Full controller support',
#    'Steam Trading Cards',
#    'Single-player',
#    'Multi-player',
#    'Co-op',
#    'Steam Achievements',
#    'Full controller support',
#    'Steam Trading Cards',
#    'Captions available',
#    'Steam Workshop',
#    'Steam Cloud',
#    'Valve Anti-Cheat enabled',
#    'Stats',
#    'Includes Source SDK',
#    'Commentary available',
#    'Single-player',
#    'Multi-player',
#    'Co-op',
#    'Shared/Split Screen',
#    'Steam Achievements',
#    'Full controller support',
#    'Steam Workshop',
#    'Steam Cloud',
#    'Valve Anti-Cheat enabled',
#    'Steam Leaderboards',
#    'Single-player',
#    'Steam Achievements',
#    'Steam Trading Cards',
#    'Captions available',
#    'Partial Controller Support',
#    'Steam Cloud',
#    'Includes Source SDK']},
#  '76561198079601835': {'genres': ['Action'],
#   'tags': ['FPS',
#    'Multiplayer',
#    'Shooter',
#    'Action',
#    'Team-Based',
#    'Competitive',
#    'Tactical',
#    'First-Person',
#    'e-sports',
#    'PvP',
#    'Online Co-Op',
#    'Military',
#    'Co-op',
#    'Strategy',
#    'War',
#    'Trading',
#    'Realistic',
#    'Difficult',
#    'Fast-Paced',
#    'Moddable'],
#   'specs': ['Multi-player',
#    'Steam Achievements',
#    'Full controller support',
#    'Steam Trading Cards',
#    'Steam Workshop',
#    'In-App Purchases',
#    'Valve Anti-Cheat enabled',
#    'Stats']},
#  'MeaTCompany': {'genres': ['Action'],
#   'tags': ['FPS',
#    'Multiplayer',
#    'Shooter',
#    'Action',
#    'Team-Based',
#    'Competitive',
#    'Tactical',
#    'First-Person',
#    'e-sports',
#    'PvP',
#    'Online Co-Op',
#    'Military',
#    'Co-op',
#    'Strategy',
#    'War',
#    'Trading',
#    'Realistic',
#    'Difficult',
#    'Fast-Paced',
#    'Moddable'],
#   'specs': ['Multi-player',
#    'Steam Achievements',
#    'Full controller support',
#    'Steam Trading Cards',
#    'Steam Workshop',
#    'In-App Purchases',
#    'Valve Anti-Cheat enabled',
#    'Stats']},
#  '76561198089393905': {'genres': ['Action', 'Free to Play'],
#   'tags': ['Free to Play',
#    'Multiplayer',
#    'FPS',
#    'Action',
#    'Shooter',
#    'Class-Based',
#    'Team-Based',
#    'Funny',
#    'First-Person',
#    'Trading',
#    'Cartoony',
#    'Competitive',
#    'Online Co-Op',
#    'Co-op',
#    'Robots',
#    'Comedy',
#    'Tactical',
#    'Crafting',
#    'Cartoon',
#    'Moddable'],
#   'specs': ['Multi-player',
#    'Cross-Platform Multiplayer',
#    'Steam Achievements',
#    'Steam Trading Cards',
#    'Captions available',
#    'Steam Workshop',
#    'In-App Purchases',
#    'Partial Controller Support',
#    'Valve Anti-Cheat enabled',
#    'Stats',
#    'Includes level editor',
#    'Commentary available']},
#  '76561198156664158': {'genres': ['Action', 'Indie', 'Racing', 'Sports'],
#   'tags': ['Multiplayer',
#    'Racing',
#    'Soccer',
#    'Sports',
#    'Competitive',
#    'Team-Based',
#    'Online Co-Op',
#    'Football',
#    'Action',
#    'Co-op',
#    'Fast-Paced',
#    'Funny',
#    'Local Multiplayer',
#    'Great Soundtrack',
#    'Split Screen',
#    'Local Co-Op',
#    'Singleplayer',
#    '4 Player Local',
#    'Casual',
#    'Indie'],
#   'specs': ['Single-player',
#    'Multi-player',
#    'Co-op',
#    'Shared/Split Screen',
#    'Cross-Platform Multiplayer',
#    'Steam Achievements',
#    'Full controller support',
#    'Steam Trading Cards',
#    'Steam Workshop',
#    'Steam Cloud',
#    'Stats']},
#  '76561198077246154': {'genres': ['Action',
#    'Free to Play',
#    'Action',
#    'Adventure',
#    'Casual',
#    'Free to Play',
#    'Indie'],
#   'tags': ['Free to Play',
#    'Multiplayer',
#    'FPS',
#    'Action',
#    'Shooter',
#    'Class-Based',
#    'Team-Based',
#    'Funny',
#    'First-Person',
#    'Trading',
#    'Cartoony',
#    'Competitive',
#    'Online Co-Op',
#    'Co-op',
#    'Robots',
#    'Comedy',
#    'Tactical',
#    'Crafting',
#    'Cartoon',
#    'Moddable',
#    'Free to Play',
#    'Survival',
#    'Zombies',
#    'Multiplayer',
#    'Open World',
#    'Adventure',
#    'Crafting',
#    'Action',
#    'First-Person',
#    'Co-op',
#    'Sandbox',
#    'Post-apocalyptic',
#    'Shooter',
#    'FPS',
#    'Singleplayer',
#    'Massively Multiplayer',
#    'Indie',
#    'Atmospheric',
#    'Casual',
#    'Horror'],
#   'specs': ['Multi-player',
#    'Cross-Platform Multiplayer',
#    'Steam Achievements',
#    'Steam Trading Cards',
#    'Captions available',
#    'Steam Workshop',
#    'In-App Purchases',
#    'Partial Controller Support',
#    'Valve Anti-Cheat enabled',
#    'Stats',
#    'Includes level editor',
#    'Commentary available',
#    'Single-player',
#    'Online Multi-Player',
#    'Online Co-op',
#    'Steam Achievements',
#    'Steam Trading Cards',
#    'Steam Workshop',
#    'In-App Purchases',
#    'Steam Cloud',
#    'Valve Anti-Cheat enabled',
#    'Stats',
#    'Includes level editor']},
#  'WeiEDKrSat': {'genres': ['Indie', 'Simulation'],
#   'tags': ['Sandbox',
#    'Multiplayer',
#    'Funny',
#    'Moddable',
#    'Building',
#    'Co-op',
#    'Comedy',
#    'First-Person',
#    'Mod',
#    'Simulation',
#    'Online Co-Op',
#    'FPS',
#    'Singleplayer',
#    'Physics',
#    'Action',
#    'Indie',
#    'Shooter',
#    'Animation & Modeling',
#    'Adventure',
#    'Massively Multiplayer'],
#   'specs': ['Single-player',
#    'Multi-player',
#    'Co-op',
#    'Cross-Platform Multiplayer',
#    'Steam Achievements',
#    'Steam Trading Cards',
#    'Captions available',
#    'Steam Workshop',
#    'Steam Cloud',
#    'Valve Anti-Cheat enabled',
#    'Includes level editor']},
#  'thequeenpanda': {'genres': ['Action', 'RPG'],
#   'tags': ['Comedy',
#    'Action',
#    'Co-op',
#    'Fantasy',
#    'RPG',
#    'Multiplayer',
#    'Online Co-Op',
#    'Adventure',
#    'Magic',
#    'Funny',
#    'Local Co-Op',
#    '4 Player Local',
#    'Indie',
#    'Local Multiplayer',
#    'Difficult',
#    'Singleplayer',
#    'Team-Based',
#    'Action RPG',
#    'Strategy',
#    'Arcade'],
#   'specs': ['Single-player',
#    'Multi-player',
#    'Co-op',
#    'Shared/Split Screen',
#    'Steam Achievements',
#    'Full controller support',
#    'Steam Trading Cards',
#    'Steam Leaderboards']},
#  'death-hunter': {'genres': ['Action', 'Action', 'Indie', 'Simulation'],
#   'tags': ['Zombies',
#    'Co-op',
#    'Gore',
#    'FPS',
#    'Survival',
#    'Action',
#    'Horror',
#    'Multiplayer',
#    'Online Co-Op',
#    'Shooter',
#    'First-Person',
#    'Team-Based',
#    'Survival Horror',
#    'Great Soundtrack',
#    'Atmospheric',
#    'Difficult',
#    'Singleplayer',
#    'Indie',
#    'Funny',
#    'Blood',
#    'FPS',
#    'Zombies',
#    'Co-op',
#    'Survival',
#    'Action',
#    'Multiplayer',
#    'Horror',
#    'Online Co-Op',
#    'Shooter',
#    'Gore',
#    'Team-Based',
#    'First-Person',
#    'Moddable',
#    'Survival Horror',
#    'Great Soundtrack',
#    'Singleplayer',
#    'Class-Based',
#    'Difficult',
#    'Comedy',
#    'Adventure',
#    'Sandbox',
#    'Multiplayer',
#    'Funny',
#    'Moddable',
#    'Building',
#    'Co-op',
#    'Comedy',
#    'First-Person',
#    'Mod',
#    'Simulation',
#    'Online Co-Op',
#    'FPS',
#    'Singleplayer',
#    'Physics',
#    'Action',
#    'Indie',
#    'Shooter',
#    'Animation & Modeling',
#    'Adventure',
#    'Massively Multiplayer'],
#   'specs': ['Single-player',
#    'Multi-player',
#    'Online Multi-Player',
#    'Co-op',
#    'Online Co-op',
#    'Steam Achievements',
#    'Full controller support',
#    'Steam Trading Cards',
#    'Steam Workshop',
#    'In-App Purchases',
#    'Valve Anti-Cheat enabled',
#    'Includes level editor',
#    'Single-player',
#    'Multi-player',
#    'Co-op',
#    'Cross-Platform Multiplayer',
#    'Steam Achievements',
#    'Steam Trading Cards',
#    'Steam Workshop',
#    'Valve Anti-Cheat enabled',
#    'Stats',
#    'Includes level editor',
#    'Single-player',
#    'Multi-player',
#    'Co-op',
#    'Cross-Platform Multiplayer',
#    'Steam Achievements',
#    'Steam Trading Cards',
#    'Captions available',
#    'Steam Workshop',
#    'Steam Cloud',
#    'Valve Anti-Cheat enabled',
#    'Includes level editor']},
#  'DJKamBer': {'genres': ['Action',
#    'Adventure',
#    'Casual',
#    'Free to Play',
#    'Indie',
#    'Action',
#    'Free to Play',
#    'Indie',
#    'Action',
#    'Action',
#    'Free to Play'],
#   'tags': ['Free to Play',
#    'Survival',
#    'Zombies',
#    'Multiplayer',
#    'Open World',
#    'Adventure',
#    'Crafting',
#    'Action',
#    'First-Person',
#    'Co-op',
#    'Sandbox',
#    'Post-apocalyptic',
#    'Shooter',
#    'FPS',
#    'Singleplayer',
#    'Massively Multiplayer',
#    'Indie',
#    'Atmospheric',
#    'Casual',
#    'Horror',
#    'Free to Play',
#    'MOBA',
#    'Strategy',
#    'Multiplayer',
#    'Team-Based',
#    'Action',
#    'e-sports',
#    'Online Co-Op',
#    'Competitive',
#    'PvP',
#    'RTS',
#    'Difficult',
#    'RPG',
#    'Fantasy',
#    'Tower Defense',
#    'Co-op',
#    'Character Customization',
#    'Replay Value',
#    'Action RPG',
#    'Simulation',
#    'Co-op',
#    'Action',
#    'FPS',
#    'Heist',
#    'Online Co-Op',
#    'Multiplayer',
#    'Stealth',
#    'Crime',
#    'Team-Based',
#    'Shooter',
#    'First-Person',
#    'Great Soundtrack',
#    'Gun Customization',
#    'Tactical',
#    'PvE',
#    'Strategy',
#    'Singleplayer',
#    'Simulation',
#    'Funny',
#    'Adventure',
#    'Free to Play',
#    'Zombies',
#    'Multiplayer',
#    'Survival',
#    'Horror',
#    'Co-op',
#    'Action',
#    'Online Co-Op',
#    'FPS',
#    'First-Person',
#    'Shooter',
#    'Survival Horror',
#    'Post-apocalyptic',
#    'Open World',
#    'Realistic',
#    'Indie',
#    'Atmospheric',
#    'Mod',
#    'Adventure',
#    'Massively Multiplayer',
#    'FPS',
#    'Zombies',
#    'Co-op',
#    'Survival',
#    'Action',
#    'Multiplayer',
#    'Horror',
#    'Online Co-Op',
#    'Shooter',
#    'Gore',
#    'Team-Based',
#    'First-Person',
#    'Moddable',
#    'Survival Horror',
#    'Great Soundtrack',
#    'Singleplayer',
#    'Class-Based',
#    'Difficult',
#    'Comedy',
#    'Adventure',
#    'Free to Play',
#    'Multiplayer',
#    'FPS',
#    'Action',
#    'Shooter',
#    'Class-Based',
#    'Team-Based',
#    'Funny',
#    'First-Person',
#    'Trading',
#    'Cartoony',
#    'Competitive',
#    'Online Co-Op',
#    'Co-op',
#    'Robots',
#    'Comedy',
#    'Tactical',
#    'Crafting',
#    'Cartoon',
#    'Moddable'],
#   'specs': ['Single-player',
#    'Online Multi-Player',
#    'Online Co-op',
#    'Steam Achievements',
#    'Steam Trading Cards',
#    'Steam Workshop',
#    'In-App Purchases',
#    'Steam Cloud',
#    'Valve Anti-Cheat enabled',
#    'Stats',
#    'Includes level editor',
#    'Multi-player',
#    'Co-op',
#    'Steam Trading Cards',
#    'Steam Workshop',
#    'SteamVR Collectibles',
#    'In-App Purchases',
#    'Valve Anti-Cheat enabled',
#    'HTC Vive',
#    'Tracked Motion Controllers',
#    'Seated',
#    'Standing',
#    'Room-Scale',
#    'Single-player',
#    'Multi-player',
#    'Co-op',
#    'Online Co-op',
#    'Steam Achievements',
#    'Full controller support',
#    'Steam Trading Cards',
#    'In-App Purchases',
#    'HTC Vive',
#    'Multi-player',
#    'Co-op',
#    'Cross-Platform Multiplayer',
#    'Steam Achievements',
#    'Captions available',
#    'Partial Controller Support',
#    'Valve Anti-Cheat enabled',
#    'Includes level editor',
#    'Includes Source SDK',
#    'Single-player',
#    'Multi-player',
#    'Co-op',
#    'Cross-Platform Multiplayer',
#    'Steam Achievements',
#    'Steam Trading Cards',
#    'Steam Workshop',
#    'Valve Anti-Cheat enabled',
#    'Stats',
#    'Includes level editor',
#    'Multi-player',
#    'Cross-Platform Multiplayer',
#    'Steam Achievements',
#    'Steam Trading Cards',
#    'Captions available',
#    'Steam Workshop',
#    'In-App Purchases',
#    'Partial Controller Support',
#    'Valve Anti-Cheat enabled',
#    'Stats',
#    'Includes level editor',
#    'Commentary available']},
#  'Rainbow-Dashie': {'genres': ['Action',
#    'Action',
#    'Free to Play',
#    'Action',
#    'RPG'],
#   'tags': ['FPS',
#    'Multiplayer',
#    'Shooter',
#    'Action',
#    'Team-Based',
#    'Competitive',
#    'Tactical',
#    'First-Person',
#    'e-sports',
#    'PvP',
#    'Online Co-Op',
#    'Military',
#    'Co-op',
#    'Strategy',
#    'War',
#    'Trading',
#    'Realistic',
#    'Difficult',
#    'Fast-Paced',
#    'Moddable',
#    'Free to Play',
#    'Multiplayer',
#    'FPS',
#    'Action',
#    'Shooter',
#    'Class-Based',
#    'Team-Based',
#    'Funny',
#    'First-Person',
#    'Trading',
#    'Cartoony',
#    'Competitive',
#    'Online Co-Op',
#    'Co-op',
#    'Robots',
#    'Comedy',
#    'Tactical',
#    'Crafting',
#    'Cartoon',
#    'Moddable',
#    'FPS',
#    'Co-op',
#    'Action',
#    'RPG',
#    'Loot',
#    'Shooter',
#    'Open World',
#    'Funny',
#    'Multiplayer',
#    'Comedy',
#    'Adventure',
#    'Action RPG',
#    'Online Co-Op',
#    'Memes',
#    'Stylized',
#    'Sci-fi',
#    'Futuristic',
#    'Dark Humor',
#    'Singleplayer',
#    'Atmospheric'],
#   'specs': ['Multi-player',
#    'Steam Achievements',
#    'Full controller support',
#    'Steam Trading Cards',
#    'Steam Workshop',
#    'In-App Purchases',
#    'Valve Anti-Cheat enabled',
#    'Stats',
#    'Multi-player',
#    'Cross-Platform Multiplayer',
#    'Steam Achievements',
#    'Steam Trading Cards',
#    'Captions available',
#    'Steam Workshop',
#    'In-App Purchases',
#    'Partial Controller Support',
#    'Valve Anti-Cheat enabled',
#    'Stats',
#    'Includes level editor',
#    'Commentary available',
#    'Single-player',
#    'Co-op',
#    'Steam Achievements',
#    'Full controller support',
#    'Steam Trading Cards',
#    'Steam Cloud']},
#  '76561198043472122': {'genres': [], 'tags': [], 'specs': []},
#  'MarbleShrine': {'genres': ['Indie', 'Simulation'],
#   'tags': ['Space',
#    'Simulation',
#    'Sandbox',
#    'Physics',
#    'Science',
#    'Space Sim',
#    'Building',
#    'Indie',
#    'Moddable',
#    'Education',
#    'Singleplayer',
#    'Open World',
#    'Exploration',
#    'Funny',
#    'Sci-fi',
#    'Adventure',
#    'Strategy',
#    'Difficult',
#    'Replay Value',
#    'Comedy'],
#   'specs': ['Single-player', 'Steam Trading Cards']},
#  'PPanther': {'genres': ['Action', 'Adventure', 'Casual', 'Indie', 'RPG'],
#   'tags': ['Sandbox',
#    'Adventure',
#    'Survival',
#    'Indie',
#    'Crafting',
#    'Space',
#    'Multiplayer',
#    'Building',
#    'Pixel Graphics',
#    '2D',
#    'RPG',
#    'Exploration',
#    'Action',
#    'Open World',
#    'Platformer',
#    'Sci-fi',
#    'Co-op',
#    'Singleplayer',
#    'Atmospheric',
#    'Great Soundtrack'],
#   'specs': ['Single-player',
#    'Multi-player',
#    'Online Multi-Player',
#    'Co-op',
#    'Online Co-op',
#    'Cross-Platform Multiplayer',
#    'Steam Achievements',
#    'Steam Trading Cards',
#    'Steam Workshop']},
#  'devvonst': {'genres': ['Action',
#    'Free to Play',
#    'Adventure',
#    'Indie',
#    'Action'],
#   'tags': ['Free to Play',
#    'Multiplayer',
#    'FPS',
#    'Action',
#    'Shooter',
#    'Class-Based',
#    'Team-Based',
#    'Funny',
#    'First-Person',
#    'Trading',
#    'Cartoony',
#    'Competitive',
#    'Online Co-Op',
#    'Co-op',
#    'Robots',
#    'Comedy',
#    'Tactical',
#    'Crafting',
#    'Cartoon',
#    'Moddable',
#    'Indie',
#    'Platformer',
#    'Adventure',
#    'Puzzle',
#    'Singleplayer',
#    'Difficult',
#    'Local Co-Op',
#    'Co-op',
#    'Great Soundtrack',
#    'Atmospheric',
#    'Side Scroller',
#    '2D',
#    'Stealth',
#    'Local Multiplayer',
#    'Zombies',
#    'Co-op',
#    'FPS',
#    'Multiplayer',
#    'Action',
#    'Online Co-Op',
#    'Shooter',
#    'Survival',
#    'First-Person',
#    'Horror',
#    'Team-Based',
#    'Moddable',
#    'Gore',
#    'Survival Horror',
#    'Post-apocalyptic',
#    'Singleplayer',
#    'Adventure',
#    'Local Co-Op',
#    'Tactical',
#    'Replay Value'],
#   'specs': ['Multi-player',
#    'Cross-Platform Multiplayer',
#    'Steam Achievements',
#    'Steam Trading Cards',
#    'Captions available',
#    'Steam Workshop',
#    'In-App Purchases',
#    'Partial Controller Support',
#    'Valve Anti-Cheat enabled',
#    'Stats',
#    'Includes level editor',
#    'Commentary available',
#    'Single-player',
#    'Shared/Split Screen',
#    'Steam Achievements',
#    'Full controller support',
#    'Single-player',
#    'Multi-player',
#    'Co-op',
#    'Steam Achievements',
#    'Full controller support',
#    'Steam Trading Cards',
#    'Captions available',
#    'Steam Workshop',
#    'Steam Cloud',
#    'Valve Anti-Cheat enabled',
#    'Stats',
#    'Includes Source SDK',
#    'Commentary available']},
#  'Fr0stedLine': {'genres': ['Action'],
#   'tags': ['FPS',
#    'Action',
#    'Sci-fi',
#    'Singleplayer',
#    'Classic',
#    'Story Rich',
#    'Shooter',
#    'Adventure',
#    'First-Person',
#    'Dystopian',
#    'Atmospheric',
#    'Zombies',
#    'Aliens',
#    'Great Soundtrack',
#    'Silent Protagonist',
#    'Physics',
#    'Multiplayer',
#    'Horror',
#    'Moddable',
#    'Puzzle'],
#   'specs': ['Single-player',
#    'Steam Achievements',
#    'Steam Trading Cards',
#    'Captions available',
#    'Partial Controller Support',
#    'Steam Cloud',
#    'Includes Source SDK']},
#  'starkillershadow553': {'genres': ['Action',
#    'Adventure',
#    'Action',
#    'Indie',
#    'Simulation',
#    'Action'],
#   'tags': ['Sniper',
#    'Action',
#    'Stealth',
#    'Multiplayer',
#    'World War II',
#    'Shooter',
#    'Co-op',
#    'Adventure',
#    'Third-Person Shooter',
#    'Tactical',
#    'Third Person',
#    'War',
#    'Singleplayer',
#    'Online Co-Op',
#    'Open World',
#    'Gore',
#    'Strategy',
#    'FPS',
#    'Atmospheric',
#    'Simulation',
#    'Action',
#    'Simulation',
#    'Flight',
#    'Indie',
#    'Arcade',
#    'Multiplayer',
#    'Singleplayer',
#    'Action',
#    'Top-Down Shooter',
#    'Sci-fi',
#    'Singleplayer',
#    'Top-Down',
#    'Shooter',
#    'Twin Stick Shooter',
#    'Strategy',
#    'Touch-Friendly',
#    'Great Soundtrack',
#    'Adventure',
#    'Arcade',
#    'Futuristic',
#    'Multiplayer',
#    'Third Person',
#    'Aliens',
#    'Space',
#    'Third-Person Shooter',
#    'Isometric',
#    'RTS'],
#   'specs': ['Single-player',
#    'Multi-player',
#    'Co-op',
#    'Steam Achievements',
#    'Full controller support',
#    'Steam Trading Cards',
#    'Steam Cloud',
#    'Steam Leaderboards',
#    'Single-player',
#    'Multi-player',
#    'Steam Achievements',
#    'Full controller support',
#    'Steam Trading Cards',
#    'Steam Workshop',
#    'Includes level editor',
#    'Single-player',
#    'Steam Achievements',
#    'Steam Trading Cards',
#    'Partial Controller Support',
#    'Steam Cloud',
#    'Steam Leaderboards']},
#  '76561198058373434': {'genres': ['Action'],
#   'tags': ['FPS',
#    'Action',
#    'Story Rich',
#    'Singleplayer',
#    'Steampunk',
#    'Atmospheric',
#    'Shooter',
#    'First-Person',
#    'Alternate History',
#    'Adventure',
#    'Great Soundtrack',
#    'Dystopian',
#    'Sci-fi',
#    'Time Travel',
#    'Fantasy',
#    'Gore',
#    'Linear',
#    'RPG',
#    'Political',
#    'Controller'],
#   'specs': ['Single-player',
#    'Steam Achievements',
#    'Full controller support',
#    'Steam Trading Cards',
#    'Steam Cloud']},
#  '76561198048353577': {'genres': ['Indie',
#    'Simulation',
#    'Strategy',
#    'Indie',
#    'Simulation',
#    'Action',
#    'Simulation',
#    'Strategy'],
#   'tags': ['Strategy',
#    'Pixel Graphics',
#    'Survival',
#    '2D',
#    'Indie',
#    'Medieval',
#    'Tower Defense',
#    'Singleplayer',
#    'Side Scroller',
#    'Resource Management',
#    'Great Soundtrack',
#    'Simulation',
#    'City Builder',
#    'Rogue-like',
#    'Atmospheric',
#    'Casual',
#    'Difficult',
#    'Action',
#    'Adventure',
#    'Female Protagonist',
#    'Sandbox',
#    'Multiplayer',
#    'Funny',
#    'Moddable',
#    'Building',
#    'Co-op',
#    'Comedy',
#    'First-Person',
#    'Mod',
#    'Simulation',
#    'Online Co-Op',
#    'FPS',
#    'Singleplayer',
#    'Physics',
#    'Action',
#    'Indie',
#    'Shooter',
#    'Animation & Modeling',
#    'Adventure',
#    'Massively Multiplayer',
#    'Simulation',
#    'Action',
#    'Military',
#    'Multiplayer',
#    'Strategy',
#    'Tactical',
#    'Realistic',
#    'Shooter',
#    'FPS',
#    'Open World',
#    'Moddable',
#    'War',
#    'First-Person',
#    'Team-Based',
#    'Singleplayer',
#    'Co-op',
#    'Sandbox',
#    'Modern',
#    'Difficult',
#    'Third Person'],
#   'specs': ['Single-player',
#    'Steam Achievements',
#    'Full controller support',
#    'Steam Trading Cards',
#    'Steam Cloud',
#    'Single-player',
#    'Multi-player',
#    'Co-op',
#    'Cross-Platform Multiplayer',
#    'Steam Achievements',
#    'Steam Trading Cards',
#    'Captions available',
#    'Steam Workshop',
#    'Steam Cloud',
#    'Valve Anti-Cheat enabled',
#    'Includes level editor',
#    'Single-player',
#    'Multi-player',
#    'Co-op',
#    'Captions available',
#    'Partial Controller Support',
#    'Includes level editor']},
#  '76561198066046412': {'genres': ['Action', 'Indie'],
#   'tags': ['Medieval',
#    'Multiplayer',
#    'Action',
#    'Gore',
#    'First-Person',
#    'Violent',
#    'Swordplay',
#    'PvP',
#    'Indie',
#    'Third Person',
#    'Competitive',
#    'Team-Based',
#    'Hack and Slash',
#    'FPS',
#    'Class-Based',
#    'Historical',
#    'Co-op',
#    'Atmospheric',
#    'Simulation',
#    'Difficult'],
#   'specs': ['Multi-player',
#    'Steam Achievements',
#    'Full controller support',
#    'Steam Trading Cards',
#    'Steam Workshop',
#    'Valve Anti-Cheat enabled',
#    'Includes level editor']},
#  'tru_mu_': {'genres': ['Indie', 'Simulation', 'Strategy'],
#   'tags': ['Strategy',
#    'Simulation',
#    'Indie',
#    'Puzzle',
#    'Minimalist',
#    'Singleplayer',
#    'Trains',
#    'Casual',
#    'Management',
#    '2D',
#    'Relaxing',
#    'Touch-Friendly',
#    'Difficult',
#    'Building',
#    'Great Soundtrack',
#    'Mouse only'],
#   'specs': ['Single-player',
#    'Steam Achievements',
#    'Steam Trading Cards',
#    'Steam Cloud',
#    'Steam Leaderboards']},
#  '76561198070565427': {'genres': ['Action',
#    'Free to Play',
#    'Indie',
#    'Action',
#    'Action',
#    'Free to Play',
#    'Indie'],
#   'tags': ['Co-op',
#    'Action',
#    'FPS',
#    'Heist',
#    'Online Co-Op',
#    'Multiplayer',
#    'Stealth',
#    'Crime',
#    'Team-Based',
#    'Shooter',
#    'First-Person',
#    'Great Soundtrack',
#    'Gun Customization',
#    'Tactical',
#    'PvE',
#    'Strategy',
#    'Singleplayer',
#    'Simulation',
#    'Funny',
#    'Adventure',
#    'Free to Play',
#    'Third-Person Shooter',
#    'Action',
#    'Gore',
#    'Multiplayer',
#    'Gun Customization',
#    'Shooter',
#    'Funny',
#    'Fast-Paced',
#    'Indie',
#    'Comedy',
#    'Mature',
#    'Character Customization',
#    'Third Person',
#    'Cartoony',
#    'Massively Multiplayer',
#    'Co-op',
#    'Crafting',
#    'Arena Shooter',
#    'Casual',
#    'Fighting',
#    'Superhero',
#    'Action',
#    'Multiplayer',
#    'Batman',
#    'Comic Book',
#    'Singleplayer',
#    'Local Multiplayer',
#    'Controller',
#    '2D Fighter',
#    "Beat 'em up",
#    'Arcade',
#    '2.5D',
#    'Competitive',
#    'Story Rich',
#    '2D',
#    'Atmospheric',
#    '3D Vision',
#    'Gore',
#    'Great Soundtrack',
#    'Free to Play',
#    'Zombies',
#    'Multiplayer',
#    'Survival',
#    'Horror',
#    'Co-op',
#    'Action',
#    'Online Co-Op',
#    'FPS',
#    'First-Person',
#    'Shooter',
#    'Survival Horror',
#    'Post-apocalyptic',
#    'Open World',
#    'Realistic',
#    'Indie',
#    'Atmospheric',
#    'Mod',
#    'Adventure',
#    'Massively Multiplayer'],
#   'specs': ['Single-player',
#    'Multi-player',
#    'Co-op',
#    'Online Co-op',
#    'Steam Achievements',
#    'Full controller support',
#    'Steam Trading Cards',
#    'In-App Purchases',
#    'HTC Vive',
#    'Multi-player',
#    'Co-op',
#    'Steam Achievements',
#    'Steam Trading Cards',
#    'Partial Controller Support',
#    'Steam Cloud',
#    'Valve Anti-Cheat enabled',
#    'Single-player',
#    'Multi-player',
#    'Steam Achievements',
#    'Full controller support',
#    'Steam Trading Cards',
#    'Steam Cloud',
#    'Steam Leaderboards',
#    'Multi-player',
#    'Co-op',
#    'Cross-Platform Multiplayer',
#    'Steam Achievements',
#    'Captions available',
#    'Partial Controller Support',
#    'Valve Anti-Cheat enabled',
#    'Includes level editor',
#    'Includes Source SDK']},
#  'SavageEeEe': {'genres': ['Action',
#    'Indie',
#    'Massively Multiplayer',
#    'Early Access'],
#   'tags': ['Early Access',
#    'Survival',
#    'Zombies',
#    'Open World',
#    'Multiplayer',
#    'PvP',
#    'Massively Multiplayer',
#    'Action',
#    'Simulation',
#    'FPS',
#    'Post-apocalyptic',
#    'Survival Horror',
#    'Shooter',
#    'Sandbox',
#    'Indie',
#    'Adventure',
#    'Co-op',
#    'Horror',
#    'Atmospheric',
#    'Military'],
#   'specs': ['Multi-player', 'Steam Cloud', 'Valve Anti-Cheat enabled']},
#  '76561198076909484': {'genres': [],
#   'tags': ['Free to Play',
#    'MOBA',
#    'Strategy',
#    'Multiplayer',
#    'Team-Based',
#    'Action',
#    'e-sports',
#    'Online Co-Op',
#    'Competitive',
#    'PvP',
#    'RTS',
#    'Difficult',
#    'RPG',
#    'Fantasy',
#    'Tower Defense',
#    'Co-op',
#    'Character Customization',
#    'Replay Value',
#    'Action RPG',
#    'Simulation'],
#   'specs': ['Multi-player',
#    'Co-op',
#    'Steam Trading Cards',
#    'Steam Workshop',
#    'SteamVR Collectibles',
#    'In-App Purchases',
#    'Valve Anti-Cheat enabled',
#    'HTC Vive',
#    'Tracked Motion Controllers',
#    'Seated',
#    'Standing',
#    'Room-Scale']},
#  'KanadeTheNeko': {'genres': ['Adventure',
#    'Casual',
#    'Free to Play',
#    'Indie',
#    'Indie',
#    'Simulation'],
#   'tags': ['Visual Novel',
#    'Free to Play',
#    'Story Rich',
#    'Anime',
#    'Great Soundtrack',
#    'Choices Matter',
#    'Singleplayer',
#    'Mature',
#    'Romance',
#    'Multiple Endings',
#    'Nudity',
#    'Dating Sim',
#    'Replay Value',
#    'Adventure',
#    '2D',
#    'Mystery',
#    'Indie',
#    'Comedy',
#    'Classic',
#    'Casual',
#    'Sandbox',
#    'Multiplayer',
#    'Funny',
#    'Moddable',
#    'Building',
#    'Co-op',
#    'Comedy',
#    'First-Person',
#    'Mod',
#    'Simulation',
#    'Online Co-Op',
#    'FPS',
#    'Singleplayer',
#    'Physics',
#    'Action',
#    'Indie',
#    'Shooter',
#    'Animation & Modeling',
#    'Adventure',
#    'Massively Multiplayer'],
#   'specs': ['Single-player',
#    'Steam Achievements',
#    'Partial Controller Support',
#    'Steam Cloud',
#    'Single-player',
#    'Multi-player',
#    'Co-op',
#    'Cross-Platform Multiplayer',
#    'Steam Achievements',
#    'Steam Trading Cards',
#    'Captions available',
#    'Steam Workshop',
#    'Steam Cloud',
#    'Valve Anti-Cheat enabled',
#    'Includes level editor']},
#  'Leaf_Light_Moscow': {'genres': ['Action',
#    'Adventure',
#    'Free to Play',
#    'Massively Multiplayer',
#    'RPG'],
#   'tags': ['Free to Play',
#    'MMORPG',
#    'Massively Multiplayer',
#    'RPG',
#    'Action',
#    'Open World',
#    'Fantasy',
#    'Adventure',
#    'Anime',
#    'Third Person',
#    'Action RPG',
#    'Co-op',
#    'Character Customization',
#    'Multiplayer',
#    'PvP',
#    'Hack and Slash',
#    'PvE',
#    'Cute',
#    'Controller',
#    'Nudity'],
#   'specs': ['Multi-player',
#    'MMO',
#    'Co-op',
#    'Steam Trading Cards',
#    'Partial Controller Support']},
#  'GoAwayZach': {'genres': ['Action',
#    'Adventure',
#    'Casual',
#    'Free to Play',
#    'Indie'],
#   'tags': ['Free to Play',
#    'Survival',
#    'Zombies',
#    'Multiplayer',
#    'Open World',
#    'Adventure',
#    'Crafting',
#    'Action',
#    'First-Person',
#    'Co-op',
#    'Sandbox',
#    'Post-apocalyptic',
#    'Shooter',
#    'FPS',
#    'Singleplayer',
#    'Massively Multiplayer',
#    'Indie',
#    'Atmospheric',
#    'Casual',
#    'Horror'],
#   'specs': ['Single-player',
#    'Online Multi-Player',
#    'Online Co-op',
#    'Steam Achievements',
#    'Steam Trading Cards',
#    'Steam Workshop',
#    'In-App Purchases',
#    'Steam Cloud',
#    'Valve Anti-Cheat enabled',
#    'Stats',
#    'Includes level editor']},
#  '76561198054540475': {'genres': ['Action', 'RPG'],
#   'tags': ['Medieval',
#    'RPG',
#    'Open World',
#    'Strategy',
#    'Action',
#    'Sandbox',
#    'Multiplayer',
#    'Moddable',
#    'Military',
#    'Adventure',
#    'Horses',
#    'Realistic',
#    'First-Person',
#    'Historical',
#    'Singleplayer',
#    'Third Person',
#    'Hack and Slash',
#    'Simulation',
#    'Fantasy',
#    'Indie'],
#   'specs': ['Single-player',
#    'Multi-player',
#    'Steam Achievements',
#    'Steam Trading Cards',
#    'Steam Workshop']},
#  '76561198085547365': {'genres': ['Action',
#    'Adventure',
#    'Casual',
#    'Indie',
#    'Indie'],
#   'tags': ['Comedy',
#    'Co-op',
#    'Platformer',
#    'Funny',
#    'Multiplayer',
#    'Indie',
#    'Adventure',
#    'Local Co-Op',
#    '2D',
#    'Action',
#    'Great Soundtrack',
#    'Casual',
#    'Puzzle',
#    'Online Co-Op',
#    'Level Editor',
#    'Local Multiplayer',
#    'Singleplayer',
#    'Difficult',
#    'Team-Based',
#    'Sandbox',
#    'Cult Classic',
#    'Physics',
#    'Indie',
#    'Gore',
#    'Puzzle',
#    'Singleplayer',
#    'Dark',
#    'Co-op',
#    'World War II',
#    'Mature',
#    'Bullet Hell',
#    'Quick-Time Events',
#    'Perma Death',
#    'Choices Matter',
#    'Third-Person Shooter',
#    'Psychedelic',
#    'Sports',
#    'Replay Value',
#    'Violent',
#    'Blood'],
#   'specs': ['Single-player',
#    'Multi-player',
#    'Online Multi-Player',
#    'Local Multi-Player',
#    'Co-op',
#    'Online Co-op',
#    'Local Co-op',
#    'Shared/Split Screen',
#    'Steam Achievements',
#    'Full controller support',
#    'Steam Trading Cards',
#    'Steam Workshop',
#    'Steam Cloud',
#    'Stats',
#    'Steam Leaderboards',
#    'Includes level editor',
#    'Single-player',
#    'Steam Achievements',
#    'Steam Trading Cards']},
#  '76561198061252210': {'genres': ['Action'],
#   'tags': ['FPS',
#    'Multiplayer',
#    'Shooter',
#    'Action',
#    'Team-Based',
#    'Competitive',
#    'Tactical',
#    'First-Person',
#    'e-sports',
#    'PvP',
#    'Online Co-Op',
#    'Military',
#    'Co-op',
#    'Strategy',
#    'War',
#    'Trading',
#    'Realistic',
#    'Difficult',
#    'Fast-Paced',
#    'Moddable'],
#   'specs': ['Multi-player',
#    'Steam Achievements',
#    'Full controller support',
#    'Steam Trading Cards',
#    'Steam Workshop',
#    'In-App Purchases',
#    'Valve Anti-Cheat enabled',
#    'Stats']},
#  'OfficialShroomsy': {'genres': ['Action', 'Adventure', 'Indie', 'RPG'],
#   'tags': ['Rogue-like',
#    'Indie',
#    'Replay Value',
#    'Difficult',
#    'Procedural Generation',
#    'Action',
#    'Dark',
#    'Top-Down',
#    'Great Soundtrack',
#    'Adventure',
#    'Singleplayer',
#    'Rogue-lite',
#    'RPG',
#    'Survival',
#    '2D',
#    'Perma Death',
#    'Dungeon Crawler',
#    'Bullet Hell',
#    'Atmospheric',
#    'Arena Shooter'],
#   'specs': ['Single-player', 'Steam Achievements', 'Steam Trading Cards']},
#  'boydeer': {'genres': ['Action', 'Free to Play'],
#   'tags': ['Free to Play',
#    'Multiplayer',
#    'FPS',
#    'Action',
#    'Shooter',
#    'Class-Based',
#    'Team-Based',
#    'Funny',
#    'First-Person',
#    'Trading',
#    'Cartoony',
#    'Competitive',
#    'Online Co-Op',
#    'Co-op',
#    'Robots',
#    'Comedy',
#    'Tactical',
#    'Crafting',
#    'Cartoon',
#    'Moddable'],
#   'specs': ['Multi-player',
#    'Cross-Platform Multiplayer',
#    'Steam Achievements',
#    'Steam Trading Cards',
#    'Captions available',
#    'Steam Workshop',
#    'In-App Purchases',
#    'Partial Controller Support',
#    'Valve Anti-Cheat enabled',
#    'Stats',
#    'Includes level editor',
#    'Commentary available']},
#  'VVillis': {'genres': ['Action', 'Adventure', 'RPG'],
#   'tags': ['RPG',
#    'Comedy',
#    'Adventure',
#    'Funny',
#    'Turn-Based',
#    'Dark Humor',
#    'Action',
#    'Singleplayer',
#    'Mature',
#    '2D',
#    'Satire',
#    'Nudity',
#    'Cartoon',
#    'Open World',
#    'Story Rich',
#    'Fantasy',
#    'Zombies',
#    'Turn-Based Strategy',
#    'JRPG',
#    'Short'],
#   'specs': ['Single-player', 'Steam Achievements', 'Full controller support']},
#  '76561198083226897': {'genres': ['Action', 'Adventure', 'Indie', 'RPG'],
#   'tags': ['Sandbox',
#    'Adventure',
#    'Survival',
#    '2D',
#    'Multiplayer',
#    'Crafting',
#    'Building',
#    'Exploration',
#    'Pixel Graphics',
#    'Co-op',
#    'Indie',
#    'Open World',
#    'Action',
#    'RPG',
#    'Online Co-Op',
#    'Singleplayer',
#    'Platformer',
#    'Replay Value',
#    'Atmospheric',
#    'Family Friendly'],
#   'specs': ['Single-player',
#    'Multi-player',
#    'Online Multi-Player',
#    'Co-op',
#    'Online Co-op',
#    'Steam Achievements',
#    'Full controller support',
#    'Steam Trading Cards',
#    'Steam Cloud']},
#  '76561198075277292': {'genres': ['Action'],
#   'tags': ['FPS',
#    'Multiplayer',
#    'Shooter',
#    'Action',
#    'Team-Based',
#    'Competitive',
#    'Tactical',
#    'First-Person',
#    'e-sports',
#    'PvP',
#    'Online Co-Op',
#    'Military',
#    'Co-op',
#    'Strategy',
#    'War',
#    'Trading',
#    'Realistic',
#    'Difficult',
#    'Fast-Paced',
#    'Moddable',
#    'Free to Play',
#    'MOBA',
#    'Strategy',
#    'Multiplayer',
#    'Team-Based',
#    'Action',
#    'e-sports',
#    'Online Co-Op',
#    'Competitive',
#    'PvP',
#    'RTS',
#    'Difficult',
#    'RPG',
#    'Fantasy',
#    'Tower Defense',
#    'Co-op',
#    'Character Customization',
#    'Replay Value',
#    'Action RPG',
#    'Simulation'],
#   'specs': ['Multi-player',
#    'Steam Achievements',
#    'Full controller support',
#    'Steam Trading Cards',
#    'Steam Workshop',
#    'In-App Purchases',
#    'Valve Anti-Cheat enabled',
#    'Stats',
#    'Multi-player',
#    'Co-op',
#    'Steam Trading Cards',
#    'Steam Workshop',
#    'SteamVR Collectibles',
#    'In-App Purchases',
#    'Valve Anti-Cheat enabled',
#    'HTC Vive',
#    'Tracked Motion Controllers',
#    'Seated',
#    'Standing',
#    'Room-Scale']},
#  '76561198028895010': {'genres': ['Action', 'Adventure'],
#   'tags': ['Puzzle',
#    'Co-op',
#    'First-Person',
#    'Sci-fi',
#    'Comedy',
#    'Singleplayer',
#    'Adventure',
#    'Online Co-Op',
#    'Funny',
#    'Science',
#    'Female Protagonist',
#    'Action',
#    'Story Rich',
#    'Multiplayer',
#    'Atmospheric',
#    'Local Co-Op',
#    'FPS',
#    'Strategy',
#    'Space',
#    'Platformer'],
#   'specs': ['Single-player',
#    'Co-op',
#    'Steam Achievements',
#    'Full controller support',
#    'Steam Trading Cards',
#    'Captions available',
#    'Steam Workshop',
#    'Steam Cloud',
#    'Stats',
#    'Includes level editor',
#    'Commentary available']},
#  '76561198170198366': {'genres': [], 'tags': [], 'specs': []},
#  'diego9031': {'genres': ['Indie',
#    'Simulation',
#    'Action',
#    'Free to Play',
#    'Indie',
#    'Action',
#    'Adventure',
#    'Indie',
#    'Action',
#    'Free to Play',
#    'Massively Multiplayer',
#    'Strategy',
#    'Adventure',
#    'Indie',
#    'Simulation',
#    'Action',
#    'Action',
#    'Action',
#    'Adventure',
#    'Casual',
#    'Indie',
#    'RPG',
#    'Action',
#    'Free to Play',
#    'Action',
#    'Free to Play',
#    'Indie'],
#   'tags': ['Sandbox',
#    'Multiplayer',
#    'Funny',
#    'Moddable',
#    'Building',
#    'Co-op',
#    'Comedy',
#    'First-Person',
#    'Mod',
#    'Simulation',
#    'Online Co-Op',
#    'FPS',
#    'Singleplayer',
#    'Physics',
#    'Action',
#    'Indie',
#    'Shooter',
#    'Animation & Modeling',
#    'Adventure',
#    'Massively Multiplayer',
#    'Free to Play',
#    'Action',
#    'Multiplayer',
#    'Third-Person Shooter',
#    'Parkour',
#    'Shooter',
#    'FPS',
#    'Bullet Time',
#    'Open World',
#    'First-Person',
#    'Funny',
#    'Indie',
#    'Co-op',
#    'Comedy',
#    'Singleplayer',
#    'Online Co-Op',
#    'Adventure',
#    'Survival',
#    'Controller',
#    'Zombies',
#    'Horror',
#    'Free to Play',
#    'Survival Horror',
#    'Co-op',
#    'Multiplayer',
#    'Action',
#    'Indie',
#    'Psychological Horror',
#    'Atmospheric',
#    'Online Co-Op',
#    'First-Person',
#    'Adventure',
#    'Zombies',
#    'Psychological',
#    'Singleplayer',
#    'FPS',
#    'Survival',
#    'Shooter',
#    'Mod',
#    'Massively Multiplayer',
#    'Free to Play',
#    'Action',
#    'Multiplayer',
#    'FPS',
#    'Building',
#    'Shooter',
#    'Strategy',
#    'First-Person',
#    'Team-Based',
#    'Base Building',
#    'Class-Based',
#    'Destruction',
#    'Massively Multiplayer',
#    'PvP',
#    'Sandbox',
#    'Funny',
#    'MOBA',
#    'Voxel',
#    'Comedy',
#    'Gore',
#    'Survival',
#    'Multiplayer',
#    'Co-op',
#    'Open World',
#    'Adventure',
#    'Crafting',
#    'Sandbox',
#    'Indie',
#    'Difficult',
#    'Online Co-Op',
#    '2D',
#    'Atmospheric',
#    'Survival Horror',
#    'Strategy',
#    'Simulation',
#    'Funny',
#    'Action',
#    'Singleplayer',
#    'Horror',
#    'Rogue-like',
#    'FPS',
#    'Zombies',
#    'Co-op',
#    'Survival',
#    'Action',
#    'Multiplayer',
#    'Horror',
#    'Online Co-Op',
#    'Shooter',
#    'Gore',
#    'Team-Based',
#    'First-Person',
#    'Moddable',
#    'Survival Horror',
#    'Great Soundtrack',
#    'Singleplayer',
#    'Class-Based',
#    'Difficult',
#    'Comedy',
#    'Adventure',
#    'Open World',
#    'Action',
#    'Classic',
#    'Third Person',
#    'Singleplayer',
#    'Sandbox',
#    'Crime',
#    'Driving',
#    'Shooter',
#    'Adventure',
#    'Third-Person Shooter',
#    'Atmospheric',
#    'Great Soundtrack',
#    'Violent',
#    'Silent Protagonist',
#    'Mature',
#    'Story Rich',
#    'Multiplayer',
#    'Moddable',
#    'Satire',
#    'Co-op',
#    'Action',
#    'Adventure',
#    'Multiplayer',
#    "Beat 'em up",
#    'Local Co-Op',
#    'Indie',
#    'Funny',
#    'Online Co-Op',
#    'Comedy',
#    'Hack and Slash',
#    '2D',
#    'RPG',
#    'Casual',
#    'Local Multiplayer',
#    'Controller',
#    'Great Soundtrack',
#    'Fantasy',
#    'Side Scroller',
#    'Action RPG',
#    'Free to Play',
#    'Multiplayer',
#    'FPS',
#    'Action',
#    'Shooter',
#    'Class-Based',
#    'Team-Based',
#    'Funny',
#    'First-Person',
#    'Trading',
#    'Cartoony',
#    'Competitive',
#    'Online Co-Op',
#    'Co-op',
#    'Robots',
#    'Comedy',
#    'Tactical',
#    'Crafting',
#    'Cartoon',
#    'Moddable',
#    'Free to Play',
#    'Zombies',
#    'Multiplayer',
#    'Survival',
#    'Horror',
#    'Co-op',
#    'Action',
#    'Online Co-Op',
#    'FPS',
#    'First-Person',
#    'Shooter',
#    'Survival Horror',
#    'Post-apocalyptic',
#    'Open World',
#    'Realistic',
#    'Indie',
#    'Atmospheric',
#    'Mod',
#    'Adventure',
#    'Massively Multiplayer'],
#   'specs': ['Single-player',
#    'Multi-player',
#    'Co-op',
#    'Cross-Platform Multiplayer',
#    'Steam Achievements',
#    'Steam Trading Cards',
#    'Captions available',
#    'Steam Workshop',
#    'Steam Cloud',
#    'Valve Anti-Cheat enabled',
#    'Includes level editor',
#    'Multi-player',
#    'Cross-Platform Multiplayer',
#    'Includes level editor',
# ...
#    'Steam Cloud',
#    'Valve Anti-Cheat enabled']},
#  '76561198067352691': {'genres': ['Adventure'],
#   'tags': ['Zombies',
#    'Adventure',
#    'Story Rich',
#    'Point & Click',
#    'Episodic',
#    'Singleplayer',
#    'Horror',
#    'Choices Matter',
#    'Mature',
#    'Drama',
#    'Atmospheric',
#    'Comic Book',
#    'Choose Your Own Adventure',
#    'Survival',
#    'Post-apocalyptic',
#    'Quick-Time Events',
#    'Gore',
#    'Action',
#    'Third Person',
#    'Visual Novel'],
#   'specs': ['Single-player',
#    'Steam Achievements',
#    'Full controller support',
#    'Steam Trading Cards']},
#  '76561198060072424': {'genres': ['Action',
#    'Free to Play',
#    'Indie',
#    'Action',
#    'Adventure',
#    'Casual',
#    'Free to Play',
#    'Indie'],
#   'tags': ['Free to Play',
#    'Multiplayer',
#    'FPS',
#    'Western',
#    'Shooter',
#    'Action',
#    'First-Person',
#    'Indie',
#    'Funny',
#    'Mod',
#    'Online Co-Op',
#    'Co-op',
#    'Comedy',
#    'Survival',
#    'Massively Multiplayer',
#    'Historical',
#    'Classic',
#    'Simulation',
#    'Adventure',
#    'RPG',
#    'Free to Play',
#    'Survival',
#    'Zombies',
#    'Multiplayer',
#    'Open World',
#    'Adventure',
#    'Crafting',
#    'Action',
#    'First-Person',
#    'Co-op',
#    'Sandbox',
#    'Post-apocalyptic',
#    'Shooter',
#    'FPS',
#    'Singleplayer',
#    'Massively Multiplayer',
#    'Indie',
#    'Atmospheric',
#    'Casual',
#    'Horror'],
#   'specs': ['Multi-player',
#    'Online Multi-Player',
#    'Local Multi-Player',
#    'Cross-Platform Multiplayer',
#    'Steam Achievements',
#    'Steam Workshop',
#    'Stats',
#    'Steam Leaderboards',
#    'Includes level editor',
#    'Includes Source SDK',
#    'Single-player',
#    'Online Multi-Player',
#    'Online Co-op',
#    'Steam Achievements',
#    'Steam Trading Cards',
#    'Steam Workshop',
#    'In-App Purchases',
#    'Steam Cloud',
#    'Valve Anti-Cheat enabled',
#    'Stats',
#    'Includes level editor']},
#  '76561198065466146': {'genres': ['Action',
#    'Adventure',
#    'Free to Play',
#    'Massively Multiplayer',
#    'RPG',
#    'Free to Play',
#    'Massively Multiplayer',
#    'RPG',
#    'Action'],
#   'tags': ['Free to Play',
#    'MMORPG',
#    'Massively Multiplayer',
#    'RPG',
#    'Action',
#    'Open World',
#    'Fantasy',
#    'Adventure',
#    'Anime',
#    'Third Person',
#    'Action RPG',
#    'Co-op',
#    'Character Customization',
#    'Multiplayer',
#    'PvP',
#    'Hack and Slash',
#    'PvE',
#    'Cute',
#    'Controller',
#    'Nudity',
#    'Free to Play',
#    'MMORPG',
#    'Massively Multiplayer',
#    'RPG',
#    'Fantasy',
#    'Open World',
#    'Adventure',
#    'Multiplayer',
#    'Based On A Novel',
#    'Action',
#    'Exploration',
#    'Character Customization',
#    'Story Rich',
#    'Co-op',
#    'Online Co-Op',
#    'Third Person',
#    'Survival',
#    'PvP',
#    'Singleplayer',
#    'Dark Fantasy',
#    'FPS',
#    'Multiplayer',
#    'Shooter',
#    'Action',
#    'Team-Based',
#    'Competitive',
#    'Tactical',
#    'First-Person',
#    'e-sports',
#    'PvP',
#    'Online Co-Op',
#    'Military',
#    'Co-op',
#    'Strategy',
#    'War',
#    'Trading',
#    'Realistic',
#    'Difficult',
#    'Fast-Paced',
#    'Moddable'],
#   'specs': ['Multi-player',
#    'MMO',
#    'Co-op',
#    'Steam Trading Cards',
#    'Partial Controller Support',
#    'MMO',
#    'Multi-player',
#    'Steam Achievements',
#    'Full controller support',
#    'Steam Trading Cards',
#    'Steam Workshop',
#    'In-App Purchases',
#    'Valve Anti-Cheat enabled',
#    'Stats']},
#  'SGSChief': {'genres': [], 'tags': [], 'specs': []},
#  'haonman': {'genres': [], 'tags': [], 'specs': []},
#  'HeavyfromHell': {'genres': ['Action', 'Free to Play', 'Indie', 'RPG'],
#   'tags': ['Free to Play',
#    'Multiplayer',
#    'FPS',
#    'Action',
#    'Shooter',
#    'Class-Based',
#    'Team-Based',
#    'Funny',
#    'First-Person',
#    'Trading',
#    'Cartoony',
#    'Competitive',
#    'Online Co-Op',
#    'Co-op',
#    'Robots',
#    'Comedy',
#    'Tactical',
#    'Crafting',
#    'Cartoon',
#    'Moddable',
#    'Great Soundtrack',
#    'Story Rich',
#    'Choices Matter',
#    'Funny',
#    'Multiple Endings',
#    'RPG',
#    'Pixel Graphics',
#    'Singleplayer',
#    'Indie',
#    'Comedy',
#    '2D',
#    'Replay Value',
#    'Bullet Hell',
#    'Cute',
#    'Memes',
#    'Retro',
#    'Dark',
#    'Dating Sim',
#    'Psychological Horror',
#    'Horror'],
#   'specs': ['Multi-player',
#    'Cross-Platform Multiplayer',
#    'Steam Achievements',
#    'Steam Trading Cards',
#    'Captions available',
#    'Steam Workshop',
#    'In-App Purchases',
#    'Partial Controller Support',
#    'Valve Anti-Cheat enabled',
#    'Stats',
#    'Includes level editor',
#    'Commentary available',
#    'Single-player',
#    'Steam Trading Cards']},
#  'MysticZemo': {'genres': ['Action', 'Adventure', 'Action', 'Indie'],
#   'tags': ['Action',
#    'Open World',
#    'Adventure',
#    'Third Person',
#    'Gore',
#    'Singleplayer',
#    'Parkour',
#    'Superhero',
#    'Zombies',
#    'Hack and Slash',
#    'Action-Adventure',
#    'Violent',
#    'Sci-fi',
#    'Sandbox',
#    'Story Rich',
#    'Stealth',
#    'RPG',
#    'Atmospheric',
#    'Controller',
#    'Horror',
#    'Difficult',
#    'Indie',
#    'Great Soundtrack',
#    'Fast-Paced',
#    'Arcade',
#    'Rhythm',
#    'Singleplayer',
#    'Action',
#    'Score Attack',
#    'Minimalist',
#    'Music',
#    '2D',
#    'Psychedelic',
#    'Colorful',
#    'Casual',
#    'Replay Value',
#    'Controller',
#    'Puzzle',
#    'Bullet Hell',
#    'Abstract'],
#   'specs': ['Single-player', 'Single-player', 'Full controller support']},
#  'gfire555': {'genres': ['Action',
#    'Free to Play',
#    'Indie',
#    'Massively Multiplayer',
#    'RPG',
#    'Simulation',
#    'Action',
#    'Adventure',
#    'Indie',
#    'RPG'],
#   'tags': ['Free to Play',
#    'Robots',
#    'Building',
#    'Multiplayer',
#    'Action',
#    'Shooter',
#    'PvP',
#    'Massively Multiplayer',
#    'Sandbox',
#    'Crafting',
#    'Third-Person Shooter',
#    'Sci-fi',
#    'Strategy',
#    'Simulation',
#    'Indie',
#    'Open World',
#    'Funny',
#    'Adventure',
#    'RPG',
#    'FPS',
#    'Sandbox',
#    'Adventure',
#    'Survival',
#    '2D',
#    'Multiplayer',
#    'Crafting',
#    'Building',
#    'Exploration',
#    'Pixel Graphics',
#    'Co-op',
#    'Indie',
#    'Open World',
#    'Action',
#    'RPG',
#    'Online Co-Op',
#    'Singleplayer',
#    'Platformer',
#    'Replay Value',
#    'Atmospheric',
#    'Family Friendly'],
#   'specs': ['Multi-player',
#    'Online Multi-Player',
#    'MMO',
#    'Online Co-op',
#    'Steam Trading Cards',
#    'In-App Purchases',
#    'Single-player',
#    'Multi-player',
#    'Online Multi-Player',
#    'Co-op',
#    'Online Co-op',
#    'Steam Achievements',
#    'Full controller support',
#    'Steam Trading Cards',
#    'Steam Cloud']},
#  '76561198202329564': {'genres': ['Action',
#    'Action',
#    'Adventure',
#    'Casual',
#    'Free to Play',
#    'Indie'],
#   'tags': ['FPS',
#    'Multiplayer',
#    'Shooter',
#    'Action',
#    'Team-Based',
#    'Competitive',
#    'Tactical',
#    'First-Person',
#    'e-sports',
#    'PvP',
#    'Online Co-Op',
#    'Military',
#    'Co-op',
#    'Strategy',
#    'War',
#    'Trading',
#    'Realistic',
#    'Difficult',
#    'Fast-Paced',
#    'Moddable',
#    'Co-op',
#    'Action',
#    'FPS',
#    'Heist',
#    'Online Co-Op',
#    'Multiplayer',
#    'Stealth',
#    'Crime',
#    'Team-Based',
#    'Shooter',
#    'First-Person',
#    'Great Soundtrack',
#    'Gun Customization',
#    'Tactical',
#    'PvE',
#    'Strategy',
#    'Singleplayer',
#    'Simulation',
#    'Funny',
#    'Adventure',
#    'Free to Play',
#    'Survival',
#    'Zombies',
#    'Multiplayer',
#    'Open World',
#    'Adventure',
#    'Crafting',
#    'Action',
#    'First-Person',
#    'Co-op',
#    'Sandbox',
#    'Post-apocalyptic',
#    'Shooter',
#    'FPS',
#    'Singleplayer',
#    'Massively Multiplayer',
#    'Indie',
#    'Atmospheric',
#    'Casual',
#    'Horror'],
#   'specs': ['Multi-player',
#    'Steam Achievements',
#    'Full controller support',
#    'Steam Trading Cards',
#    'Steam Workshop',
#    'In-App Purchases',
#    'Valve Anti-Cheat enabled',
#    'Stats',
#    'Single-player',
#    'Multi-player',
#    'Co-op',
#    'Online Co-op',
#    'Steam Achievements',
#    'Full controller support',
#    'Steam Trading Cards',
#    'In-App Purchases',
#    'HTC Vive',
#    'Single-player',
#    'Online Multi-Player',
#    'Online Co-op',
#    'Steam Achievements',
#    'Steam Trading Cards',
#    'Steam Workshop',
#    'In-App Purchases',
#    'Steam Cloud',
#    'Valve Anti-Cheat enabled',
#    'Stats',
#    'Includes level editor']},
#  '76561198050768829': {'genres': [], 'tags': [], 'specs': []},
#  '76561198036861500': {'genres': ['Action'],
#   'tags': ['Zombies',
#    'Co-op',
#    'FPS',
#    'Multiplayer',
#    'Action',
#    'Online Co-Op',
#    'Shooter',
#    'Survival',
#    'First-Person',
#    'Horror',
#    'Team-Based',
#    'Moddable',
#    'Gore',
#    'Survival Horror',
#    'Post-apocalyptic',
#    'Singleplayer',
#    'Adventure',
#    'Local Co-Op',
#    'Tactical',
#    'Replay Value'],
#   'specs': ['Single-player',
#    'Multi-player',
#    'Co-op',
#    'Steam Achievements',
#    'Full controller support',
#    'Steam Trading Cards',
#    'Captions available',
#    'Steam Workshop',
#    'Steam Cloud',
#    'Valve Anti-Cheat enabled',
#    'Stats',
#    'Includes Source SDK',
#    'Commentary available']},
#  '76561198088472271': {'genres': ['RPG'],
#   'tags': ['Open World',
#    'RPG',
#    'Post-apocalyptic',
#    'Singleplayer',
#    'Moddable',
#    'First-Person',
#    'Sci-fi',
#    'Action',
#    'Adventure',
#    'FPS',
#    'Replay Value',
#    'Sandbox',
#    'Third Person',
#    'Exploration',
#    'Atmospheric',
#    'Story Rich',
#    'Shooter',
#    'Cult Classic',
#    'Action RPG',
#    'Great Soundtrack'],
#   'specs': ['Single-player']},
#  'HiJason': {'genres': [], 'tags': [], 'specs': []},
#  'ghostlybug22': {'genres': ['Action',
#    'Action',
#    'Action',
#    'Adventure',
#    'Action',
#    'Adventure',
#    'Action',
#    'Adventure',
#    'Indie',
#    'Massively Multiplayer',
#    'RPG',
#    'Early Access',
#    'Action'],
#   'tags': ['Free to Play',
#    'MOBA',
#    'Strategy',
#    'Multiplayer',
#    'Team-Based',
#    'Action',
#    'e-sports',
#    'Online Co-Op',
#    'Competitive',
#    'PvP',
#    'RTS',
#    'Difficult',
#    'RPG',
#    'Fantasy',
#    'Tower Defense',
#    'Co-op',
#    'Character Customization',
#    'Replay Value',
#    'Action RPG',
#    'Simulation',
#    'FPS',
#    'Multiplayer',
#    'Shooter',
#    'Action',
#    'Team-Based',
#    'Competitive',
#    'Tactical',
#    'First-Person',
#    'e-sports',
#    'PvP',
#    'Online Co-Op',
#    'Military',
#    'Co-op',
#    'Strategy',
#    'War',
#    'Trading',
#    'Realistic',
#    'Difficult',
#    'Fast-Paced',
#    'Moddable',
#    'FPS',
#    'Action',
#    'Story Rich',
#    'Singleplayer',
#    'Steampunk',
#    'Atmospheric',
#    'Shooter',
#    'First-Person',
#    'Alternate History',
#    'Adventure',
#    'Great Soundtrack',
#    'Dystopian',
#    'Sci-fi',
#    'Time Travel',
#    'Fantasy',
#    'Gore',
#    'Linear',
#    'RPG',
#    'Political',
#    'Controller',
#    'Action',
#    'Open World',
#    'Adventure',
#    'Third Person',
#    'Gore',
#    'Singleplayer',
#    'Parkour',
#    'Superhero',
#    'Zombies',
#    'Hack and Slash',
#    'Action-Adventure',
#    'Violent',
#    'Sci-fi',
#    'Sandbox',
#    'Story Rich',
#    'Stealth',
#    'RPG',
#    'Atmospheric',
#    'Controller',
#    'Horror',
#    'Stealth',
#    'First-Person',
#    'Action',
#    'Steampunk',
#    'Assassin',
#    'Singleplayer',
#    'Atmospheric',
#    'Story Rich',
#    'Adventure',
#    'Multiple Endings',
#    'Dark',
#    'Magic',
#    'Dystopian',
#    'FPS',
#    'RPG',
#    'Replay Value',
#    'Fantasy',
#    'Open World',
#    'Shooter',
#    'Sci-fi',
#    'Early Access',
#    'Survival',
#    'Crafting',
#    'Multiplayer',
#    'Open World',
#    'Sandbox',
#    'Building',
#    'PvP',
#    'Adventure',
#    'First-Person',
#    'Action',
#    'FPS',
#    'Nudity',
#    'Indie',
#    'Co-op',
#    'Shooter',
#    'Online Co-Op',
#    'Simulation',
#    'Post-apocalyptic',
#    'Survival Horror',
#    'Open World',
#    'Action',
#    'Comedy',
#    'Third-Person Shooter',
#    'Co-op',
#    'Sandbox',
#    'Funny',
#    'Third Person',
#    'Online Co-Op',
#    'Singleplayer',
#    'Character Customization',
#    'Great Soundtrack',
#    'Shooter',
#    'Multiplayer',
#    'Crime',
#    'Female Protagonist',
#    'Adventure',
#    'Zombies',
#    'RPG',
#    'Satire'],
#   'specs': ['Multi-player',
#    'Co-op',
#    'Steam Trading Cards',
#    'Steam Workshop',
#    'SteamVR Collectibles',
#    'In-App Purchases',
#    'Valve Anti-Cheat enabled',
#    'HTC Vive',
#    'Tracked Motion Controllers',
#    'Seated',
#    'Standing',
#    'Room-Scale',
#    'Multi-player',
#    'Steam Achievements',
#    'Full controller support',
#    'Steam Trading Cards',
#    'Steam Workshop',
#    'In-App Purchases',
#    'Valve Anti-Cheat enabled',
#    'Stats',
#    'Single-player',
#    'Steam Achievements',
#    'Full controller support',
#    'Steam Trading Cards',
#    'Steam Cloud',
#    'Single-player',
#    'Single-player',
#    'Steam Achievements',
#    'Full controller support',
#    'Steam Cloud',
#    'Multi-player',
#    'MMO',
#    'Cross-Platform Multiplayer',
#    'Steam Workshop',
#    'In-App Purchases',
#    'Valve Anti-Cheat enabled',
#    'Single-player',
#    'Co-op',
#    'Steam Achievements',
#    'Steam Trading Cards',
#    'Partial Controller Support',
#    'Steam Cloud']},
#  'GiBaPEzLife': {'genres': ['Action', 'Free to Play', 'Action'],
#   'tags': ['Free to Play',
#    'Action',
#    'Co-op',
#    'Multiplayer',
#    'Third-Person Shooter',
#    'Sci-fi',
#    'Ninja',
#    'Shooter',
#    'Parkour',
#    'Space',
#    'Online Co-Op',
#    'Futuristic',
#    'Third Person',
#    'Massively Multiplayer',
#    'PvE',
#    'RPG',
#    'Singleplayer',
#    'Hack and Slash',
#    'FPS',
#    'Cyberpunk',
#    'FPS',
#    'Multiplayer',
#    'Shooter',
#    'Action',
#    'Team-Based',
#    'Competitive',
#    'Tactical',
#    'First-Person',
#    'e-sports',
#    'PvP',
#    'Online Co-Op',
#    'Military',
#    'Co-op',
#    'Strategy',
#    'War',
#    'Trading',
#    'Realistic',
#    'Difficult',
#    'Fast-Paced',
#    'Moddable'],
#   'specs': ['Single-player',
#    'Multi-player',
#    'Co-op',
#    'Steam Trading Cards',
#    'In-App Purchases',
#    'Partial Controller Support',
#    'Multi-player',
#    'Steam Achievements',
#    'Full controller support',
#    'Steam Trading Cards',
#    'Steam Workshop',
#    'In-App Purchases',
#    'Valve Anti-Cheat enabled',
#    'Stats']},
#  '76561198079080583': {'genres': [], 'tags': [], 'specs': []},
#  '76561198079227569': {'genres': ['Action', 'Free to Play'],
#   'tags': ['Action',
#    'Multiplayer',
#    'Co-op',
#    'FPS',
#    'Online Co-Op',
#    'Shooter',
#    'Team-Based',
#    'Survival',
#    'Sci-fi',
#    'Aliens',
#    'PvP',
#    'First-Person',
#    'Class-Based',
#    'Strategy',
#    'Atmospheric',
#    'Third Person',
#    'Tactical',
#    'Singleplayer',
#    'Stealth',
#    'Casual'],
#   'specs': ['Single-player',
#    'Multi-player',
#    'Co-op',
#    'Full controller support',
#    'Steam Trading Cards',
#    'Valve Anti-Cheat enabled']},
#  'gillinator': {'genres': ['Action', 'Adventure', 'Casual', 'Indie', 'RPG'],
#   'tags': ['Sandbox',
#    'Adventure',
#    'Survival',
#    'Indie',
#    'Crafting',
#    'Space',
#    'Multiplayer',
#    'Building',
#    'Pixel Graphics',
#    '2D',
#    'RPG',
#    'Exploration',
#    'Action',
#    'Open World',
#    'Platformer',
#    'Sci-fi',
#    'Co-op',
#    'Singleplayer',
#    'Atmospheric',
#    'Great Soundtrack'],
#   'specs': ['Single-player',
#    'Multi-player',
#    'Online Multi-Player',
#    'Co-op',
#    'Online Co-op',
#    'Cross-Platform Multiplayer',
#    'Steam Achievements',
#    'Steam Trading Cards',
#    'Steam Workshop']},
#  '76561198095945803': {'genres': ['Strategy', 'Action', 'Indie', 'Strategy'],
#   'tags': ['Strategy',
#    'Historical',
#    'War',
#    'Turn-Based Strategy',
#    'Grand Strategy',
#    'Tactical',
#    'RTS',
#    'Rome',
#    'Multiplayer',
#    'Singleplayer',
#    'Real Time Tactics',
#    'Medieval',
#    'Atmospheric',
#    'Action',
#    'Co-op',
#    'Turn-Based',
#    'Open World',
#    'Survival',
#    'Simulation',
#    'Adventure',
#    'World War I',
#    'FPS',
#    'Multiplayer',
#    'War',
#    'Historical',
#    'Realistic',
#    'Action',
#    'Shooter',
#    'First-Person',
#    'Military',
#    'Tactical',
#    'Strategy',
#    'Simulation',
#    'Team-Based',
#    'Co-op',
#    'Indie',
#    'Atmospheric',
#    'Singleplayer',
#    'Adventure',
#    'Gore'],
#   'specs': ['Single-player',
#    'Multi-player',
#    'Steam Achievements',
#    'Steam Trading Cards',
#    'Steam Cloud',
#    'Multi-player',
#    'Online Multi-Player',
#    'Cross-Platform Multiplayer',
#    'Steam Achievements',
#    'Steam Trading Cards',
#    'Partial Controller Support',
#    'Steam Cloud',
#    'Steam Leaderboards']},
#  ...}

# %%
# find jaccard similarity between games in a bundle and user's preferred genres/tags/specs
# let teh threshold be 0.5 for now

total_len = len(user_recommend_genres.keys())
i = 0


jaccard_similarity_threshold = 0.8
user_bundle_match = defaultdict(list)
for user in user_recommend_genres.keys():

    print(f"Processing user {user} ({list(user_recommend_genres.keys()).index(user)+1}/{total_len})")
    user_genres_set = set(user_recommend_genres[user]['genres'])
    user_tags_set = set(user_recommend_genres[user]['tags'])
    user_specs_set = set(user_recommend_genres[user]['specs'])

    for bundle in bundle_games_genres.keys():
        bundle_genres_set = set(bundle_games_genres[bundle]['genres'])
        bundle_tags_set = set(bundle_games_genres[bundle]['tags'])
        bundle_specs_set = set(bundle_games_genres[bundle]['specs'])

        genre_jaccard = jaccard_similarity(user_genres_set, bundle_genres_set)
        tag_jaccard = jaccard_similarity(user_tags_set, bundle_tags_set)
        specs_jaccard = jaccard_similarity(user_specs_set, bundle_specs_set)

        if (np.mean([genre_jaccard, tag_jaccard, specs_jaccard])
            >= jaccard_similarity_threshold):
            user_bundle_match[user].append(bundle)
# Out:
# Processing user 76561197970982479 (1/25485)
# Processing user js41637 (2/25485)
# Processing user evcentric (3/25485)
# Processing user doctr (4/25485)
# Processing user maplemage (5/25485)
# Processing user Wackky (6/25485)
# Processing user 76561198079601835 (7/25485)
# Processing user MeaTCompany (8/25485)
# Processing user 76561198089393905 (9/25485)
# Processing user 76561198156664158 (10/25485)
# Processing user 76561198077246154 (11/25485)
# Processing user WeiEDKrSat (12/25485)
# Processing user thequeenpanda (13/25485)
# Processing user death-hunter (14/25485)
# Processing user DJKamBer (15/25485)
# Processing user Rainbow-Dashie (16/25485)
# Processing user 76561198043472122 (17/25485)
# Processing user MarbleShrine (18/25485)
# Processing user PPanther (19/25485)
# Processing user devvonst (20/25485)
# Processing user Fr0stedLine (21/25485)
# Processing user starkillershadow553 (22/25485)
# Processing user 76561198058373434 (23/25485)
# Processing user 76561198048353577 (24/25485)
# Processing user 76561198066046412 (25/25485)
# Processing user tru_mu_ (26/25485)
# Processing user 76561198070565427 (27/25485)
# Processing user SavageEeEe (28/25485)
# Processing user 76561198076909484 (29/25485)
# Processing user KanadeTheNeko (30/25485)
# Processing user Leaf_Light_Moscow (31/25485)
# Processing user GoAwayZach (32/25485)
# Processing user 76561198054540475 (33/25485)
# Processing user 76561198085547365 (34/25485)
# Processing user 76561198061252210 (35/25485)
# Processing user OfficialShroomsy (36/25485)
# Processing user boydeer (37/25485)
# Processing user VVillis (38/25485)
# Processing user 76561198083226897 (39/25485)
# Processing user 76561198075277292 (40/25485)
# Processing user 76561198028895010 (41/25485)
# Processing user 76561198170198366 (42/25485)
# Processing user diego9031 (43/25485)
# Processing user jarrodtrim (44/25485)
# Processing user 76561198078738103 (45/25485)
# Processing user 76561198067936203 (46/25485)
# Processing user 76561198079770573 (47/25485)
# Processing user 76561198087586464 (48/25485)
# Processing user Derp-e (49/25485)
# Processing user 76561198070194565 (50/25485)
# Processing user Rivtex (51/25485)
# Processing user UTNerd24 (52/25485)
# Processing user sandwiches1 (53/25485)
# Processing user 76561198138053270 (54/25485)
# Processing user lucaswerg (55/25485)
# Processing user Life-Of-Blu (56/25485)
# Processing user CaptianAutismo (57/25485)
# Processing user 76561198075895633 (58/25485)
# Processing user TheDropix101 (59/25485)
# Processing user kube134 (60/25485)
# Processing user iamthekingofbrowntown (61/25485)
# Processing user MainScout (62/25485)
# Processing user gdxsd (63/25485)
# Processing user yookobz (64/25485)
# Processing user Posiblydead (65/25485)
# Processing user Mossy_Gaming (66/25485)
# Processing user 76561198102421718 (67/25485)
# Processing user 76561198087407319 (68/25485)
# Processing user 76561198056741844 (69/25485)
# Processing user sad-commie (70/25485)
# Processing user 76561198030567998 (71/25485)
# Processing user 76561198010674657 (72/25485)
# Processing user Coldaniel (73/25485)
# Processing user therealmorty (74/25485)
# Processing user Berserklejerker (75/25485)
# Processing user 76561198061730629 (76/25485)
# Processing user YoHuNz (77/25485)
# Processing user possessioniskey (78/25485)
# Processing user 76561198093112529 (79/25485)
# Processing user 76561198060447950 (80/25485)
# Processing user whiteofwolfing (81/25485)
# Processing user sergarino (82/25485)
# Processing user 76561198081962345 (83/25485)
# Processing user 76561198094224872 (84/25485)
# Processing user 76561198073210139 (85/25485)
# Processing user Nozomikat (86/25485)
# Processing user xfluttersx (87/25485)
# Processing user 76561198056290589 (88/25485)
# Processing user ii_voltage_ii (89/25485)
# Processing user 76561198097762318 (90/25485)
# Processing user Hirukaz (91/25485)
# Processing user StelerForYou (92/25485)
# Processing user 76561198183396245 (93/25485)
# Processing user Xx-Woods (94/25485)
# Processing user kevinator23 (95/25485)
# Processing user 76561198090715178 (96/25485)
# Processing user CatsWhale (97/25485)
# Processing user 76561198073784601 (98/25485)
# Processing user mimimomoma (99/25485)
# Processing user 76561198102410011 (100/25485)
# Processing user de_Butl3r (101/25485)
# Processing user 76561198027947401 (102/25485)
# Processing user Bluezap1 (103/25485)
# Processing user 76561198074200011 (104/25485)
# Processing user jonasdbomb (105/25485)
# Processing user L1J1N (106/25485)
# Processing user Lord_Exploit (107/25485)
# Processing user AVATAR715 (108/25485)
# Processing user YieuwMage (109/25485)
# Processing user 76561198078752187 (110/25485)
# Processing user A-Very-Sly-Person (111/25485)
# Processing user 76561198211054671 (112/25485)
# Processing user 76561197994493402 (113/25485)
# Processing user Koolcaz12 (114/25485)
# Processing user 76561198065656175 (115/25485)
# Processing user 76561198188979775 (116/25485)
# Processing user 97396295 (117/25485)
# Processing user 76561198126640317 (118/25485)
# Processing user DemonicWolvz (119/25485)
# Processing user DieMadchenschanderin (120/25485)
# Processing user GGargula (121/25485)
# Processing user Myther43 (122/25485)
# Processing user getf0kinn0sc0pedm9 (123/25485)
# Processing user 76561198141443390 (124/25485)
# Processing user 76561198097333029 (125/25485)
# Processing user whodafuqisthisguilao (126/25485)
# Processing user Magjiikal (127/25485)
# Processing user ohnospaghet (128/25485)
# Processing user 76561198050347115 (129/25485)
# Processing user 2768820078 (130/25485)
# Processing user 76561198056392326 (131/25485)
# Processing user 2d4nk4m3 (132/25485)
# Processing user 76561198078478151 (133/25485)
# Processing user exiaez (134/25485)
# Processing user 76561198095921854 (135/25485)
# Processing user EizanAratoFujimaki (136/25485)
# Processing user TeCool (137/25485)
# Processing user 2xDelorean (138/25485)
# Processing user washington_ (139/25485)
# Processing user jewxxl (140/25485)
# Processing user 76561198088944293 (141/25485)
# Processing user 76561198092540221 (142/25485)
# Processing user 76561198051258119 (143/25485)
# Processing user nubquake123 (144/25485)
# Processing user Pyromanic (145/25485)
# Processing user 76561198109656922 (146/25485)
# Processing user CobRazor (147/25485)
# Processing user relesprit (148/25485)
# Processing user WitchHunter4542 (149/25485)
# Processing user pwrt (150/25485)
# Processing user wantmahbody (151/25485)
# Processing user 76561198115868847 (152/25485)
# Processing user benedictcuminherbatch (153/25485)
# Processing user 76561198031207016 (154/25485)
# Processing user 76561198043458582 (155/25485)
# Processing user smashiroshh (156/25485)
# Processing user shark854 (157/25485)
# Processing user killbunny38 (158/25485)
# Processing user 76561198047630659 (159/25485)
# Processing user 1337lolroflmao (160/25485)
# Processing user sithjjf (161/25485)
# Processing user 76561198060039459 (162/25485)
# Processing user OzfurAtlas (163/25485)
# Processing user 76561198065593074 (164/25485)
# Processing user 76561198044169764 (165/25485)
# Processing user euzi (166/25485)
# Processing user 76561198074935997 (167/25485)
# Processing user 76561197961778802 (168/25485)
# Processing user lucasrash (169/25485)
# Processing user 76561198016602703 (170/25485)
# Processing user thisissohardtomakeoneup (171/25485)
# Processing user 76561198087010391 (172/25485)
# Processing user 66666669999999 (173/25485)
# Processing user 76561198061174192 (174/25485)
# Processing user ReMiXOfficalSteam (175/25485)
# Processing user Wilfire77 (176/25485)
# Processing user 76561198084390807 (177/25485)
# Processing user Mastic (178/25485)
# Processing user 76561198028286104 (179/25485)
# Processing user tarjla (180/25485)
# Processing user deathnz1 (181/25485)
# Processing user readingthis4noobs (182/25485)
# Processing user 76561198104393251 (183/25485)
# Processing user 76561198075322986 (184/25485)
# Processing user redsncrimson (185/25485)
# Processing user 76561198151910904 (186/25485)
# Processing user H1DD3NT3RR0R (187/25485)
# Processing user 76561198071214618 (188/25485)
# Processing user 76561198115115631 (189/25485)
# Processing user 76561198071175142 (190/25485)
# Processing user t8s (191/25485)
# Processing user pikawuu2 (192/25485)
# Processing user Sammeh00 (193/25485)
# Processing user Michaelele (194/25485)
# Processing user 76561198045754869 (195/25485)
# Processing user 76561198076098774 (196/25485)
# Processing user 76561198103253374 (197/25485)
# Processing user 76561198048417105 (198/25485)
# Processing user 76561198090842891 (199/25485)
# Processing user 76561198055767971 (200/25485)
# Processing user 76561197998052647 (201/25485)
# Processing user adohya343 (202/25485)
# Processing user 76561198145436942 (203/25485)
# Processing user jjas01 (204/25485)
# Processing user 3xotic26 (205/25485)
# Processing user iamthetrashlord (206/25485)
# Processing user 3dster (207/25485)
# Processing user 76561198079990063 (208/25485)
# Processing user Forty-Nine (209/25485)
# Processing user 76561198051017916 (210/25485)
# Processing user L4M1NAS (211/25485)
# Processing user 76561198096766604 (212/25485)
# Processing user 76561197995322437 (213/25485)
# Processing user imsojipper (214/25485)
# Processing user 76561198084542731 (215/25485)
# Processing user 76561198103671881 (216/25485)
# Processing user mrpfresh (217/25485)
# Processing user GamerFag (218/25485)
# Processing user EHS-R3AP3R (219/25485)
# Processing user chidori_647 (220/25485)
# Processing user 76561198092227136 (221/25485)
# Processing user hellcat59 (222/25485)
# Processing user 76561198007584361 (223/25485)
# Processing user tbimperator (224/25485)
# Processing user Allahu_Akbar666 (225/25485)
# Processing user ulramite (226/25485)
# Processing user -GM-Dragon (227/25485)
# Processing user 76561198054040292 (228/25485)
# Processing user 76561198078799606 (229/25485)
# Processing user I_DID_911_JUST_SAYING (230/25485)
# Processing user 750805 (231/25485)
# Processing user diabeticfuck (232/25485)
# Processing user 76561198054465623 (233/25485)
# Processing user aaropro (234/25485)
# Processing user abiam (235/25485)
# Processing user FrankoWalker (236/25485)
# Processing user LightfootSword7 (237/25485)
# Processing user SALTTHEW0UND (238/25485)
# Processing user express157 (239/25485)
# Processing user 76561198074644990 (240/25485)
# Processing user 76561198064304806 (241/25485)
# Processing user TomoeMamiewe (242/25485)
# Processing user 76561198057086148 (243/25485)
# Processing user Acidius99 (244/25485)
# Processing user acorn13 (245/25485)
# Processing user adamcookie (246/25485)
# Processing user AddzyTheBaddzy (247/25485)
# Processing user mrfunkyjunkie (248/25485)
# Processing user mradobe7 (249/25485)
# Processing user 76561198167207237 (250/25485)
# Processing user cancerkek (251/25485)
# Processing user 76561198073508075 (252/25485)
# Processing user 76561198074323290 (253/25485)
# Processing user 76561198090899557 (254/25485)
# Processing user advenger95 (255/25485)
# Processing user EndAtHallow (256/25485)
# Processing user 76561198063624801 (257/25485)
# Processing user aeryal (258/25485)
# Processing user 76561198070263209 (259/25485)
# Processing user 76561198015968275 (260/25485)
# Processing user Agiegamma (261/25485)
# Processing user 76561198082614708 (262/25485)
# Processing user Agronoth (263/25485)
# Processing user UnholyFallenAngel (264/25485)
# Processing user 76561198068565589 (265/25485)
# Processing user SlutOnTheSpit (266/25485)
# Processing user WestyGaming (267/25485)
# Processing user NaruseAiria (268/25485)
# Processing user 76561198067713802 (269/25485)
# Processing user 76561198187212131 (270/25485)
# Processing user 76561198044678148 (271/25485)
# Processing user Alex680 (272/25485)
# Processing user alansiulun (273/25485)
# Processing user Albolah (274/25485)
# Processing user 76561198003056556 (275/25485)
# Processing user maxpaynepillkiller (276/25485)
# Processing user AlexNoClutch (277/25485)
# Processing user Alexwai04 (278/25485)
# Processing user 76561198095481910 (279/25485)
# Processing user 76561198164545985 (280/25485)
# Processing user AlkalineDeath (281/25485)
# Processing user 76561198075935236 (282/25485)
# Processing user mintifreshbadger (283/25485)
# Processing user AlpacaRevolution (284/25485)
# Processing user AlphaBryn444 (285/25485)
# Processing user 76561198071952798 (286/25485)
# Processing user 76561198009001563 (287/25485)
# Processing user 76561198016753953 (288/25485)
# Processing user smegmyfoodle (289/25485)
# Processing user 76561198057869849 (290/25485)
# Processing user 76561198058836921 (291/25485)
# Processing user lol_ursuchanoob (292/25485)
# Processing user AMV72 (293/25485)
# Processing user 76561198069170979 (294/25485)
# Processing user 76561198085956238 (295/25485)
# Processing user 76561198132540690 (296/25485)
# Processing user 711armageddoncarmageddon (297/25485)
# Processing user 76561198034868596 (298/25485)
# Processing user Andraison (299/25485)
# Processing user 76561198055790408 (300/25485)
# Processing user 76561198069560699 (301/25485)
# Processing user 76561198099625419 (302/25485)
# Processing user 76561198084032274 (303/25485)
# Processing user Angrovar (304/25485)
# Processing user AngryAinsley (305/25485)
# Processing user uradumbtit (306/25485)
# Processing user 76561198037038784 (307/25485)
# Processing user IKillNoobsFirst (308/25485)
# Processing user 76561198037888300 (309/25485)
# Processing user 1234865654 (310/25485)
# Processing user 76561198040925596 (311/25485)
# Processing user 76561198084123358 (312/25485)
# Processing user Apachehavoc (313/25485)
# Processing user ApexNZ (314/25485)
# Processing user 76561198039441595 (315/25485)
# Processing user 76561198036687918 (316/25485)
# Processing user benjamin27 (317/25485)
# Processing user AppoGetsSuperAdmin (318/25485)
# Processing user 76561198071475367 (319/25485)
# Processing user 76561198049916759 (320/25485)
# Processing user 76561198065064829 (321/25485)
# Processing user XABLAUziitu (322/25485)
# Processing user 76561198012909706 (323/25485)
# Processing user dragonchief (324/25485)
# Processing user 76561198040530605 (325/25485)
# Processing user 76561197974500703 (326/25485)
# Processing user 76561198047185525 (327/25485)
# Processing user sweep6060 (328/25485)
# Processing user bilyitu (329/25485)
# Processing user 76561198021244661 (330/25485)
# Processing user 76561198088538797 (331/25485)
# Processing user deployablearchnagel (332/25485)
# Processing user rotflmaoman (333/25485)
# Processing user armouredmarshmallow (334/25485)
# Processing user 76561198020928326 (335/25485)
# Processing user Array71 (336/25485)
# Processing user 76561198039874575 (337/25485)
# Processing user arronlim13 (338/25485)
# Processing user ARTHERDUNGER10 (339/25485)
# Processing user Mackus1011 (340/25485)
# Processing user 76561198041877981 (341/25485)
# Processing user ARZARNAR (342/25485)
# Processing user darkmassieh (343/25485)
# Processing user asianturtlefrenzy (344/25485)
# Processing user blowjobsfurdayzandgayz (345/25485)
# Processing user 76561198082992295 (346/25485)
# Processing user LaLocaDeLosDulces (347/25485)
# Processing user 76561198064352761 (348/25485)
# Processing user assassin_warman (349/25485)
# Processing user Astrelt (350/25485)
# Processing user 76561198091740831 (351/25485)
# Processing user AtomicWoodchuck (352/25485)
# Processing user omgihaveawebpage (353/25485)
# Processing user Swish0009 (354/25485)
# Processing user Aurora99 (355/25485)
# Processing user 76561198053071988 (356/25485)
# Processing user 76561198083375450 (357/25485)
# Processing user scroopy22 (358/25485)
# Processing user 76561198078730600 (359/25485)
# Processing user auzmoz (360/25485)
# Processing user auzzie_96 (361/25485)
# Processing user fatrangacuntnolifevirgin (362/25485)
# Processing user 76561198064150679 (363/25485)
# Processing user 76561198110293299 (364/25485)
# Processing user de_triggered (365/25485)
# Processing user 76561198071748311 (366/25485)
# Processing user Azrafael (367/25485)
# Processing user -Azsael- (368/25485)
# Processing user 76561198076301023 (369/25485)
# Processing user hoarbiscuit (370/25485)
# Processing user bohgeraltofrivia (371/25485)
# Processing user TeH-B-Rad (372/25485)
# Processing user BAW_Killer (373/25485)
# Processing user gamerdude7892 (374/25485)
# Processing user 2ez4medick (375/25485)
# Processing user BBBirb (376/25485)
# Processing user AgentXiri (377/25485)
# Processing user 76561197998761331 (378/25485)
# Processing user 76561198064579722 (379/25485)
# Processing user 76561198096750939 (380/25485)
# Processing user potatoskins (381/25485)
# Processing user crispymemesmantheyremyfavourite (382/25485)
# Processing user 76561198074409406 (383/25485)
# Processing user H-Alo (384/25485)
# Processing user 420Blz (385/25485)
# Processing user 76561198076548816 (386/25485)
# Processing user chillrend (387/25485)
# Processing user BarretaJrs (388/25485)
# Processing user Gborges (389/25485)
# Processing user lukeyturley (390/25485)
# Processing user PolygonCloud (391/25485)
# Processing user 76561198095142204 (392/25485)
# Processing user BOB_200 (393/25485)
# Processing user 76561198070735033 (394/25485)
# Processing user 76561198018560501 (395/25485)
# Processing user 76561198069458790 (396/25485)
# Processing user 76561198051148175 (397/25485)
# Processing user 76561198047208452 (398/25485)
# Processing user generalale (399/25485)
# Processing user brendoboy (400/25485)
# Processing user 76561198071234254 (401/25485)
# Processing user 76561198165870150 (402/25485)
# Processing user 76561197988934555 (403/25485)
# Processing user Infixation (404/25485)
# Processing user 76561198071162228 (405/25485)
# Processing user 76561198047304525 (406/25485)
# Processing user 76561197994969639 (407/25485)
# Processing user JuanManSnipez (408/25485)
# Processing user Ben_Andy (409/25485)
# Processing user Bennysaputra (410/25485)
# Processing user 76561198067021476 (411/25485)
# Processing user 76561198190487725 (412/25485)
# Processing user 76561198045071942 (413/25485)
# Processing user Bhappiikhat (414/25485)
# Processing user Ahahahahahahahahahahahahahahaha (415/25485)
# Processing user BITCHPLESE (416/25485)
# Processing user Too_1337 (417/25485)
# Processing user kinglemon1222 (418/25485)
# Processing user 76561198030636321 (419/25485)
# Processing user 76561198007342405 (420/25485)
# Processing user IJustWantedToTalk (421/25485)
# Processing user 76561198081885254 (422/25485)
# Processing user 76561198034643189 (423/25485)
# Processing user LlamasInNigjamas (424/25485)
# Processing user mavros88 (425/25485)
# Processing user 76561198035363871 (426/25485)
# Processing user Hummingsenpai (427/25485)
# Processing user CHAAANG (428/25485)
# Processing user 76561198056980314 (429/25485)
# Processing user 76561198077586769 (430/25485)
# Processing user bitmat (431/25485)
# Processing user 76561198028483487 (432/25485)
# Processing user Ghoster09 (433/25485)
# Processing user 76561198081496844 (434/25485)
# Processing user 180577 (435/25485)
# Processing user Barridos (436/25485)
# Processing user Blackhawk611 (437/25485)
# Processing user 76561197988863895 (438/25485)
# Processing user 76561198042728201 (439/25485)
# Processing user hbk1462 (440/25485)
# Processing user 76561198088724903 (441/25485)
# Processing user 76561198057521157 (442/25485)
# Processing user 76561198053766465 (443/25485)
# Processing user 76561198057389499 (444/25485)
# Processing user FHK (445/25485)
# Processing user 76561198030735076 (446/25485)
# Processing user Bluegills (447/25485)
# Processing user 76561197970931849 (448/25485)
# Processing user rrbr (449/25485)
# Processing user 13lazer (450/25485)
# Processing user 76561198044344399 (451/25485)
# Processing user 76561197999613236 (452/25485)
# Processing user RespekPlox (453/25485)
# Processing user 76561198062288797 (454/25485)
# Processing user bobseagull (455/25485)
# Processing user bokkkbokkk (456/25485)
# Processing user Bonesdontrattlethem (457/25485)
# Processing user 76561198062403736 (458/25485)
# Processing user 76561198073642113 (459/25485)
# Processing user 76561198211433640 (460/25485)
# Processing user ilyjoepoe (461/25485)
# Processing user Mantrouminati (462/25485)
# Processing user hididdlyhoe (463/25485)
# Processing user 76561198027225504 (464/25485)
# Processing user dicksoutforboromir (465/25485)
# Processing user probotsteve (466/25485)
# Processing user 76561197977543317 (467/25485)
# Processing user BrutalLegend69 (468/25485)
# Processing user 76561198007539695 (469/25485)
# Processing user 76561198064026657 (470/25485)
# Processing user 76561198024450886 (471/25485)
# Processing user saint556 (472/25485)
# Processing user Brayneeah (473/25485)
# Processing user brettebear (474/25485)
# Processing user metiqu (475/25485)
# Processing user Brianseb (476/25485)
# Processing user spike_heart (477/25485)
# Processing user brocky0405 (478/25485)
# Processing user 76561198046094676 (479/25485)
# Processing user Vladimirputinisgreatman (480/25485)
# Processing user Br0wni3 (481/25485)
# Processing user 76561198079351819 (482/25485)
# Processing user 76561198093381429 (483/25485)
# Processing user 76561198110065267 (484/25485)
# Processing user 76561198059167106 (485/25485)
# Processing user 76561198105270589 (486/25485)
# Processing user Trutle (487/25485)
# Processing user BugsyBro (488/25485)
# Processing user Jyep (489/25485)
# Processing user 76561198074561346 (490/25485)
# Processing user 76561198094074209 (491/25485)
# Processing user BurningCassette (492/25485)
# Processing user 76561198087011672 (493/25485)
# Processing user busternut (494/25485)
# Processing user 76561198075981950 (495/25485)
# Processing user Butteryyy (496/25485)
# Processing user 76561198079326390 (497/25485)
# Processing user 76561198142749308 (498/25485)
# Processing user 897w463824638109276 (499/25485)
# Processing user Butterz (500/25485)
# Processing user 8789568 (501/25485)
# Processing user 76561198112547239 (502/25485)
# Processing user ByzGirl (503/25485)
# Processing user C14M8S (504/25485)
# Processing user 1122305938 (505/25485)
# Processing user 76561198069050565 (506/25485)
# Processing user Cabey64 (507/25485)
# Processing user Cabjoy (508/25485)
# Processing user 76561198082278758 (509/25485)
# Processing user Stormaggen (510/25485)
# Processing user gusvu (511/25485)
# Processing user Punixa (512/25485)
# Processing user 76561198051084367 (513/25485)
# Processing user 76561198044402508 (514/25485)
# Processing user 76561198081987102 (515/25485)
# Processing user 76561197996741396 (516/25485)
# Processing user calii (517/25485)
# Processing user 76561198084718144 (518/25485)
# Processing user 76561198077034833 (519/25485)
# Processing user calypto52 (520/25485)
# Processing user camduman (521/25485)
# Processing user camquarter (522/25485)
# Processing user aquelecaraqfazaquilo (523/25485)
# Processing user 76561198079009374 (524/25485)
# Processing user 76561197992910116 (525/25485)
# Processing user jonjon4351 (526/25485)
# Processing user 76561198008551473 (527/25485)
# Processing user ThePyrite99 (528/25485)
# Processing user 76561198062276935 (529/25485)
# Processing user 76561198048121243 (530/25485)
# Processing user CAPTAINVRITRAS (531/25485)
# Processing user ConkerBirdy (532/25485)
# Processing user 76561198078194423 (533/25485)
# Processing user 76561198067657905 (534/25485)
# Processing user 76561198070072786 (535/25485)
# Processing user 76561197966764681 (536/25485)
# Processing user 76561198007988939 (537/25485)
# Processing user ca_ra_cal (538/25485)
# Processing user 76561198067721589 (539/25485)
# Processing user 76561197996092338 (540/25485)
# Processing user carouserwhite (541/25485)
# Processing user 76561198045631910 (542/25485)
# Processing user 76561198078670623 (543/25485)
# Processing user Lord_Casso (544/25485)
# Processing user 76561198058789410 (545/25485)
# Processing user 76561198070087725 (546/25485)
# Processing user fsfs546hd (547/25485)
# Processing user 76561198045283919 (548/25485)
# Processing user 76561198081438874 (549/25485)
# Processing user 76561198072411281 (550/25485)
# Processing user 76561198032143135 (551/25485)
# Processing user CrazyGiraffe71 (552/25485)
# Processing user chalkmetal (553/25485)
# Processing user kggj (554/25485)
# Processing user asdasdfsadgdfhfgjggj (555/25485)
# Processing user elheat (556/25485)
# Processing user ElementalGodChaos (557/25485)
# Processing user 76561197971917242 (558/25485)
# Processing user melonmaniac (559/25485)
# Processing user 76561198048491595 (560/25485)
# Processing user 76561198074108172 (561/25485)
# Processing user charmaps5 (562/25485)
# Processing user mexz1999 (563/25485)
# Processing user IchMasKung (564/25485)
# Processing user HoxtonPleaseDontSueMe (565/25485)
# Processing user 76561198051215704 (566/25485)
# Processing user 76561198058842042 (567/25485)
# Processing user 76561198074291619 (568/25485)
# Processing user cheetahpocalypse (569/25485)
# Processing user Axzothrift (570/25485)
# Processing user 76561198283109848 (571/25485)
# Processing user Chermoil (572/25485)
# Processing user harharharharhar (573/25485)
# Processing user chicken_tonight (574/25485)
# Processing user chidvd (575/25485)
# Processing user 76561198056960847 (576/25485)
# Processing user 76561198052700471 (577/25485)
# Processing user 76561198097450390 (578/25485)
# Processing user 76561197981448997 (579/25485)
# Processing user aerpub (580/25485)
# Processing user 76561198078733772 (581/25485)
# Processing user 76561198061273070 (582/25485)
# Processing user SmeshDoge (583/25485)
# Processing user 76561198037342853 (584/25485)
# Processing user 76561198062869989 (585/25485)
# Processing user harrisonnorris (586/25485)
# Processing user 76561198142474106 (587/25485)
# Processing user Los_Shmurdos (588/25485)
# Processing user ciborg2000 (589/25485)
# Processing user Mikinmash (590/25485)
# Processing user 76561198060510583 (591/25485)
# Processing user Norf_Norf (592/25485)
# Processing user 76561198041840982 (593/25485)
# Processing user 76561198056339034 (594/25485)
# Processing user OfficialSenix (595/25485)
# Processing user mike14476 (596/25485)
# Processing user kelby003 (597/25485)
# Processing user Clawz3z (598/25485)
# Processing user 76561198079650317 (599/25485)
# Processing user 76561198071207551 (600/25485)
# Processing user 76561198061039259 (601/25485)
# Processing user 76561198074202726 (602/25485)
# Processing user 76561198074347537 (603/25485)
# Processing user SurfChicken (604/25485)
# Processing user 76561198126142125 (605/25485)
# Processing user Clouwolf (606/25485)
# Processing user 76561198043339975 (607/25485)
# Processing user 69bmw (608/25485)
# Processing user 76561198067414480 (609/25485)
# Processing user 76561198078246064 (610/25485)
# Processing user iamshingo (611/25485)
# Processing user SirParadiseLost (612/25485)
# Processing user Rafantasma (613/25485)
# Processing user SupermanSocks17 (614/25485)
# Processing user 76561198061456632 (615/25485)
# Processing user 76561198049614185 (616/25485)
# Processing user 76561198046958203 (617/25485)
# Processing user UnseenEvangelist (618/25485)
# Processing user jichaelcoaching (619/25485)
# Processing user CompoBlue (620/25485)
# Processing user MT-101 (621/25485)
# Processing user 76561198172099661 (622/25485)
# Processing user ConjuredMadness (623/25485)
# Processing user cookieblade (624/25485)
# Processing user coolslayer666 (625/25485)
# Processing user cheese_is_illuminati (626/25485)
# Processing user 76561198042756236 (627/25485)
# Processing user ndrss (628/25485)
# Processing user 76561198081677554 (629/25485)
# Processing user Gamercubeeyes (630/25485)
# Processing user 76561198091515229 (631/25485)
# Processing user NotJustAnyOrange (632/25485)
# Processing user cosmicguy22 (633/25485)
# Processing user Cosmonaut123456789 (634/25485)
# Processing user 76561197971591275 (635/25485)
# Processing user TheCheekyOne (636/25485)
# Processing user aProfileInTheMidOfNowhere (637/25485)
# Processing user 76561198107928649 (638/25485)
# Processing user 76561198056352983 (639/25485)
# Processing user 76561198104404617 (640/25485)
# Processing user 76561198071955492 (641/25485)
# Processing user 76561198073799272 (642/25485)
# Processing user bruhbruhxd (643/25485)
# Processing user Crazymac123 (644/25485)
# Processing user 76561198135673978 (645/25485)
# Processing user 76561198045148546 (646/25485)
# Processing user 76561198077244610 (647/25485)
# Processing user 76561198063850360 (648/25485)
# Processing user 76561198080465715 (649/25485)
# Processing user CrimsonStormFTW (650/25485)
# Processing user cripla66 (651/25485)
# Processing user 76561198064305132 (652/25485)
# Processing user 76561198067214601 (653/25485)
# Processing user 76561198017913139 (654/25485)
# Processing user OldLeakyBoat (655/25485)
# Processing user SSAANNEESS (656/25485)
# Processing user fatkris (657/25485)
# Processing user cruzercru (658/25485)
# Processing user getyourmarsbar (659/25485)
# Processing user 76561198107811819 (660/25485)
# Processing user aweoplopo (661/25485)
# Processing user 76561198042921883 (662/25485)
# Processing user kanekicg (663/25485)
# Processing user 76561198048024738 (664/25485)
# Processing user 76561198084976671 (665/25485)
# Processing user THE_ART_OF_FEEDING (666/25485)
# Processing user Cynex_ (667/25485)
# Processing user 76561198039197193 (668/25485)
# Processing user 76561197996190797 (669/25485)
# Processing user 76561197995146150 (670/25485)
# Processing user 76561198082559637 (671/25485)
# Processing user DKA013 (672/25485)
# Processing user 76561198069345625 (673/25485)
# Processing user D00MS (674/25485)
# Processing user 76561198059201575 (675/25485)
# Processing user 76561198060901683 (676/25485)
# Processing user 76561198074763789 (677/25485)
# Processing user DABLUICE (678/25485)
# Processing user BlitzGames (679/25485)
# Processing user DaftyTM (680/25485)
# Processing user 76561197992227006 (681/25485)
# Processing user 76561198070775610 (682/25485)
# Processing user 76561198012514677 (683/25485)
# Processing user 76561198053111161 (684/25485)
# Processing user 76561197970691715 (685/25485)
# Processing user misterross (686/25485)
# Processing user 76561198044888778 (687/25485)
# Processing user mainkradxdxdx (688/25485)
# Processing user 76561198101576470 (689/25485)
# Processing user Dante69123 (690/25485)
# Processing user Dantress (691/25485)
# Processing user 76561198079220364 (692/25485)
# Processing user DareTheSeal (693/25485)
# Processing user blackcheeze (694/25485)
# Processing user 6dighero (695/25485)
# Processing user DarkDragonForce (696/25485)
# Processing user 76561198044594262 (697/25485)
# Processing user 76561198136941803 (698/25485)
# Processing user 76561198021814659 (699/25485)
# Processing user 76561198078913614 (700/25485)
# Processing user BOBROSSJPEGEXE (701/25485)
# Processing user blablabla174 (702/25485)
# Processing user fatppl (703/25485)
# Processing user 76561198050864519 (704/25485)
# Processing user datts (705/25485)
# Processing user sirkillsalot1337 (706/25485)
# Processing user 76561198082545803 (707/25485)
# Processing user 76561198115099755 (708/25485)
# Processing user 76561198046045640 (709/25485)
# Processing user 76561198195091390 (710/25485)
# Processing user damayo (711/25485)
# Processing user 76561198084697858 (712/25485)
# Processing user 76561198008827809 (713/25485)
# Processing user 76561198039605834 (714/25485)
# Processing user Yugm (715/25485)
# Processing user dblddr (716/25485)
# Processing user deathbreath220 (717/25485)
# Processing user 76561198084112448 (718/25485)
# Processing user 76561198097730477 (719/25485)
# Processing user DeepCrysis (720/25485)
# Processing user shay181 (721/25485)
# Processing user degen97 (722/25485)
# Processing user 76561197994831363 (723/25485)
# Processing user deltalink21 (724/25485)
# Processing user Qzt (725/25485)
# Processing user 76561198052661205 (726/25485)
# Processing user NZObiwan (727/25485)
# Processing user 76561198071716213 (728/25485)
# Processing user 76561198065988138 (729/25485)
# Processing user Denied72 (730/25485)
# Processing user 76561198034337192 (731/25485)
# Processing user 76561198056953510 (732/25485)
# Processing user 76561198047363411 (733/25485)
# Processing user 76561198068479124 (734/25485)
# Processing user GetMLGRekt (735/25485)
# Processing user BoyangBao (736/25485)
# Processing user meeman (737/25485)
# Processing user fuzzygrilz (738/25485)
# Processing user Derkness (739/25485)
# Processing user 76561198086282677 (740/25485)
# Processing user DerpyAura (741/25485)
# Processing user 76561198021745490 (742/25485)
# Processing user beepbeepimasheep (743/25485)
# Processing user 76561198032293266 (744/25485)
# Processing user 76561198057406795 (745/25485)
# Processing user 76561198074942714 (746/25485)
# Processing user 76561198091717988 (747/25485)
# Processing user 76561198126500843 (748/25485)
# Processing user destruktikus (749/25485)
# Processing user Des_Mondo (750/25485)
# Processing user 76561198066881691 (751/25485)
# Processing user 76561198042146054 (752/25485)
# Processing user 76561198093191096 (753/25485)
# Processing user Device600 (754/25485)
# Processing user Devmabby (755/25485)
# Processing user 76561197980614542 (756/25485)
# Processing user 76561197971532272 (757/25485)
# Processing user wenndiesoldaten (758/25485)
# Processing user TacticalLynx (759/25485)
# Processing user djman56 (760/25485)
# Processing user 76561198114039731 (761/25485)
# Processing user digfernandes (762/25485)
# Processing user dijakeplays (763/25485)
# Processing user ohplsguuby (764/25485)
# Processing user 76561198071578365 (765/25485)
# Processing user NathanielPeace (766/25485)
# Processing user 76561198054421576 (767/25485)
# Processing user 76561198072486822 (768/25485)
# Processing user 76561198099102298 (769/25485)
# Processing user 76561198077992470 (770/25485)
# Processing user 76561198059166102 (771/25485)
# Processing user 76561198038374904 (772/25485)
# Processing user ShrikeShrikeShrikeShrikeShrike (773/25485)
# Processing user efefuyg3g4u5u22u4yv (774/25485)
# Processing user 76561198058711482 (775/25485)
# Processing user dimitriirfan (776/25485)
# Processing user Dobble (777/25485)
# Processing user 76561198023903233 (778/25485)
# Processing user KingOfOpportunity (779/25485)
# Processing user doctorpotatoes (780/25485)
# Processing user 76561198103858676 (781/25485)
# Processing user 76561198083029873 (782/25485)
# Processing user 1920410 (783/25485)
# Processing user 76561198049760472 (784/25485)
# Processing user 6294421419 (785/25485)
# Processing user 76561198081443272 (786/25485)
# Processing user regentorange (787/25485)
# Processing user 76561198120646995 (788/25485)
# Processing user 76561197990557433 (789/25485)
# Processing user diglekango (790/25485)
# Processing user 76561198055370293 (791/25485)
# Processing user duzim (792/25485)
# Processing user 76561197995098683 (793/25485)
# Processing user DropBear99 (794/25485)
# Processing user banjoabbyshelly (795/25485)
# Processing user swscorpian (796/25485)
# Processing user thecosplayermotherfucker (797/25485)
# Processing user durolan2535 (798/25485)
# Processing user whatcanisayimjusttoogood (799/25485)
# Processing user 123repulseMe (800/25485)
# Processing user 76561197969800840 (801/25485)
# Processing user Cab117 (802/25485)
# Processing user DrVendax (803/25485)
# Processing user 76561198090773476 (804/25485)
# Processing user Dragoten (805/25485)
# Processing user thedragon347 (806/25485)
# Processing user 76561198015157743 (807/25485)
# Processing user 76561198073725626 (808/25485)
# Processing user 76561198084378649 (809/25485)
# Processing user 76561198172455607 (810/25485)
# Processing user DrMolo (811/25485)
# Processing user 76561198097534775 (812/25485)
# Processing user DrumEssence (813/25485)
# Processing user ashley1222 (814/25485)
# Processing user dubsdoge (815/25485)
# Processing user 76561198165512984 (816/25485)
# Processing user mrenigmate (817/25485)
# Processing user vitoprofile (818/25485)
# Processing user Axe603 (819/25485)
# Processing user 76561198057119793 (820/25485)
# Processing user 76561198090724989 (821/25485)
# Processing user JamesDurham23JubileeRd (822/25485)
# Processing user Congo-Jack (823/25485)
# Processing user 76561198018159202 (824/25485)
# Processing user 76561198080980901 (825/25485)
# Processing user 76561198066955730 (826/25485)
# Processing user 76561198056288026 (827/25485)
# Processing user dyslexicdew (828/25485)
# Processing user Dysloyal (829/25485)
# Processing user Eack (830/25485)
# Processing user 76561198008263039 (831/25485)
# Processing user 76561198060822442 (832/25485)
# Processing user 76561198049435011 (833/25485)
# Processing user 76561198084637047 (834/25485)
# Processing user 76561198105310142 (835/25485)
# Processing user edgar_its_the_popo (836/25485)
# Processing user riseofnations231 (837/25485)
# Processing user Efreak (838/25485)
# Processing user 76561198038840599 (839/25485)
# Processing user SuccForCancer (840/25485)
# Processing user UberDuckLord (841/25485)
# Processing user hashandtag (842/25485)
# Processing user JZargo4Pres (843/25485)
# Processing user XavvPlays (844/25485)
# Processing user 76561198056254879 (845/25485)
# Processing user ELCHUZZY69 (846/25485)
# Processing user 76561198053858353 (847/25485)
# Processing user 117331 (848/25485)
# Processing user Clarkos (849/25485)
# Processing user susanoofag (850/25485)
# Processing user eljefe2171 (851/25485)
# Processing user 76561198140431707 (852/25485)
# Processing user LapFucksTrax (853/25485)
# Processing user 76561198047866299 (854/25485)
# Processing user pon2543007 (855/25485)
# Processing user 76561198064445006 (856/25485)
# Processing user en-esta-partecita-esta-zacler (857/25485)
# Processing user 76561198075233562 (858/25485)
# Processing user EnderRay10420 (859/25485)
# Processing user Mr_Doge (860/25485)
# Processing user 76561198026040814 (861/25485)
# Processing user 76561198059783767 (862/25485)
# Processing user PurpleGenius (863/25485)
# Processing user 76561198048256508 (864/25485)
# Processing user 76561198154493361 (865/25485)
# Processing user epicsquid (866/25485)
# Processing user FedeAcv2 (867/25485)
# Processing user 76561198097219763 (868/25485)
# Processing user akiomio (869/25485)
# Processing user 76561198170217862 (870/25485)
# Processing user 76561198117877658 (871/25485)
# Processing user 76561198073082088 (872/25485)
# Processing user EternumHD (873/25485)
# Processing user SpecialSomeone (874/25485)
# Processing user compuguy123 (875/25485)
# Processing user 76561198041889877 (876/25485)
# Processing user 76561198054332392 (877/25485)
# Processing user 76561198014848587 (878/25485)
# Processing user 76561198064260593 (879/25485)
# Processing user hayen- (880/25485)
# Processing user 76561198068174077 (881/25485)
# Processing user 76561197995939652 (882/25485)
# Processing user hoot_toot (883/25485)
# Processing user 76561198028187926 (884/25485)
# Processing user ExtraEdition (885/25485)
# Processing user 76561198088408984 (886/25485)
# Processing user sgtkitty (887/25485)
# Processing user 76561198065247694 (888/25485)
# Processing user 76561198054549164 (889/25485)
# Processing user 76561198094506909 (890/25485)
# Processing user Letachal (891/25485)
# Processing user 76561198046912445 (892/25485)
# Processing user falynax (893/25485)
# Processing user PlainLukekil (894/25485)
# Processing user 76561198103524411 (895/25485)
# Processing user rockethaul (896/25485)
# Processing user 76561198106239471 (897/25485)
# Processing user 76561198085107826 (898/25485)
# Processing user 76561198073714126 (899/25485)
# Processing user 76561198047208774 (900/25485)
# Processing user whyiscustomurlathing (901/25485)
# Processing user FeatInk (902/25485)
# Processing user bigprenis (903/25485)
# Processing user 76561198068086235 (904/25485)
# Processing user dahaydos (905/25485)
# Processing user matt20131 (906/25485)
# Processing user 76561198028357316 (907/25485)
# Processing user 76561198090768760 (908/25485)
# Processing user Mrawes0m3 (909/25485)
# Processing user InsightXIVC (910/25485)
# Processing user 76561198054211660 (911/25485)
# Processing user izumireina (912/25485)
# Processing user Fetolino (913/25485)
# Processing user 76561198032373589 (914/25485)
# Processing user Fiesta787 (915/25485)
# Processing user 76561197960425229 (916/25485)
# Processing user 76561198057473311 (917/25485)
# Processing user 76561198068825441 (918/25485)
# Processing user LetsBeOn (919/25485)
# Processing user 76561198061285334 (920/25485)
# Processing user Takmid (921/25485)
# Processing user 76561198075229095 (922/25485)
# Processing user FiveCast (923/25485)
# Processing user 76561198003855855 (924/25485)
# Processing user OH_MY_GOSH (925/25485)
# Processing user modtech (926/25485)
# Processing user Fliqi (927/25485)
# Processing user adderz308 (928/25485)
# Processing user BajanCanidian (929/25485)
# Processing user Fluphy_ (930/25485)
# Processing user 76561198021135914 (931/25485)
# Processing user treemasterrace (932/25485)
# Processing user 76561198162487321 (933/25485)
# Processing user Anthonybasso (934/25485)
# Processing user 76561198081848896 (935/25485)
# Processing user 76561198124526584 (936/25485)
# Processing user 76561198044471846 (937/25485)
# Processing user FORTHMINGUTH (938/25485)
# Processing user TruBru (939/25485)
# Processing user 76561198007165405 (940/25485)
# Processing user tyrone266 (941/25485)
# Processing user Frankaloons (942/25485)
# Processing user jach5270 (943/25485)
# Processing user 76561197995338574 (944/25485)
# Processing user 76561198094830975 (945/25485)
# Processing user joshj23 (946/25485)
# Processing user 76561198066916378 (947/25485)
# Processing user idsoftwaresquake (948/25485)
# Processing user 76561198057781627 (949/25485)
# Processing user 76561198007208545 (950/25485)
# Processing user 76561198062924967 (951/25485)
# Processing user bradon745 (952/25485)
# Processing user farmerbillson (953/25485)
# Processing user iConnor_ (954/25485)
# Processing user 76561198093394236 (955/25485)
# Processing user 76561198091938654 (956/25485)
# Processing user dankememesforsweatyteens (957/25485)
# Processing user 76561198045421572 (958/25485)
# Processing user mudswipe (959/25485)
# Processing user dazahh (960/25485)
# Processing user 76561198019669521 (961/25485)
# Processing user 76561197985634755 (962/25485)
# Processing user 76561198067938749 (963/25485)
# Processing user maketeanotwar (964/25485)
# Processing user LeBovin (965/25485)
# Processing user FunkMeister1 (966/25485)
# Processing user 76561198141880878 (967/25485)
# Processing user 76561198071928116 (968/25485)
# Processing user 76561198079327998 (969/25485)
# Processing user 76561198025199025 (970/25485)
# Processing user jb2481 (971/25485)
# Processing user 76561198034573935 (972/25485)
# Processing user 76561198072724653 (973/25485)
# Processing user xKillerInstinct (974/25485)
# Processing user galvanicturtles (975/25485)
# Processing user JorazGamerGuy (976/25485)
# Processing user 76561198089131001 (977/25485)
# Processing user loominis (978/25485)
# Processing user tcase42 (979/25485)
# Processing user gatorgolfing (980/25485)
# Processing user Has2Ragretz (981/25485)
# Processing user 76561198067352691 (982/25485)
# Processing user 76561198060072424 (983/25485)
# Processing user 76561198065466146 (984/25485)
# Processing user SGSChief (985/25485)
# Processing user haonman (986/25485)
# Processing user HeavyfromHell (987/25485)
# Processing user MysticZemo (988/25485)
# Processing user gfire555 (989/25485)
# Processing user 76561198202329564 (990/25485)
# Processing user 76561198050768829 (991/25485)
# Processing user 76561198036861500 (992/25485)
# Processing user 76561198088472271 (993/25485)
# Processing user HiJason (994/25485)
# Processing user ghostlybug22 (995/25485)
# Processing user GiBaPEzLife (996/25485)
# Processing user 76561198079080583 (997/25485)
# Processing user 76561198079227569 (998/25485)
# Processing user gillinator (999/25485)
# Processing user 76561198095945803 (1000/25485)
# Processing user Wazzaa_man (1001/25485)
# Processing user 76561198075871336 (1002/25485)
# Processing user Glenbluey (1003/25485)
# Processing user 76561198071445832 (1004/25485)
# Processing user sunnnnnnnnnnnny (1005/25485)
# Processing user 76561198048230501 (1006/25485)
# Processing user Fishisaurus (1007/25485)
# Processing user Gterrestrial (1008/25485)
# Processing user Turntaker (1009/25485)
# Processing user 76561198052512374 (1010/25485)
# Processing user gothamsavior24 (1011/25485)
# Processing user uhhallo (1012/25485)
# Processing user Govostype0406 (1013/25485)
# Processing user 76561198003189312 (1014/25485)
# Processing user 76561198149213236 (1015/25485)
# Processing user farquadspenis (1016/25485)
# Processing user FullTimeSilver3 (1017/25485)
# Processing user GravityI (1018/25485)
# Processing user 76561198100417292 (1019/25485)
# Processing user 76561197996156672 (1020/25485)
# Processing user GREENMAN41 (1021/25485)
# Processing user 76561198066611105 (1022/25485)
# Processing user Grelekzel (1023/25485)
# Processing user 76561198016940185 (1024/25485)
# Processing user greyson_4450 (1025/25485)
# Processing user 76561198138586856 (1026/25485)
# Processing user ReapersHunt (1027/25485)
# Processing user luduwick (1028/25485)
# Processing user GirlzLikeBears (1029/25485)
# Processing user TheWaterGod (1030/25485)
# Processing user sphix (1031/25485)
# Processing user 76561198070892581 (1032/25485)
# Processing user guhou (1033/25485)
# Processing user GuihZito (1034/25485)
# Processing user mastergamerinfinity (1035/25485)
# Processing user Spiritedaway1 (1036/25485)
# Processing user GungeonRighteer (1037/25485)
# Processing user 76561198062447997 (1038/25485)
# Processing user gusso10_ (1039/25485)
# Processing user 76561198053608159 (1040/25485)
# Processing user Habbyman (1041/25485)
# Processing user 76561197970519408 (1042/25485)
# Processing user Haelnorr (1043/25485)
# Processing user 76561198082179266 (1044/25485)
# Processing user Haitroid (1045/25485)
# Processing user 76561198299095634 (1046/25485)
# Processing user 76561198021575394 (1047/25485)
# Processing user 76561198074079694 (1048/25485)
# Processing user Halio99 (1049/25485)
# Processing user HallowedDragon (1050/25485)
# Processing user halofreak61 (1051/25485)
# Processing user HamThePanMan (1052/25485)
# Processing user 76561198043275956 (1053/25485)
# Processing user hand0fcthulhu (1054/25485)
# Processing user 76561198065866954 (1055/25485)
# Processing user supersushi987 (1056/25485)
# Processing user sopramudar (1057/25485)
# Processing user 76561198080881484 (1058/25485)
# Processing user 76561198038572397 (1059/25485)
# Processing user 76561198081776244 (1060/25485)
# Processing user 76561198081114534 (1061/25485)
# Processing user 76561198077993857 (1062/25485)
# Processing user OfficialRagey (1063/25485)
# Processing user TittyDestroyer (1064/25485)
# Processing user xxxkennySopxxx (1065/25485)
# Processing user 76561198083095219 (1066/25485)
# Processing user HAramabeeHarrrisssooon (1067/25485)
# Processing user DANKESTMEMEMACHINEEVER (1068/25485)
# Processing user lucky-seven (1069/25485)
# Processing user DeliciousPuddin (1070/25485)
# Processing user 76561198119721428 (1071/25485)
# Processing user 76561198072072529 (1072/25485)
# Processing user 76561198121314683 (1073/25485)
# Processing user 76561198123168383 (1074/25485)
# Processing user harrylolman (1075/25485)
# Processing user Harv3yy (1076/25485)
# Processing user 76561198046718131 (1077/25485)
# Processing user Rambo1061 (1078/25485)
# Processing user harvse (1079/25485)
# Processing user corhodzic (1080/25485)
# Processing user hawaiianisswag (1081/25485)
# Processing user 76561198066734993 (1082/25485)
# Processing user 76561198103362354 (1083/25485)
# Processing user Nzatz (1084/25485)
# Processing user fil96 (1085/25485)
# Processing user 76561198070092383 (1086/25485)
# Processing user hecaton_john (1087/25485)
# Processing user 76561198088531301 (1088/25485)
# Processing user 76561198042879129 (1089/25485)
# Processing user TDOJ3DTDO (1090/25485)
# Processing user HeliDash (1091/25485)
# Processing user punkinoz (1092/25485)
# Processing user imsufferingkillme (1093/25485)
# Processing user hellotherem8 (1094/25485)
# Processing user fintanboy (1095/25485)
# Processing user henrydxb (1096/25485)
# Processing user 76561198059990081 (1097/25485)
# Processing user bobthehappyterroriest (1098/25485)
# Processing user PimpIt (1099/25485)
# Processing user 76561198062484829 (1100/25485)
# Processing user 76561198055335886 (1101/25485)
# Processing user 76561198070690856 (1102/25485)
# Processing user 76561198045953692 (1103/25485)
# Processing user 216712138 (1104/25485)
# Processing user 76561198006679831 (1105/25485)
# Processing user hewl (1106/25485)
# Processing user Gawee08 (1107/25485)
# Processing user 76561198123074348 (1108/25485)
# Processing user koconut100 (1109/25485)
# Processing user 76561198036822015 (1110/25485)
# Processing user highpr (1111/25485)
# Processing user CyberBlade (1112/25485)
# Processing user 76561198042823843 (1113/25485)
# Processing user stevenlikesdicks (1114/25485)
# Processing user Hollowfun (1115/25485)
# Processing user holyswifter (1116/25485)
# Processing user WildCheese (1117/25485)
# Processing user 76561198079621961 (1118/25485)
# Processing user 76561198080786408 (1119/25485)
# Processing user quadruplemoney (1120/25485)
# Processing user 76561198080644089 (1121/25485)
# Processing user peoplesidiot (1122/25485)
# Processing user IrishNZ (1123/25485)
# Processing user iareasdaft (1124/25485)
# Processing user kylesimmonds (1125/25485)
# Processing user DazzaPlays (1126/25485)
# Processing user horizon95 (1127/25485)
# ...
# Processing user 76561198131096197 (25127/25485)
# Processing user 76561198131181299 (25128/25485)
# Processing user allanhammon (25129/25485)
# Processing user 76561198131370221 (25130/25485)
# Processing user 76561198131383023 (25131/25485)
# Processing user 76561198131459436 (25132/25485)
# Processing user 76561198131557668 (25133/25485)
# Processing user Kyubi99 (25134/25485)
# Processing user 76561198131937518 (25135/25485)
# Processing user hayda123 (25136/25485)
# Processing user 76561198132039660 (25137/25485)
# Processing user padyay2 (25138/25485)
# Processing user cassiexDD (25139/25485)
# Processing user 76561198132083512 (25140/25485)
# Processing user 76561198132273399 (25141/25485)
# Processing user 76561198132624943 (25142/25485)
# Processing user 76561198132637732 (25143/25485)
# Processing user 76561198132730100 (25144/25485)
# Processing user 76561198132859612 (25145/25485)
# Processing user Ma5terEthan (25146/25485)
# Processing user 76561198133180878 (25147/25485)
# Processing user issepol (25148/25485)
# Processing user 76561198133288603 (25149/25485)
# Processing user 76561198133319761 (25150/25485)
# Processing user 76561198133543733 (25151/25485)
# Processing user 76561198133637161 (25152/25485)
# Processing user xoeairrr (25153/25485)
# Processing user 76561198134104596 (25154/25485)
# Processing user 76561198134139139 (25155/25485)
# Processing user salthesquirrel (25156/25485)
# Processing user 76561198134165301 (25157/25485)
# Processing user 76561198134341792 (25158/25485)
# Processing user 76561198134453088 (25159/25485)
# Processing user xX_Z4N_Xx (25160/25485)
# Processing user chuckles382 (25161/25485)
# Processing user 76561198134648837 (25162/25485)
# Processing user 76561198134732704 (25163/25485)
# Processing user hfeygugbuhg (25164/25485)
# Processing user Atomic_Unicorn_7 (25165/25485)
# Processing user nz_killahz (25166/25485)
# Processing user 79694738686698975975 (25167/25485)
# Processing user SamuelTepes (25168/25485)
# Processing user 76561198135631832 (25169/25485)
# Processing user VegetaSenpai (25170/25485)
# Processing user codex131 (25171/25485)
# Processing user 76561198135997971 (25172/25485)
# Processing user 76561198136064861 (25173/25485)
# Processing user 76561198136202915 (25174/25485)
# Processing user 76561198136207352 (25175/25485)
# Processing user 76561198136215651 (25176/25485)
# Processing user chickengooby (25177/25485)
# Processing user cyborgeinstein (25178/25485)
# Processing user 76561198136953069 (25179/25485)
# Processing user Kieralicous (25180/25485)
# Processing user netcodebio (25181/25485)
# Processing user 76561198136998398 (25182/25485)
# Processing user 76561198137010978 (25183/25485)
# Processing user 76561198137164994 (25184/25485)
# Processing user victorlam111 (25185/25485)
# Processing user talibanstorm (25186/25485)
# Processing user 76561198137568508 (25187/25485)
# Processing user 76561198137941512 (25188/25485)
# Processing user zmeygorinich150 (25189/25485)
# Processing user FlamingORB (25190/25485)
# Processing user Anarchismatitsfinist (25191/25485)
# Processing user solelywolf (25192/25485)
# Processing user WonderTop (25193/25485)
# Processing user mataway (25194/25485)
# Processing user dani3l3262 (25195/25485)
# Processing user 76561198138691719 (25196/25485)
# Processing user SwagmasterWellingtune (25197/25485)
# Processing user potatokid2009 (25198/25485)
# Processing user The_Lorangatang (25199/25485)
# Processing user 76561198138994931 (25200/25485)
# Processing user 76561198139327660 (25201/25485)
# Processing user 320RustPro (25202/25485)
# Processing user Brocklix (25203/25485)
# Processing user 76561198139533051 (25204/25485)
# Processing user SEGASURD259 (25205/25485)
# Processing user 76561198139687835 (25206/25485)
# Processing user 76561198139870694 (25207/25485)
# Processing user 76561198139928409 (25208/25485)
# Processing user CharlesMate (25209/25485)
# Processing user MatthewTsirides (25210/25485)
# Processing user 76561198140459669 (25211/25485)
# Processing user brazzershd (25212/25485)
# Processing user 76561198140607750 (25213/25485)
# Processing user SKELETRONPRIMEISOP (25214/25485)
# Processing user 76561198140985236 (25215/25485)
# Processing user 76561198141079508 (25216/25485)
# Processing user 76561198141352940 (25217/25485)
# Processing user 76561198141383050 (25218/25485)
# Processing user blackdmulisha (25219/25485)
# Processing user 76561198141694307 (25220/25485)
# Processing user 76561198141889949 (25221/25485)
# Processing user asjunnn (25222/25485)
# Processing user endradigo (25223/25485)
# Processing user quite_the (25224/25485)
# Processing user Ash1261 (25225/25485)
# Processing user 76561198142429917 (25226/25485)
# Processing user turdicles (25227/25485)
# Processing user 76561198142606609 (25228/25485)
# Processing user 76561198142646079 (25229/25485)
# Processing user 76561198142695199 (25230/25485)
# Processing user 76561198142813123 (25231/25485)
# Processing user 76561198142902055 (25232/25485)
# Processing user ProfessorHashtag (25233/25485)
# Processing user 76561198143089719 (25234/25485)
# Processing user 76561198143329709 (25235/25485)
# Processing user br33ny (25236/25485)
# Processing user rhys3852 (25237/25485)
# Processing user hicancerbaws (25238/25485)
# Processing user 76561198143785725 (25239/25485)
# Processing user cantreportmelickmyass (25240/25485)
# Processing user hlebteampro (25241/25485)
# Processing user 76561198143918354 (25242/25485)
# Processing user Hamish_Birch (25243/25485)
# Processing user L_DiCaprio (25244/25485)
# Processing user AdrianC88 (25245/25485)
# Processing user Coreyt549 (25246/25485)
# Processing user 42456 (25247/25485)
# Processing user TrabicTheII (25248/25485)
# Processing user feelgoodincc (25249/25485)
# Processing user beddoni (25250/25485)
# Processing user 76561198146796603 (25251/25485)
# Processing user 76561198146806915 (25252/25485)
# Processing user teaza13za (25253/25485)
# Processing user nottynotty (25254/25485)
# Processing user 76561198147106771 (25255/25485)
# Processing user 76561198147204783 (25256/25485)
# Processing user VenusNeko (25257/25485)
# Processing user mizi (25258/25485)
# Processing user MG_Fuzion (25259/25485)
# Processing user jakefarnsdirttrack (25260/25485)
# Processing user Jmanza420 (25261/25485)
# Processing user 76561198147832762 (25262/25485)
# Processing user SomeRandomNewAccount (25263/25485)
# Processing user 76561198147908192 (25264/25485)
# Processing user Tredders6635 (25265/25485)
# Processing user AilensAreNeverAmongUs (25266/25485)
# Processing user SaBeR_ (25267/25485)
# Processing user Hp4SmXCGYuc (25268/25485)
# Processing user cozzabro (25269/25485)
# Processing user 76561198148904255 (25270/25485)
# Processing user 76561198148988655 (25271/25485)
# Processing user 76561198149074032 (25272/25485)
# Processing user KANGAWOLAFOX (25273/25485)
# Processing user calello88 (25274/25485)
# Processing user 76561198149544451 (25275/25485)
# Processing user cslng1111111 (25276/25485)
# Processing user pizzajesus (25277/25485)
# Processing user permanently-a-cat-lady (25278/25485)
# Processing user thisisatrash (25279/25485)
# Processing user officialAlex3y (25280/25485)
# Processing user ivanyao88 (25281/25485)
# Processing user 76561198150605293 (25282/25485)
# Processing user me2118 (25283/25485)
# Processing user 76561198151618926 (25284/25485)
# Processing user BreckiRedi (25285/25485)
# Processing user 123123123131231231 (25286/25485)
# Processing user mlgbongsquad (25287/25485)
# Processing user 76561198152913733 (25288/25485)
# Processing user SlothTime (25289/25485)
# Processing user ShadowRyze (25290/25485)
# Processing user NamerGamer69 (25291/25485)
# Processing user 76561198153360103 (25292/25485)
# Processing user BabyLeviathan (25293/25485)
# Processing user 76561198153660339 (25294/25485)
# Processing user SponsoredByBenQ (25295/25485)
# Processing user Jess111 (25296/25485)
# Processing user SoraThailand (25297/25485)
# Processing user 76561198154265296 (25298/25485)
# Processing user 76561198154626659 (25299/25485)
# Processing user 76561198155168543 (25300/25485)
# Processing user tvrvirtux (25301/25485)
# Processing user 76561198155410391 (25302/25485)
# Processing user BadMadMurphy (25303/25485)
# Processing user AlphaPodbury (25304/25485)
# Processing user NEYMRJR (25305/25485)
# Processing user 76561198155824473 (25306/25485)
# Processing user 76561198156015935 (25307/25485)
# Processing user cranialperv (25308/25485)
# Processing user Hatergonewiild (25309/25485)
# Processing user valinorau (25310/25485)
# Processing user Azzaaaa (25311/25485)
# Processing user kalagan123 (25312/25485)
# Processing user uncleshenny (25313/25485)
# Processing user saSZapauer (25314/25485)
# Processing user TheRealBangz (25315/25485)
# Processing user 76561198158553602 (25316/25485)
# Processing user ben_oco1 (25317/25485)
# Processing user GamingDope (25318/25485)
# Processing user grmd2 (25319/25485)
# Processing user ButNae (25320/25485)
# Processing user 76561198161001019 (25321/25485)
# Processing user 76561198161220449 (25322/25485)
# Processing user 76561198161415002 (25323/25485)
# Processing user KillKenny2122 (25324/25485)
# Processing user 76561198162065948 (25325/25485)
# Processing user GamingAce (25326/25485)
# Processing user 76561198162375835 (25327/25485)
# Processing user HyperYooo (25328/25485)
# Processing user Raider8799 (25329/25485)
# Processing user 76561198163760109 (25330/25485)
# Processing user 76561198164570126 (25331/25485)
# Processing user 76561198165286287 (25332/25485)
# Processing user 76561198165466207 (25333/25485)
# Processing user andyroidster (25334/25485)
# Processing user 76561198165674451 (25335/25485)
# Processing user Slicorice (25336/25485)
# Processing user 76561198166061333 (25337/25485)
# Processing user 76561198166194627 (25338/25485)
# Processing user 76561198166303039 (25339/25485)
# Processing user dontneedtoknow (25340/25485)
# Processing user Freakazoidz (25341/25485)
# Processing user ShadowYT100 (25342/25485)
# Processing user Scruffy681 (25343/25485)
# Processing user W3LSHY (25344/25485)
# Processing user FlakeTrades (25345/25485)
# Processing user freeteamfortress2itemsgiveaway (25346/25485)
# Processing user 76561198167847213 (25347/25485)
# Processing user Mooseox (25348/25485)
# Processing user 76561198168132031 (25349/25485)
# Processing user Durp1234 (25350/25485)
# Processing user Spreii (25351/25485)
# Processing user darren4500 (25352/25485)
# Processing user NSGLOLGAMER (25353/25485)
# Processing user the_simulacra (25354/25485)
# Processing user gavvv (25355/25485)
# Processing user 76561198169928263 (25356/25485)
# Processing user imakeclocks (25357/25485)
# Processing user KrillUrself (25358/25485)
# Processing user Section_279 (25359/25485)
# Processing user 76561198170661539 (25360/25485)
# Processing user LakituLucas (25361/25485)
# Processing user 76561198172360410 (25362/25485)
# Processing user 76561198172394339 (25363/25485)
# Processing user brodielatimer (25364/25485)
# Processing user pingaas (25365/25485)
# Processing user DreamingTillDawnAlt2 (25366/25485)
# Processing user 76561198174605218 (25367/25485)
# Processing user pingasss4daysss (25368/25485)
# Processing user maddydufall (25369/25485)
# Processing user 76561198177168627 (25370/25485)
# Processing user badxbox (25371/25485)
# Processing user Bradz (25372/25485)
# Processing user HughMyFriend (25373/25485)
# Processing user DuckM80 (25374/25485)
# Processing user wosie009 (25375/25485)
# Processing user 76561198179668470 (25376/25485)
# Processing user Fezi (25377/25485)
# Processing user BottleTopNation (25378/25485)
# Processing user DownSyndromeWombat (25379/25485)
# Processing user SphereAce (25380/25485)
# Processing user 76561198182057073 (25381/25485)
# Processing user zigzagsoft (25382/25485)
# Processing user 76561198184108699 (25383/25485)
# Processing user StrangeOfficial (25384/25485)
# Processing user 76561198185106509 (25385/25485)
# Processing user cyvoxfromyoutube (25386/25485)
# Processing user jazzecks (25387/25485)
# Processing user 76561198187081679 (25388/25485)
# Processing user wrenchbloke (25389/25485)
# Processing user luncetalos (25390/25485)
# Processing user 76561198189432654 (25391/25485)
# Processing user lachwe (25392/25485)
# Processing user wendyfiore (25393/25485)
# Processing user danebuchanan (25394/25485)
# Processing user Salttyy (25395/25485)
# Processing user 76561198191146478 (25396/25485)
# Processing user 76561198191648654 (25397/25485)
# Processing user K1NGCJS (25398/25485)
# Processing user gramps10289098 (25399/25485)
# Processing user 76561198194200105 (25400/25485)
# Processing user thegalaxyfutureyoutuber (25401/25485)
# Processing user 76561198196131562 (25402/25485)
# Processing user 76561198196614946 (25403/25485)
# Processing user laislabonita75 (25404/25485)
# Processing user evilindiegaming (25405/25485)
# Processing user 0412734634 (25406/25485)
# Processing user alphahostage (25407/25485)
# Processing user F4ND4NGL3DXD (25408/25485)
# Processing user TripleQMark (25409/25485)
# Processing user 76561198202877783 (25410/25485)
# Processing user HipP0p2 (25411/25485)
# Processing user huangsy (25412/25485)
# Processing user celebrexISGO (25413/25485)
# Processing user 76561198204448251 (25414/25485)
# Processing user BBiiiirr (25415/25485)
# Processing user Gamer0009 (25416/25485)
# Processing user globalLV (25417/25485)
# Processing user Keenno90 (25418/25485)
# Processing user 76561198208507532 (25419/25485)
# Processing user 76561198208704549 (25420/25485)
# Processing user NikitaOsworth1991 (25421/25485)
# Processing user bestcustomurlevermade (25422/25485)
# Processing user 76561198209667851 (25423/25485)
# Processing user 76561198209894493 (25424/25485)
# Processing user themenaceonpc (25425/25485)
# Processing user lazasmurf (25426/25485)
# Processing user 76561198212354172 (25427/25485)
# Processing user 225555 (25428/25485)
# Processing user 76561198216570016 (25429/25485)
# Processing user 76561198216894008 (25430/25485)
# Processing user Hahneex (25431/25485)
# Processing user 76561198219561792 (25432/25485)
# Processing user llDracuwulf (25433/25485)
# Processing user 76561198222628548 (25434/25485)
# Processing user 76561198223837952 (25435/25485)
# Processing user 76561198225879872 (25436/25485)
# Processing user 76561198226666576 (25437/25485)
# Processing user 76561198227671916 (25438/25485)
# Processing user 01shan (25439/25485)
# Processing user 112367263762 (25440/25485)
# Processing user 76561198229845636 (25441/25485)
# Processing user 76561198232198516 (25442/25485)
# Processing user 76561198232478272 (25443/25485)
# Processing user Assult_Satan (25444/25485)
# Processing user 76561198236893796 (25445/25485)
# Processing user pigeonie (25446/25485)
# Processing user 76561198237650078 (25447/25485)
# Processing user AusBacon (25448/25485)
# Processing user Tattzie (25449/25485)
# Processing user 76561198239215706 (25450/25485)
# Processing user wayfeng (25451/25485)
# Processing user 76561198251004808 (25452/25485)
# Processing user 76561198251328528 (25453/25485)
# Processing user 76561198254993106 (25454/25485)
# Processing user kimjongadam (25455/25485)
# Processing user 72947282842 (25456/25485)
# Processing user ZaubieHunter23 (25457/25485)
# Processing user ApxLGhost (25458/25485)
# Processing user iwishihadaids (25459/25485)
# Processing user 76561198261200685 (25460/25485)
# Processing user SenpaiDemon (25461/25485)
# Processing user snarkcornwtt (25462/25485)
# Processing user Fuckfhaisjnsnsjakaka (25463/25485)
# Processing user 3214213216 (25464/25485)
# Processing user ChrisCoroner (25465/25485)
# Processing user CaptainAmericaCw (25466/25485)
# Processing user 76561198267374962 (25467/25485)
# Processing user KinkyyyCSGO (25468/25485)
# Processing user 76561198270958927 (25469/25485)
# Processing user elasticgoose (25470/25485)
# Processing user 76561198272389051 (25471/25485)
# Processing user MeloncraftLP (25472/25485)
# Processing user 76561198277602337 (25473/25485)
# Processing user 943525 (25474/25485)
# Processing user vinquility (25475/25485)
# Processing user 76561198289386531 (25476/25485)
# Processing user GodLoveGuru (25477/25485)
# Processing user sexyawp (25478/25485)
# Processing user 76561198296402247 (25479/25485)
# Processing user JustMielThings (25480/25485)
# Processing user 76561198306599751 (25481/25485)
# Processing user Ghoustik (25482/25485)
# Processing user 76561198310819422 (25483/25485)
# Processing user 76561198312638244 (25484/25485)
# Processing user LydiaMorley (25485/25485)

# %%
# Out:
# defaultdict(list,
#             {'76561198079601835': ['236'],
#              'MeaTCompany': ['236'],
#              '76561198061252210': ['236'],
#              '76561198028895010': ['234'],
#              'Rivtex': ['447'],
#              'lucaswerg': ['1100'],
#              'MainScout': ['233'],
#              '76561198056741844': ['236'],
#              '76561198061730629': ['233'],
#              'whiteofwolfing': ['236'],
#              '76561198056290589': ['236'],
#              'Hirukaz': ['233'],
#              'mimimomoma': ['236'],
#              '76561198074200011': ['236'],
#              'YieuwMage': ['236'],
#              '76561198078752187': ['236', '240'],
#              'getf0kinn0sc0pedm9': ['236'],
#              '76561198141443390': ['236'],
#              'whodafuqisthisguilao': ['236'],
#              '76561198078478151': ['236'],
#              'EizanAratoFujimaki': ['237'],
#              '76561198051258119': ['236'],
#              'relesprit': ['575'],
#              '76561198031207016': ['575'],
#              '76561197961778802': ['236'],
#              '76561198075322986': ['236'],
#              '3dster': ['233'],
#              '76561198092227136': ['612'],
#              '76561198064304806': ['236'],
#              'acorn13': ['166', '264', '265'],
#              'cancerkek': ['236'],
#              'EndAtHallow': ['612'],
#              '76561198187212131': ['236'],
#              'alansiulun': ['374'],
#              '76561198164545985': ['236'],
#              'IKillNoobsFirst': ['236'],
#              'benjamin27': ['236'],
#              'rotflmaoman': ['139'],
#              '76561198020928326': ['237'],
#              'auzzie_96': ['448'],
#              '-Azsael-': ['274'],
#              '76561198165870150': ['236'],
#              'JuanManSnipez': ['236'],
#              'LlamasInNigjamas': ['236'],
#              'FHK': ['983'],
#              'metiqu': ['236'],
#              'spike_heart': ['549', '17', '547'],
#              'Br0wni3': ['236'],
#              '76561198051084367': ['868'],
#              '76561198084718144': ['262'],
#              '76561197966764681': ['236'],
#              'ca_ra_cal': ['1265', '1208', '1138', '1107'],
#              '76561198081438874': ['435'],
#              '76561198074108172': ['236'],
#              '76561198037342853': ['236'],
#              'SurfChicken': ['236'],
#              'coolslayer666': ['236'],
#              'cheese_is_illuminati': ['236'],
#              'Gamercubeeyes': ['166', '264', '265'],
#              'aProfileInTheMidOfNowhere': ['236'],
#              'DaftyTM': ['236'],
#              '76561198079220364': ['257'],
#              '76561198136941803': ['236'],
#              'datts': ['236'],
#              'DeepCrysis': ['236'],
#              'Denied72': ['1100'],
#              '76561198056953510': ['257'],
#              '76561198047363411': ['236'],
#              'Device600': ['236'],
#              '76561197980614542': ['236'],
#              'TacticalLynx': ['236'],
#              '76561198071578365': ['236'],
#              'dimitriirfan': ['236'],
#              'KingOfOpportunity': ['257'],
#              '76561198049760472': ['236'],
#              '76561197990557433': ['575'],
#              'banjoabbyshelly': ['166', '264', '265'],
#              'whatcanisayimjusttoogood': ['257'],
#              'DrMolo': ['236'],
#              '76561198018159202': ['236'],
#              'riseofnations231': ['236'],
#              'SuccForCancer': ['575'],
#              '76561198170217862': ['575'],
#              'SpecialSomeone': ['236'],
#              'hayen-': ['236'],
#              '76561198068174077': ['236'],
#              'falynax': ['236'],
#              '76561198106239471': ['236'],
#              '76561198073714126': ['236'],
#              '76561198068086235': ['257'],
#              'Takmid': ['1100'],
#              '76561198075229095': ['1100'],
#              'Fliqi': ['236'],
#              'adderz308': ['236'],
#              'TruBru': ['755'],
#              '76561198094830975': ['236'],
#              'bradon745': ['236'],
#              '76561198093394236': ['166', '264', '265'],
#              '76561198067938749': ['236'],
#              '76561198072724653': ['236'],
#              'xKillerInstinct': ['236'],
#              '76561198036861500': ['233'],
#              'Govostype0406': ['435'],
#              'FullTimeSilver3': ['236'],
#              'guhou': ['983'],
#              'GuihZito': ['236'],
#              'Spiritedaway1': ['1100'],
#              '76561198062447997': ['236'],
#              'gusso10_': ['262'],
#              'sopramudar': ['312'],
#              '76561198081776244': ['1100'],
#              '76561198081114534': ['236'],
#              '76561198077993857': ['236'],
#              '76561198121314683': ['374'],
#              'corhodzic': ['236'],
#              '76561198103362354': ['236'],
#              'punkinoz': ['236'],
#              'henrydxb': ['612', '233'],
#              'stevenlikesdicks': ['236'],
#              '76561198079621961': ['1100'],
#              '76561198080786408': ['236'],
#              'iareasdaft': ['250'],
#              'b167er': ['236'],
#              '76561198083780235': ['236'],
#              'huy115': ['236'],
#              '76561198139694944': ['236'],
#              'itschewz': ['249'],
#              'offlinebyourmine': ['1158'],
#              'naomibby': ['236'],
#              'hzqBICEPS': ['236'],
#              '76561198034167696': ['236'],
#              '76561198055499125': ['312'],
#              'sweatmore': ['236'],
#              'guidetti1': ['236'],
#              'Issekara': ['575'],
#              'jinmanabe': ['236'],
#              'JamsL33T': ['236'],
#              'Memphis__': ['236'],
#              '76561198115194725': ['236'],
#              '2ZESTY4ME': ['233'],
#              '76561198081148689': ['236'],
#              'Joshman106': ['236'],
#              'iloveyouus': ['236'],
#              '76561198219902115': ['236'],
#              '76561198081529182': ['612'],
#              '76561198074700614': ['257'],
#              '76561198070706154': ['236'],
#              'JusicTheGod': ['236'],
#              'kiricky': ['236'],
#              'druittmatee': ['236'],
#              'kurbi-wan_kenobi': ['166', '264', '265'],
#              'BAMOSABENSER': ['236'],
#              '76561198113520617': ['236'],
#              'lachd1223': ['1146', '1147', '758'],
#              'OfficialLandyy': ['236'],
#              '76561198130025891': ['236'],
#              '23184798': ['236'],
#              'LordDefault': ['236'],
#              'whoisming': ['236'],
#              '76561198092577173': ['447'],
#              'FromTheDepthsOfHell': ['236'],
#              'lulzley': ['236'],
#              'J_Gismondi': ['236'],
#              'masonplays2': ['236'],
#              'maxristevski': ['236'],
#              'chemicalizedacid': ['236'],
#              '76561198075552656': ['257'],
#              'madcow2234': ['257'],
#              'mesmic13': ['250'],
#              '76561198131748854': ['236'],
#              'corbinanderson94': ['236'],
#              '76561198053697018': ['476'],
#              '34324132': ['312'],
#              '76561198053085687': ['612'],
#              '76561198073085657': ['166', '264', '265'],
#              'killergrimes': ['236'],
#              '76561198092547722': ['166', '264', '265'],
#              'MuddyHikoku': ['257'],
#              'error404olofmeister': ['236'],
#              'nutinme': ['236'],
#              '76561198295350017': ['233'],
#              'OMGitsaBIKDeek': ['236'],
#              'Natty22': ['236'],
#              'GussyPlays': ['236'],
#              'AtomicNarwhal': ['236'],
#              '76561198101278301': ['236'],
#              'STEAM_NEKO': ['233'],
#              '76561198052411042': ['257'],
#              'wildninja111': ['236'],
#              '76561198045254790': ['236'],
#              'PyroProfile': ['250'],
#              'nomopro': ['236'],
#              'notsurodovahbear': ['312'],
#              '76561198041562431': ['236'],
#              '76561198081997185': ['236'],
#              '76561198243634570': ['1100'],
#              'polandismycountry': ['236'],
#              '76561198079333493': ['236'],
#              '76561198121840547': ['1100'],
#              'zenrosmc': ['234'],
#              '76561198093337643': ['233'],
#              'pedrocarrasco': ['236'],
#              'penetrator500': ['236'],
#              '5975': ['374'],
#              'lPH03N1Xl': ['236'],
#              'Phyztastic': ['236'],
#              'BusTurBrown': ['236'],
#              '34573671264yi': ['1100'],
#              'CJS1337s': ['236'],
#              'TheMightyWharu': ['236'],
#              'perverthentai': ['236'],
#              'Hot2DGrill': ['233'],
#              'Silentfantasia': ['236'],
#              'dark_skeleton': ['234'],
#              'kmcca138': ['575'],
#              '76561198044557792': ['236'],
#              'Revolver_': ['93', '125'],
#              'de_reyals': ['236'],
#              'noidhazbeendetectedno': ['234'],
#              '76561198040603456': ['236'],
#              'MrSaberr': ['712'],
#              'bumpy213': ['236'],
#              '76561198041859916': ['575'],
#              '76561198124225196': ['447'],
#              'swatgamerbr': ['612'],
#              'mad1167': ['1336', '1340', '836', '837'],
#              'p0t4rt0': ['233'],
#              'ShadowExtreme': ['236'],
#              '76561198060544136': ['236'],
#              'skylord30': ['257'],
#              '76561198040704557': ['236', '240'],
#              'smNTC': ['236'],
#              'SWAGHIGHJAKKER': ['236'],
#              'Sparkzh2o': ['234'],
#              '76561198085996419': ['236'],
#              'nerrma': ['236'],
#              'StaticStabler': ['236'],
#              '76561198094163912': ['233'],
#              '76561198091620717': ['236'],
#              '76561198059628972': ['236'],
#              '76561198061950314': ['236'],
#              '76561198070164022': ['233'],
#              '76561198102490796': ['1100'],
#              '76561198022552926': ['234'],
#              '76561198065102350': ['236'],
#              'tdgodly': ['233'],
#              'Angus887Gaming': ['166', '264', '265'],
#              'TheMGScrub': ['257'],
#              'shroud1': ['612'],
#              '76561198054577621': ['257'],
#              '76561198023133231': ['234'],
#              '76561198067124717': ['575'],
#              'TiviTed': ['236'],
#              '76561198086973040': ['236'],
#              '76561198045904236': ['575'],
#              'PorraPelaMorDeDeus': ['236'],
#              '76561198022862450': ['236'],
#              '76561197980641293': ['236'],
#              '76561198064859777': ['236'],
#              'Serious_': ['236'],
#              '76561198045319744': ['257'],
#              'UnfitMantella': ['374'],
#              'theghostmkung': ['612'],
#              'unknownanimesensei': ['236'],
#              '76561198071507074': ['236'],
#              'PoreotixVail': ['236'],
#              'veroxAU': ['236'],
#              '76561198056094672': ['435'],
#              '76561198130206911': ['236'],
#              'dvs': ['236'],
#              'EliotJordan': ['374'],
#              'WhisKeyBby': ['236'],
#              'Whitts': ['236'],
#              '76561198117321520': ['234'],
#              '76561198091950237': ['236'],
#              'trpler': ['236'],
#              '76561198064681833': ['250'],
#              '76561197992887038': ['236'],
#              '76561198047115423': ['1336', '1340', '836', '837'],
#              'akaBryce': ['236'],
#              'togekiss906': ['236'],
#              'zenncs': ['236'],
#              '76561197993872196': ['236'],
#              '76561198066714498': ['612'],
#              '76561197980386478': ['1156', '683'],
#              'wade12wilson': ['236'],
#              'lordthanatosbr': ['233'],
#              '76561198081791076': ['429'],
#              '76561198060496164': ['575'],
#              'C_a_l_u_m': ['236'],
#              'mf2_profile': ['166', '264', '265'],
#              'SuchGayMuchWow': ['236'],
#              '35353534': ['236'],
#              'shooterhunter': ['233'],
#              '76561197996576526': ['236'],
#              'ihopethisurlhasnotbeentaken': ['236'],
#              'hvf': ['612'],
#              '76561198061042318': ['236'],
#              'CSMisBeast': ['495'],
#              'FPS-Mike': ['1100'],
#              '76561198075694490': ['236'],
#              'Dylbugs': ['236'],
#              'paw_ftw': ['236'],
#              '76561198060150729': ['983'],
#              '76561198066794851': ['236'],
#              '3021Daniel': ['236'],
#              'Aussiefella_69': ['236'],
#              '76561198072028129': ['236'],
#              'otorhinolaryngologist': ['429'],
#              'GeneralHavoc_': ['236'],
#              'AmeelAhmed': ['236'],
#              '76561198109423093': ['236'],
#              'analfelatiothecircumsoldier': ['236'],
#              'thecompl3x': ['236'],
#              'projecteldor': ['236'],
#              'xdeadlymoonx': ['236'],
#              'ChakaYourLaka': ['236'],
#              'DEANOXHILL': ['236'],
#              'samuelx5': ['827'],
#              '76561198066698645': ['236'],
#              'Jupacka': ['236', '240'],
#              '76561198244813534': ['236'],
#              '76561198068538206': ['236'],
#              '76561198054772649': ['236'],
#              'mayshowganmore': ['233'],
#              '76561198057953245': ['236'],
#              '76561198036780547': ['233'],
#              '76561198076240240': ['236'],
#              'HeadShootPlay': ['236'],
#              'Keemstarisgoat': ['236'],
#              'SitteNKitteNMitteN': ['236'],
#              '76561198081026741': ['236'],
#              'QueenJesus': ['312'],
#              '76561198052591219': ['233'],
#              'sparkmastertape': ['236'],
#              'erangaea': ['234'],
#              'DestinyzFate': ['236'],
#              '76561198085255228': ['236'],
#              'HiraethCSGO': ['236'],
#              'vaughanpwnyou': ['236'],
#              'puddingtip': ['236'],
#              'rustyspoon14': ['236'],
#              '76561198081869264': ['257'],
#              'Owlake': ['236'],
#              '76561198160501969': ['236'],
#              'heavygoingblah': ['236'],
#              'allan94': ['236'],
#              'sorrentor': ['236'],
#              'cockblockula': ['145'],
#              'OscarStone': ['236'],
#              'swiggins': ['234'],
#              '76561198045212236': ['236'],
#              '76561198122124339': ['236'],
#              'archangel147': ['1232'],
#              '76561198034565104': ['236'],
#              '76561198107458237': ['236'],
#              '76561198084889581': ['236'],
#              '76561198067738015': ['233'],
#              '76561198038695064': ['612'],
#              '76561197970476149': ['257'],
#              'ay65': ['236'],
#              'azives': ['257'],
#              '76561198022736341': ['236'],
#              'AciidxWarrior': ['447'],
#              '76561198039957089': ['1103'],
#              '76561197973196808': ['612'],
#              '76561198081332337': ['257'],
#              'FatalJester3': ['236'],
#              'lone_cow': ['575'],
#              'BananaChips': ['234'],
#              'Whyunofag': ['236'],
#              '76561198041862806': ['755'],
#              '76561198068976644': ['612'],
#              'Batman4040': ['236'],
#              '76561198061650250': ['496'],
#              '76561198086039782': ['236'],
#              'volcanopyre': ['236'],
#              'infinityhz': ['1336', '1340', '836', '837'],
#              '76561198021147247': ['93', '125'],
#              '76561198013922033': ['236'],
#              '76561198083484293': ['236'],
#              '76561198042250524': ['257'],
#              '76561198065439231': ['575'],
#              'BJEXHOOP': ['236'],
#              'ooblinkoo': ['335'],
#              'BLueKangaRoO': ['236'],
#              '76561198060068927': ['1100'],
#              'boaty7_3_21': ['868'],
#              'boldboulder': ['236'],
#              'blTaaaa': ['236'],
#              '76561198083799893': ['236'],
#              '76561197972384083': ['257'],
#              'Thatonecuntwiththeprofileandshit': ['236'],
#              'janope': ['236'],
#              'rainbowducklings4lyf': ['983'],
#              '76561198097758931': ['236'],
#              'Brojomojo': ['374'],
#              'bRNSHITUP': ['236'],
#              'Hogia': ['983'],
#              'whatiyatalkinabeet': ['236'],
#              '76561198070677367': ['236'],
#              '76561198051064887': ['234'],
#              'APCameron': ['236'],
#              'wcasagrande': ['166', '264', '265'],
#              'cazaman11': ['250'],
#              'Ch3nst3r': ['257'],
#              '76561198054761819': ['236'],
#              '76561198064600203': ['93', '125'],
#              '76561198071117635': ['575'],
#              '76561198088838638': ['435'],
#              '76561198091066992': ['236'],
#              '420BlzeIT': ['236'],
#              '76561197968205306': ['257'],
#              'Phor8': ['476'],
#              '76561198051461196': ['236', '240'],
#              '76561198090548578': ['236'],
#              '76561198051976770': ['612'],
#              '76561198072036519': ['236'],
#              '76561198040900746': ['233'],
#              '76561198075584298': ['236'],
#              '76561198098364705': ['236'],
#              '76561198097864769': ['233'],
#              '76561198082142359': ['236'],
#              '76561198044664331': ['575'],
#              '76561198050407999': ['236'],
#              'crualninja': ['1011', '419'],
#              'PokeyStabbyThing': ['1100'],
#              '76561198080133542': ['250'],
#              'Mishman44': ['233'],
#              'deathbyFIREWORKS': ['257'],
#              'BestCyanide': ['236'],
#              '76561198077828707': ['236'],
#              'czarplays': ['236'],
#              '76561198080574444': ['257'],
#              'quickquack': ['236'],
#              'FDAOP': ['234'],
#              'NymphIsBae': ['257'],
#              'OrangJagoBanget': ['236'],
#              '76561198075026598': ['236'],
#              'Demalice': ['575'],
#              'alicemurphynudes': ['236'],
#              'DethInvictus': ['429'],
#              'eel_deuce': ['575'],
#              'DewyHQ': ['361'],
#              'DimmortalZ': ['236'],
#              '76561198052090943': ['312'],
#              'DisturbedDope23': ['236'],
#              'DJSean': ['236'],
#              'georgebrah': ['236', '240'],
#              'apotatodealer': ['236', '240'],
#              '76561198067336524': ['447'],
#              '76561198082639535': ['236'],
#              'thepengwin': ['612'],
#              '76561198082881423': ['236', '240'],
#              'nolosing': ['257'],
#              'tallme22': ['236'],
#              '76561197999539608': ['236'],
#              'Redjay1': ['257'],
#              '76561198073666829': ['236'],
#              '76561198028843194': ['262'],
#              'Draydian': ['236'],
#              'drako227': ['236'],
#              'droids18': ['236'],
#              '76561198062039624': ['575'],
#              'Duckuy': ['234'],
#              'dudumon': ['236'],
#              'flamingdrag00n': ['234'],
#              'readthisURL': ['236'],
#              '76561198098852080': ['236'],
#              '76561198084685872': ['236'],
#              'landaishan': ['1158'],
#              'fghjndaguihuigheir': ['236'],
#              'HeyGoodCookin': ['236'],
#              '564743553uy5367': ['236'],
#              'qwevor': ['236', '240'],
#              '76561198103357676': ['166', '264', '265'],
#              '76561198056652803': ['983'],
#              'elgerjp': ['1100'],
#              'Elkurr': ['944'],
#              'Elt0r': ['166', '264', '265'],
#              'holy_angel_of_death': ['575'],
#              'escapetradingprofile': ['236'],
#              'TempestNZ': ['1047'],
#              '76561198062630600': ['757'],
#              '76561198102826090': ['236'],
#              'Exodus20010': ['233'],
#              'chrisread672': ['757'],
#              'Sweetnurs': ['575'],
#              'digitalgateway777': ['236'],
#              'feemdeusenosirmao': ['236'],
#              's2006mark': ['236'],
#              'FestiveDuckGaming': ['755'],
#              'ITS-A-FIDO': ['234'],
#              '76561198059849113': ['236'],
#              '76561198079354308': ['236'],
#              '76561198064195918': ['236'],
#              'FlandersRJ': ['575'],
#              'FlappyPants': ['236'],
#              '76561198034942053': ['757'],
#              'FloppyMop': ['236'],
#              '76561198059271374': ['374'],
#              'gdy3120': ['233'],
#              '76561198071717735': ['236'],
#              'beautifulgu00d': ['236'],
#              '76561198085097560': ['236'],
#              '76561198067106876': ['236'],
#              '76561198046061239': ['612'],
#              '76561198001508595': ['233'],
#              '76561198049424642': ['237'],
#              'regalgjblue': ['240'],
#              '76561198020361485': ['823', '157'],
#              'chillio': ['236'],
#              '76561198057307730': ['236'],
#              '76561198052489047': ['447'],
#              'saturnyplace': ['281'],
#              '76561198085686437': ['951'],
#              '76561198042535860': ['236'],
#              '76561198089724894': ['236'],
#              'chamith': ['236'],
#              'WaddleDaisy': ['1336', '1340', '836', '837'],
#              'gravalteration': ['233'],
#              'greenfuzzie23': ['233'],
#              '76561198120774355': ['236'],
#              'GUN5_0N_WH33L5': ['249'],
#              'angusstew': ['236'],
#              '76561198009887832': ['532'],
#              'Thuum': ['236'],
#              '76561198050546597': ['257'],
#              'hakimaro': ['236'],
#              '76561198096921300': ['233'],
#              '76561198112280759': ['236'],
#              '76561198198021682': ['236'],
#              'ejthesnakehunter': ['236'],
#              '76561198057263232': ['944'],
#              'fmtpp': ['236'],
#              'loki713': ['236'],
#              'H4ZEY': ['236'],
#              '76561197991827492': ['1011', '419'],
#              'umicornbl': ['166', '264', '265'],
#              '76561198077261748': ['234'],
#              'jeffycakes': ['236'],
#              'holastickboy': ['236'],
#              'jarryd187': ['233'],
#              '76561197999260941': ['532'],
#              '76561198044610496': ['236'],
#              'Zirah': ['236'],
#              'hortycone': ['250'],
#              'kibahz': ['236'],
#              'HunterKiller182': ['236'],
#              'mist_of_pandaria': ['236', '240'],
#              'getoffmeimdone': ['236'],
#              'iceyaz': ['236'],
#              '76561198071488355': ['236'],
#              'ihaveduff': ['983'],
#              '76561198067989394': ['374'],
#              'ValIsReallySexy': ['236'],
#              'IndigenousSid': ['233'],
#              '76561198094752240': ['262'],
#              'InvertedBolt': ['234'],
#              '76561198008302183': ['1047'],
#              'Elwnquelegusta2hu': ['233'],
#              '76561198066825426': ['233'],
#              '76561198093814775': ['236'],
#              '76561198034310657': ['1303'],
#              'jackmcfox': ['1156', '683'],
#              'aywotchadoin': ['236'],
#              'Bigzy': ['236'],
#              'JAMIEX1988': ['166', '264', '265'],
#              'japologamingYT': ['236'],
#              'quaz4': ['983'],
#              'Jasontermi': ['236'],
#              '76561198068301819': ['236'],
#              '76561198039327637': ['250'],
#              'qjoshz': ['236'],
#              '76561198046833211': ['236'],
#              'ItzABitRisky': ['236'],
#              'netherjack1': ['236'],
#              '76561198068647964': ['236'],
#              'joeshoer': ['236'],
#              'julianpkp': ['575'],
#              '76561198032916644': ['233'],
#              '76561198095547867': ['236'],
#              '-kainey9777': ['236'],
#              'Kairooss': ['236'],
#              'tacticalinjustice': ['575'],
#              '76561198088892521': ['236'],
#              'Ayrtanium100': ['257'],
#              '76561198117313704': ['236'],
#              'Kazuksta': ['236'],
#              '76561198057368586': ['236'],
#              'c3rtaind3ath': ['575'],
#              '76561198118209352': ['234'],
#              '76561197993077385': ['145'],
#              '76561198045484030': ['234'],
#              '76561198081168628': ['236'],
#              '76561197978703788': ['236'],
#              '76561198118867934': ['236'],
#              '76561198100835850': ['236'],
#              '110211021': ['236'],
#              'kumatorah': ['250'],
#              '76561198002469107': ['233'],
#              '76561198104984962': ['1100'],
#              'laserbear99': ['257'],
#              'LayzeeBoi': ['237'],
#              '76561198058616080': ['755'],
#              'TheHunter42': ['721'],
#              'kasanov': ['236'],
#              '76561198295178871': ['236'],
#              'LiMasala': ['236'],
#              'Liquiddddddddd': ['312'],
#              '76561198060682655': ['257'],
#              '76561198036925039': ['236'],
#              'Apedophileatyohouse': ['236'],
#              '76561198059897383': ['236'],
#              '76561198009649906': ['139'],
#              'lordswift': ['236'],
#              'FiLoBoI': ['236'],
#              'LudiAU': ['236'],
#              '76561198127267711': ['236'],
#              'platitudinal': ['236'],
#              'mrtownie66': ['257'],
#              '76561198046042992': ['257'],
#              '76561198069399556': ['236'],
#              'Mario596327': ['236'],
#              '76561198081787220': ['236'],
#              '76561198066656517': ['257'],
#              'MasterGible': ['236'],
#              '76561198078493105': ['236'],
#              'maxyrogers': ['236'],
#              'earthsea': ['257'],
#              'davidmai7': ['236'],
#              'mcharty': ['236'],
#              '76561198080525004': ['236'],
#              'Ineedmoney4food': ['234'],
#              'megamario1500': ['757'],
#              'crazyclerkm': ['236'],
#              'MrMasterix': ['236', '240'],
#              '76561198013259049': ['236'],
#              '76561198054719518': ['236'],
#              '76561198018551219': ['575'],
#              'tyansteRR199': ['236'],
#              'stopstalkingmypagefuckers': ['312'],
#              'mistermooth': ['374'],
#              '76561198191010871': ['1100'],
#              'mithriel': ['236'],
#              '76561198326180109': ['236'],
#              '76561198025910899': ['257'],
#              '76561198078155892': ['236'],
#              'BlooperDooper': ['236'],
#              'GreatShot': ['236'],
#              '76561198027828967': ['1350', '1351'],
#              'koongod01': ['612'],
#              '76561198105743297': ['250'],
#              'NOTHING_BUT_STAR_WARS': ['257'],
#              '279519365': ['236'],
#              'MrAH2010': ['575'],
#              '76561198074356093': ['236'],
#              '76561198077898598': ['1158'],
#              '76561198059829512': ['234'],
#              '76561197983046427': ['861'],
#              'mini_sentries_everywhere': ['435'],
#              '76561198055310480': ['236'],
#              'ryanirons2': ['236'],
#              'RealAdam': ['236'],
#              'DonGusto': ['236'],
#              'nickflig': ['278'],
#              '76561198057944974': ['257'],
#              '76561198120107003': ['233'],
#              '76561198033173262': ['236'],
#              '76561198081711671': ['157'],
#              '76561198064893805': ['1100'],
#              'DipShiet': ['983'],
#              '76561198039183543': ['429'],
#              '76561198088807138': ['257'],
#              'Nopeism': ['166', '264', '265'],
#              '76561198066675436': ['612'],
#              '76561198096211787': ['257'],
#              'Goofen': ['236'],
#              'nydac98': ['575'],
#              '76561198074860147': ['236'],
#              'zeldafan57': ['234'],
#              'jcottle': ['1100'],
#              'qtdraws': ['236'],
#              'oldboss': ['236'],
#              '76561198057988265': ['983'],
#              'gamerbegamin': ['951'],
#              '76561198083731654': ['461'],
#              'ooovegitaooo': ['236'],
#              '76561198004901938': ['236'],
#              '76561198062139862': ['249'],
#              '76561198075697854': ['236'],
#              'tortilla_very_nice': ['234'],
#              '76561198071374629': ['236'],
#              'katarushikun': ['690', '721'],
#              '76561198042409394': ['374'],
#              'F22Flipside': ['236'],
#              '76561198070015638': ['166', '264', '265'],
#              '76561198056545854': ['257'],
#              'Kill3rVen0m': ['236'],
#              '76561198065554374': ['257'],
#              'pigmentcs': ['236'],
#              'pingas4daysbruv': ['236'],
#              '76561198047245194': ['236'],
#              '76561198081613852': ['236'],
#              '76561198093344933': ['236'],
#              '76561198091006606': ['250'],
#              '76561198042243844': ['262'],
#              'sananaderi': ['572'],
#              'mentipede': ['1247'],
#              '76561198061805895': ['257'],
#              'snoopfogg': ['166', '264', '265'],
#              '76561198066291680': ['236'],
#              'porticoo': ['575'],
#              'iamnotcool': ['236'],
#              'PlayZonee': ['236'],
#              'miscgaming': ['236'],
#              'sabfy72uibngbniasfoq2hgio': ['236'],
#              'PrivateSpades': ['374'],
#              '76561198052654719': ['236'],
#              'PyroGT': ['612'],
#              'leeamf': ['983'],
#              'queenaphrodite': ['166', '264', '265'],
#              'rothplayzito': ['435'],
#              '76561198122488761': ['234'],
#              'Steamkilla77': ['233'],
#              '76561198062331003': ['233'],
#              'feifei30922': ['233'],
#              'korax777': ['236'],
#              'rerety2': ['236'],
#              'kissmytaco': ['236'],
#              'rich_': ['236'],
#              '76561198007037255': ['853'],
#              '76561198085668153': ['236'],
#              'scrubzee': ['236'],
#              '76561198091491495': ['236'],
#              'rowjack1993': ['169'],
#              '76561198078828166': ['257'],
#              '76561198071421016': ['236'],
#              '76561198029591433': ['236'],
#              'saltYplayZ': ['236'],
#              '76561198190566845': ['236'],
#              '76561198107130734': ['236'],
#              'sanaret': ['709'],
#              '-SatansLittleHelper-': ['236'],
#              '76561198056772858': ['236'],
#              'ColeGoddamnPhelps': ['236'],
#              '76561198034223204': ['572'],
#              'sbeghen': ['236'],
#              '76561197989758447': ['257'],
#              'ScorchingShadow': ['236'],
#              'Unscripteddd': ['236'],
#              '76561198082666592': ['236'],
#              'SergeantMason': ['1128'],
#              'aeon5ind': ['236'],
#              '76561198073819878': ['236'],
#              '76561198151855034': ['236'],
#              'Elementico': ['312'],
#              'fagulol': ['236'],
#              '76561198025979243': ['236'],
#              '76561198060481049': ['575'],
#              '76561198044375508': ['575'],
#              'shudipwnu': ['236'],
#              '76561198157097087': ['236'],
#              '76561198000167222': ['236'],
#              'SimonB252': ['236'],
#              '76561198044207497': ['236'],
#              'SithBen': ['1047'],
#              '76561198058919153': ['712'],
#              'Sm1ley96': ['236'],
#              '76561197977799906': ['233'],
#              'pheg': ['944'],
#              'wes132': ['236'],
#              '76561198072865679': ['236'],
#              '76561198052937077': ['250'],
#              'spazrael_': ['612'],
#              'kicking_ass_for_the_lord': ['257'],
#              'Spekl': ['236'],
#              'yepitsafeel': ['236'],
#              'spudcake': ['236'],
#              'Squash': ['1158'],
#              '76561198065240425': ['1047'],
#              '2ez2xl': ['236'],
#              'WHOTHEFUCKTOOKMYURL': ['250'],
#              'switchnation': ['374'],
#              'modz_x': ['236'],
#              'kiyadabae': ['234'],
#              '76561198061375427': ['236'],
#              'tackergun': ['1182'],
#              'Tankingtype': ['236'],
#              '76561198007573338': ['236'],
#              'HipsterGoku': ['236'],
#              'optamusjebus': ['1188'],
#              'TemsterGaming': ['250'],
#              'BotBuddha': ['257'],
#              '76561198098249951': ['233'],
#              '76561198091127623': ['944'],
#              'barren_cookie': ['374'],
#              'wbauern68': ['250'],
#              '76561198036064945': ['236'],
#              '76561197975058559': ['257'],
#              'ryalln': ['236'],
#              '76561198065663621': ['236'],
#              'Like_A_Director': ['166', '264', '265'],
#              '76561198077113035': ['233'],
#              'tanryanrachmat': ['236'],
#              'Mutivate': ['234'],
#              '76561198042649425': ['944'],
#              '76561198111408860': ['236'],
#              'Tismatty': ['1103'],
#              'NerdsRepublic-ID-Titch22': ['257'],
#              'GrifforkAndZeo': ['262'],
#              'GayTom': ['257'],
#              'toodybb': ['236'],
#              '76561198045771425': ['236'],
#              '76561198101089412': ['233'],
#              'hallyy123': ['575'],
#              'iamahomosexual': ['236'],
#              '76561198077183278': ['236'],
#              '76561198082161883': ['236'],
#              '76561198121482617': ['236'],
#              'Turtzzz': ['236'],
#              '42654264': ['236'],
#              'gustavogamesBR': ['236'],
#              'ungstein': ['236', '240'],
#              '76561198094634713': ['236'],
#              'Unl33t': ['257'],
#              '76561198073518018': ['236'],
#              'mudcakez': ['1100'],
#              '76561197984271449': ['1100'],
#              'iamavegan': ['236'],
#              '76561198059429616': ['575'],
#              'fung_bb': ['236'],
#              '76561198068101386': ['236'],
#              'jewhue': ['374'],
#              'pencilspankerjunior': ['236'],
#              '76561198064702734': ['236'],
#              'WaliWan': ['1100'],
#              '45544554455445': ['495'],
#              'weels1566': ['257'],
#              'weirdeiro': ['312'],
#              'weMAD': ['236'],
#              'wwere': ['983'],
#              '76561198036077253': ['233'],
#              '76561198013261893': ['575'],
#              'kyslolxd': ['236'],
#              'wicky46': ['374'],
#              '76561198042997251': ['166', '264', '265'],
#              'PBCharlie': ['236'],
#              'WillZENex': ['236'],
#              'Darkness211': ['278'],
#              'lifeondelay': ['166', '264', '265'],
#              'denkmeames': ['236'],
#              '76561198059866467': ['257'],
#              '76561198062891102': ['236'],
#              'xenesquatro': ['236'],
#              'Iassassinatedkennedy': ['1100'],
#              '76561198024559632': ['236'],
#              '76561198110607508': ['234'],
#              'yogidude': ['236'],
#              'yaknakz': ['257'],
#              '76561198063145410': ['139'],
#              '76561198040726300': ['435'],
#              '76561198044511328': ['236', '240'],
#              '--000--': ['612'],
#              'youagain': ['236'],
#              '76561198051367425': ['236'],
#              '76561198082566561': ['236'],
#              'ESHAYDOGS': ['236'],
#              '76561198045768753': ['236'],
#              '76561198068916178': ['236'],
#              'AnToHero': ['236'],
#              '76561198069478009': ['236'],
#              '76561198064281993': ['236'],
#              'zoom-the-flash': ['233'],
#              '-Zovix-': ['236'],
#              'zukuta': ['861'],
#              'zunbae': ['236'],
#              '76561198018026822': ['951'],
#              'Zilbong': ['612'],
#              '82897172842109498141289': ['236'],
#              'LegendofLink2712': ['236'],
#              'giogaming': ['1100'],
#              '76561198022820830': ['429'],
#              'HungasH1ppo': ['236'],
#              'Timmeh99': ['236'],
#              '76561198256961474': ['1100'],
#              '76561198050543795': ['236'],
#              '76561198086687010': ['233'],
#              '4200769711': ['236'],
#              'Wolf2311': ['236'],
#              '76561197998014300': ['236'],
#              '76561198022115367': ['236'],
#              'Philipsgz': ['234'],
#              'pulosi': ['236'],
#              '4123223232': ['236'],
#              'markimoo2': ['236'],
#              'tyronelannsiter': ['236'],
#              'Walrusrick': ['1158'],
#              'cyanpile28': ['236'],
#              '76561198056455203': ['233'],
#              'IAmAbel': ['236'],
#              'coutlindo': ['236'],
#              'goneckahorse': ['236'],
#              'RuslaNLoveStefochka': ['236'],
#              'bright43': ['612'],
#              '76561197995192202': ['612'],
#              '33215469': ['236'],
#              'Nightmare28': ['236', '240'],
#              '76561198112249349': ['236'],
#              'dagster_007': ['236'],
#              'BonusZx': ['236'],
#              '76561198093944702': ['233'],
#              '76561198090694948': ['236'],
#              'Badly306': ['236'],
#              'Jabooni': ['236'],
#              '76561198080080397': ['236'],
#              '76561198079033916': ['236'],
#              'bantiacmd': ['236'],
#              '76561198057125811': ['236'],
#              '76561198071592038': ['236'],
#              '76561198085301805': ['233'],
#              '76561198058477537': ['575'],
#              '38927497': ['344'],
#              '402553929': ['236'],
#              'Kyercon': ['612'],
#              '76561198010280507': ['236'],
#              'aussiebloke_': ['236'],
#              '76561198063575392': ['236'],
#              '76561198065639052': ['236'],
#              'amann99': ['236'],
#              '76561198087197141': ['312'],
#              'drnipslip': ['236'],
#              'Jettsu': ['236'],
#              'LachieCS': ['236'],
#              'TMhun': ['166', '264', '265'],
#              'tchannygod': ['236'],
#              '76561198066391503': ['257'],
#              'HewloThere': ['236', '240'],
#              '76561198054088781': ['236'],
#              '76561198028258767': ['236'],
#              'YOuevenRoBOtMeOw': ['236'],
#              '29998000': ['1232'],
#              'l0se': ['236'],
#              'pro100van4eg': ['236'],
#              '76561198232483600': ['236'],
#              'InDoMieEnakz': ['236'],
#              'jacmacg': ['236'],
#              'captainjaydo': ['236'],
#              'GubTheKing': ['236'],
#              '76561198090998972': ['236'],
#              '76561198097160277': ['236'],
#              '76561198100183135': ['236'],
#              '2271531450': ['236'],
#              'jpvalletta': ['236'],
#              'yokkiixd': ['755'],
#              '76561198065084165': ['236'],
#              'ChokeChoke': ['233'],
#              'nooth1-RNG': ['236'],
#              'nooth2-WFX-zewsy': ['236'],
#              '76561198038722008': ['236'],
#              'L33T4RCH': ['1100'],
#              '76561198091779143': ['236'],
#              'izanamiau': ['236', '240'],
#              'xoxoQoxox': ['236'],
#              'NineODoge': ['1100'],
#              'lsleon': ['236'],
#              '76561198172525222': ['236'],
#              'TheCatNinjaz': ['447'],
#              'ZevereKryor': ['236'],
#              'xgotfearzx': ['236'],
#              'qwertycx_': ['236'],
#              'GlaLoid': ['233'],
#              'jakesnake': ['335'],
#              '76561198077612701': ['236'],
#              'tahrone': ['236'],
#              'monkeymatt1211': ['257'],
#              '76561197980184475': ['236'],
#              '76561198050620146': ['236'],
#              '-Beave-': ['233'],
#              'UfKnW0tM8': ['236'],
#              '76561198082799563': ['236'],
#              '76561198065795972': ['575'],
#              'lteecsgo': ['236'],
#              'arttab001': ['166', '264', '265'],
#              '76561197989691928': ['236', '240'],
#              '76561198052164759': ['236'],
#              '76561198067714968': ['236', '240'],
#              '76561198054027518': ['257'],
#              '1337_K_REW': ['236'],
#              '76561198085294887': ['236'],
#              'felipespy': ['236'],
#              'novaelite12': ['236'],
#              'cypher_1': ['236'],
#              'sprinter2002': ['236'],
#              'vyyyy': ['233'],
#              '654986416581986168165': ['236'],
#              '76561198081016729': ['236'],
#              'uncleden': ['1100'],
#              '76561198066689974': ['236'],
#              '76561198081727587': ['236'],
#              ...})
